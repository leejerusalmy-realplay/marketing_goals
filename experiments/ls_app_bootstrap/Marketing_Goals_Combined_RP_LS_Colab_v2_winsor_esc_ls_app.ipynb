# %% [markdown]
# # Marketing Goals — Combined (RP + LS) · **Colab** · v2 winsor_esc + LS App
#
# *Lee Jerusalmy*
#
# This is Lee's **v2 winsor_escalation** Combined Colab, plus **LoneStar App**.
#
# Open in Colab: Runtime → Run all.
#
# ### What this file does
# - **RP all pops + LS Web / Affiliate / Blended:** capped winsor escalation (`pct_used` wired into the curve).
# - **LS App:** map `affid = 1` → App. Winsor stays **0%** (no escalation). Native curve through last measured day, then **RP App day-growth** (`native_early_rp_tail`).
# - **LS Blended** stays Web + Affiliate only. App is an add-on.
# - **Organic:** LS Web/Aff use RP-style `non_app`. **LS App organic is off for now** (`organic_share = 0`, so adjusted = raw). Blended organic = 0. Mapping still has `scope`/`bucket` for later.
#
# ### Locked main columns
# `brand`, `population`, `goal_horizon`, `day`, `raw_goal_ratio`, `organic_share`, `adjusted_goal_ratio`
#
# ### How to run
# 1. **Runtime → Run all** (or top → bottom).
# 2. First cell: click allow for Google auth.
# 3. Optional: mount Drive to write under `lee_project/marketing_goals/runs/`.
# 4. `AS_OF_DATE` is pinned like v2 (`2026-08-03`) until you change it.
#
# Do not edit `reference/`. Not a methodology lock. Generic `notebooks/` Combined stays baseline.

# %%
# ── Auth (Google Colab) ──────────────────────────────────────────
from google.colab import auth
auth.authenticate_user()
IN_COLAB = True
print('Authenticated (Colab)')
# Out:
# Authenticated (Colab)

# %%
project_id = 'oceanic-citadel-454608-d2'
from google.cloud import bigquery
client = bigquery.Client(project=project_id)
print('BigQuery client ready for', project_id)
# Out:
# BigQuery client ready for oceanic-citadel-454608-d2

# %%
# ── Optional: mount Google Drive (to write under marketing_goals/runs/) ──
# Skip this cell if you only want browser downloads.

MOUNT_DRIVE = True  # set False to skip

if MOUNT_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    print('Drive mounted. Expected runs path:')
    print('  /content/drive/MyDrive/lee_project/marketing_goals/runs')
    print('  (or My Drive with a space — export cell checks both)')
else:
    print('Drive mount skipped — export will browser-download CSVs only.')
# Out:
# Mounted at /content/drive
# Drive mounted. Expected runs path:
#   /content/drive/MyDrive/lee_project/marketing_goals/runs
#   (or My Drive with a space — export cell checks both)

# %%
import pandas as pd
import numpy as np
from pandas_gbq import read_gbq

# ── Date anchor (shared for both brands) ──
# ADDED: pinned to 2026-08-03 so cohort_start/end per patch match runs/2026-08-03_rp_ls
# for before/after comparison of the adaptive-winsor test. REVERT to rolling
# `pd.Timestamp.now().normalize() - pd.Timedelta(days=2)` after this test round
# and once the fix is adopted for production runs.
AS_OF_DATE = pd.Timestamp('2026-08-03').normalize()  # pinned for before/after comparison

# ── Shared patch / horizon calendar ──
PATCHES = (
    (1, 7), (7, 14), (14, 30), (30, 60), (60, 90),
    (90, 120), (120, 150), (150, 180), (180, 270), (270, 365),
)
GOAL_HORIZONS = [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
CHECKPOINTS   = [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
LOOKBACK_COHORTS = 35
ORGANIC_LABEL = 'Organic'

# ── Which brands to run ──
RUN_BRANDS = ['realprize', 'lonestar']

# ── Per-brand knobs (from config/*.yaml / Combined predecessors) ──
BRAND_CONFIGS = {
    'realprize': {
        'brand': 'realprize',
        'cost_table': 'analytics.realprize_cost_per_user',
        'deposits_table': 'realprize.casino_astropay_dmn',
        # TikTok excluded entirely
        'exclude_affids': [4313],
        'populations': ['Web', 'App', 'Affiliate'],
        'trim_config': {
            'App':       {'method': 'winsor', 'pct': 0},
            'Web':       {'method': 'winsor', 'pct': 0.01},
            'Affiliate': {'method': 'winsor', 'pct': 0.01},
            'Blended':   {'method': 'winsor', 'pct': 0},
        },
        'organic_trim_method': 'winsor',
        'organic_trim_pct': 0,
        # App attribution change ~2025-08-12 — pin share above this horizon
        'organic_share_cap_horizon': 120,
        'cv_threshold': 0.15,
        'cv_good_enough': 0.10,
        'max_remove_fraction': 0.15,
        # RP Combined did not use a min-cohort-dates gate (default 1)
        'min_cohort_dates': 1,
        # Tail fill only in LS predecessor
        'extrapolate_tail': False,
        'extrapolation_tail_days': 30,
        'has_scope_bucket': True,  # app / non_app + app_organic
        'users_sql': None,  # filled below via builder
    },
    'lonestar': {
        'brand': 'lonestar',
        'cost_table': 'analytics.lonestar_cost_per_user',
        'deposits_table': 'lonestar.casino_astropay_dmn',
        # TikTok + TikTok Canada
        'exclude_affids': [4866, 7127],
        'populations': ['Web', 'Affiliate'],  # App is an add-on in the RUN cell; not in Blended
        'trim_config': {
            'Web':       {'method': 'winsor', 'pct': 0},
            'App':       {'method': 'winsor', 'pct': 0},  # locked 0%; RUN skips escalation
            'Affiliate': {'method': 'winsor', 'pct': 0.01},
            'Blended':   {'method': 'winsor', 'pct': 0},
        },
        'organic_trim_method': 'winsor',
        'organic_trim_pct': 0,
        # No organic share cap on LS
        'organic_share_cap_horizon': None,
        'cv_threshold': 0.15,
        'cv_good_enough': 0.10,
        'max_remove_fraction': 0.15,
        'min_cohort_dates': 20,
        'extrapolate_tail': True,
        'extrapolation_tail_days': 30,
        'has_scope_bucket': True,  # app / non_app + app_organic (same idea as RP)
        'users_sql': None,
    },
}

# ── Monitoring (print sub-outputs after each pipeline step) ──
# True  = show intermediate tables in Colab after each part (recommended first runs)
# False = quieter (still prints step banners + row counts)
MONITOR_STEPS = True
MONITOR_PREVIEW_DAYS = [1, 7, 14, 30, 60, 90, 120, 180, 270, 365]
MONITOR_PREVIEW_HORIZONS = [7, 30, 120, 365]  # goals sample only

print('ENV: Google Colab')

# ── Seed Combined globals (overwritten per brand in apply_brand_globals) ──
# Helper cells use these names as defaults; they MUST exist before those cells run.
POPULATIONS = list(BRAND_CONFIGS['realprize']['populations'])  # first brand's list as placeholder
TRIM_CONFIG = dict(BRAND_CONFIGS['realprize']['trim_config'])
ORGANIC_TRIM_METHOD = BRAND_CONFIGS['realprize']['organic_trim_method']
ORGANIC_TRIM_PCT = BRAND_CONFIGS['realprize']['organic_trim_pct']
ORGANIC_SHARE_CAP_HORIZON = BRAND_CONFIGS['realprize']['organic_share_cap_horizon']
CV_THRESHOLD = BRAND_CONFIGS['realprize']['cv_threshold']
CV_GOOD_ENOUGH = BRAND_CONFIGS['realprize']['cv_good_enough']
MAX_REMOVE_FRACTION = BRAND_CONFIGS['realprize']['max_remove_fraction']
MIN_COHORT_DATES = BRAND_CONFIGS['realprize']['min_cohort_dates']
EXTRAPOLATE_TAIL = BRAND_CONFIGS['realprize']['extrapolate_tail']
EXTRAPOLATION_TAIL_DAYS = BRAND_CONFIGS['realprize']['extrapolation_tail_days']
ACTIVE_BRAND = None

print(f'Config loaded. as_of_date = {AS_OF_DATE.date()}')
print(f'Brands to run: {RUN_BRANDS}')
print(f'Monitor steps = {MONITOR_STEPS}')
print('Mode: PERSISTENT TRIM (excluded users carry forward)')
print('Main goals columns: brand, population, goal_horizon, day, raw_goal_ratio, organic_share, adjusted_goal_ratio')
# Out:
# ENV: Google Colab
# Config loaded. as_of_date = 2026-08-03
# Brands to run: ['realprize', 'lonestar']
# Monitor steps = True
# Mode: PERSISTENT TRIM (excluded users carry forward)
# Main goals columns: brand, population, goal_horizon, day, raw_goal_ratio, organic_share, adjusted_goal_ratio

# %%
# ══════════════════════════════════════════════════════════════
# APPLY BRAND CONFIG → module-level globals used by helpers
# (same variable names as Combined predecessors)
# ══════════════════════════════════════════════════════════════

def apply_brand_globals(cfg: dict) -> None:
    """Set Combined-style globals for one brand before running the pipeline."""
    global POPULATIONS, TRIM_CONFIG
    global ORGANIC_TRIM_METHOD, ORGANIC_TRIM_PCT, ORGANIC_SHARE_CAP_HORIZON
    global CV_THRESHOLD, CV_GOOD_ENOUGH, MAX_REMOVE_FRACTION
    global MIN_COHORT_DATES, EXTRAPOLATE_TAIL, EXTRAPOLATION_TAIL_DAYS
    global ACTIVE_BRAND

    ACTIVE_BRAND = cfg['brand']
    POPULATIONS = list(cfg['populations'])
    TRIM_CONFIG = dict(cfg['trim_config'])
    ORGANIC_TRIM_METHOD = cfg['organic_trim_method']
    ORGANIC_TRIM_PCT = cfg['organic_trim_pct']
    ORGANIC_SHARE_CAP_HORIZON = cfg['organic_share_cap_horizon']
    CV_THRESHOLD = cfg['cv_threshold']
    CV_GOOD_ENOUGH = cfg['cv_good_enough']
    MAX_REMOVE_FRACTION = cfg['max_remove_fraction']
    MIN_COHORT_DATES = cfg['min_cohort_dates']
    EXTRAPOLATE_TAIL = cfg['extrapolate_tail']
    EXTRAPOLATION_TAIL_DAYS = cfg['extrapolation_tail_days']

    print(f"\n{'=' * 60}")
    print(f"BRAND: {ACTIVE_BRAND}")
    print(f"  populations = {POPULATIONS}")
    print(f"  CV threshold = {CV_THRESHOLD}  good_enough = {CV_GOOD_ENOUGH}")
    print(f"  min_cohort_dates = {MIN_COHORT_DATES}")
    print(f"  extrapolate_tail = {EXTRAPOLATE_TAIL}")
    print(f"  organic_share_cap_horizon = {ORGANIC_SHARE_CAP_HORIZON}")
    print(f"{'=' * 60}")


def load_brand_tables(cfg: dict, as_of_date=AS_OF_DATE):
    """Pull cost-per-user population assignment + deposit revenue for one brand."""
    sql_floor = (
        as_of_date - pd.Timedelta(days=max(GOAL_HORIZONS) + LOOKBACK_COHORTS + 5)
    ).date()
    brand = cfg['brand']
    cost_table = cfg['cost_table']
    dep_table = cfg['deposits_table']
    excl = cfg['exclude_affids']
    excl_sql = ', '.join(str(a) for a in excl)

    print(f'[{brand}] SQL floor date: {sql_floor}  (AS_OF_DATE = {as_of_date.date()})')

    if brand == 'realprize':
        # scope + bucket for App organic vs non_app organic
        users_sql = f"""
        SELECT
          id,
          CASE
            WHEN affid IN (63, 2521, 2535, 4957, 4971, 5048, 5062, 5069) THEN 'Web'
            WHEN affid = 1                                    THEN 'App'
            WHEN affid IN (64, 71)                            THEN 'PPC'
            WHEN affid IN (0, 78, 2290)                       THEN 'Organic'
            ELSE 'Affiliate'
          END AS population,
          CASE WHEN affid = 1 THEN 'app' ELSE 'non_app' END AS scope,
          CASE
            WHEN affid = 1 AND channel_type = 'app_organic' THEN 'organic'
            WHEN affid = 1                                   THEN 'acquired'
            WHEN affid IN (0, 78, 2290)                      THEN 'organic'
            ELSE 'acquired'
          END AS bucket,
          DATE(MIN(cost_date)) AS cost_date
        FROM `{cost_table}`
        WHERE cost_date >= DATE('{sql_floor}')
          AND affid NOT IN ({excl_sql})
          AND id > 0
        GROUP BY id, population, scope, bucket
        """
    elif brand == 'lonestar':
        # Same scope/bucket idea as RP so App gets its own organic share
        users_sql = f"""
        SELECT
          id,
          CASE
            WHEN affid IN (63, 4432, 4551, 4698, 5048, 5125, 7120, 7253, 7260, 8331, 8345) THEN 'Web'
            WHEN affid = 1 THEN 'App'
            WHEN affid IN (64, 71)  THEN 'PPC'
            WHEN affid IN (0, 78)   THEN 'Organic'
            ELSE 'Affiliate'
          END AS population,
          CASE WHEN affid = 1 THEN 'app' ELSE 'non_app' END AS scope,
          CASE
            WHEN affid = 1 AND channel_type = 'app_organic' THEN 'organic'
            WHEN affid = 1                                   THEN 'acquired'
            WHEN affid IN (0, 78)                            THEN 'organic'
            ELSE 'acquired'
          END AS bucket,
          DATE(MIN(cost_date)) AS cost_date
        FROM `{cost_table}`
        WHERE cost_date >= DATE('{sql_floor}')
          AND affid NOT IN ({excl_sql})
          AND id > 0
        GROUP BY id, population, scope, bucket
        """
    else:
        raise ValueError(f'Unknown brand: {brand}')

    revenue_sql = f"""
    SELECT
      playerId AS playerid,
      DATE(date) AS date,
      SUM(amount) / 100.0 AS amount
    FROM `{dep_table}`
    WHERE Status = 'APPROVED'
      AND date >= DATE('{sql_floor}')
    GROUP BY 1, 2
    """

    users_df = read_gbq(users_sql, project_id=project_id, use_bqstorage_api=True)
    revenue_df = read_gbq(revenue_sql, project_id=project_id, use_bqstorage_api=True)

    print(f'[{brand}] users_df:   {len(users_df):,} rows')
    print(f'[{brand}] revenue_df: {len(revenue_df):,} rows')
    print(users_df['population'].value_counts().to_string())
    return users_df, revenue_df

print('Brand loader + apply_brand_globals ready.')
# Out:
# Brand loader + apply_brand_globals ready.

# %%
# ══════════════════════════════════════════════════════════════
# HELPERS — math & base table construction
# ══════════════════════════════════════════════════════════════

def weighted_mean_std_cv(x, w):
    x = np.asarray(x, dtype=float)
    w = np.asarray(w, dtype=float)
    m = np.isfinite(x) & np.isfinite(w) & (w > 0)
    x, w = x[m], w[m]
    if x.size == 0:
        return np.nan, np.nan, np.nan
    mu  = np.average(x, weights=w)
    var = np.average((x - mu) ** 2, weights=w)
    sd  = np.sqrt(var)
    cv  = sd / mu if mu != 0 else np.nan
    return mu, sd, cv


def build_user_revenue_cums(users_df, revenue_df, *, max_day=365):
    """
    Precompute cumulative per-user revenue indexed by (population, cost_date, user, dsi).
    Returns:
      u          — one row per (population, user) with their earliest cost_date
      daily_user — cumulative revenue at each (population, cost_date, user, dsi)
    """
    u = users_df[['id', 'population', 'cost_date']].copy()
    u['population'] = u['population'].astype(str).str.strip()
    u['cost_date']  = pd.to_datetime(u['cost_date'], errors='coerce').dt.date
    u = u.loc[pd.notna(u['cost_date'])].copy()
    u = u.groupby(['population', 'id'], as_index=False)['cost_date'].min()
    u = u.rename(columns={'id': '__uid__'})

    r = revenue_df[['playerid', 'date', 'amount']].copy()
    r['date'] = pd.to_datetime(r['date'], errors='coerce').dt.date
    r = r.loc[pd.notna(r['date'])].copy()

    rr = r.merge(u, left_on='playerid', right_on='__uid__', how='inner')
    rr['dsi'] = (pd.to_datetime(rr['date']) - pd.to_datetime(rr['cost_date'])).dt.days
    rr = rr.loc[(rr['dsi'] >= 0) & (rr['dsi'] <= (max_day - 1))].copy()

    daily_user = (
        rr.groupby(['population', 'cost_date', '__uid__', 'dsi'], observed=True)['amount']
          .sum().reset_index()
          .sort_values(['population', 'cost_date', '__uid__', 'dsi'])
    )
    daily_user['cum_amount'] = (
        daily_user.groupby(['population', 'cost_date', '__uid__'], observed=True)['amount']
                  .cumsum()
    )
    return u, daily_user


print('Math + base table helpers defined.')
# Out:
# Math + base table helpers defined.

# %%
# ══════════════════════════════════════════════════════════════
# HELPERS — trimming & cohort revenue summation
# ══════════════════════════════════════════════════════════════

def compute_winsor_caps(daily_user_cums, cohort_users, e, top_pct=0.01):
    """Cap per-user cumulative revenue at the (1-top_pct) quantile within each cohort date."""
    if top_pct <= 0:
        caps = cohort_users[['population', 'cost_date', '__uid__']].copy()
        caps['cap_e'] = np.inf
        return caps
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= (e - 1)].copy()
    if du.empty:
        caps = cohort_users[['population', 'cost_date', '__uid__']].copy()
        caps['cap_e'] = np.inf
        return caps
    per_user = (
        du.groupby(['population', 'cost_date', '__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum_e')
    )
    per_user = cohort_users.merge(per_user, on=['population', 'cost_date', '__uid__'], how='left')
    per_user['cum_e'] = per_user['cum_e'].fillna(0.0)
    per_user['cap_e'] = (
        per_user.groupby(['population', 'cost_date'], observed=True)['cum_e']
                .transform(lambda s: s[s > 0].quantile(1.0 - top_pct) if (s > 0).any() else np.inf)
    )
    return per_user[['population', 'cost_date', '__uid__', 'cap_e']]


def apply_cohort_trim(daily_user_cums, cohort_users, e, trim_pct=0.10):
    """Remove the top trim_pct of depositors (by cumulative revenue) from each cohort date."""
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= (e - 1)].copy()
    if du.empty:
        return cohort_users.copy()
    per_user = (
        du.groupby(['population', 'cost_date', '__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum_e')
    )
    per_user = cohort_users.merge(per_user, on=['population', 'cost_date', '__uid__'], how='left')
    per_user['cum_e'] = per_user['cum_e'].fillna(0.0)
    depositors = per_user.loc[per_user['cum_e'] > 0].copy()
    if depositors.empty:
        return cohort_users.copy()
    thresholds = (
        depositors.groupby(['population', 'cost_date'], observed=True)['cum_e']
                  .quantile(1.0 - trim_pct).reset_index(name='threshold')
    )
    per_user = per_user.merge(thresholds, on=['population', 'cost_date'], how='left')
    per_user['threshold'] = per_user['threshold'].fillna(np.inf)
    keep = per_user.loc[
        (per_user['cum_e'] == 0) | (per_user['cum_e'] <= per_user['threshold'])
    ][['population', 'cost_date', '__uid__']]
    return keep.copy()


def get_trimmed_cohort_and_caps(population, cohort_users, daily_user_cums, e, pct_override=None):
    # CHANGED: optional pct_override for per-patch winsor escalation; now returns method, pct_used
    cfg = TRIM_CONFIG.get(population, {'method': 'cohort_trim', 'pct': 0.10})
    method = cfg['method']
    caps, trimmed = None, cohort_users
    if method == 'winsor':
        # ADDED: when pct_override is set, use it instead of config floor (winsor only)
        pct_used = cfg['pct'] if pct_override is None else pct_override
        caps = compute_winsor_caps(daily_user_cums, cohort_users, e, top_pct=pct_used)
    elif method == 'cohort_trim':
        # unchanged: no escalation for cohort_trim
        pct_used = cfg['pct']
        trimmed = apply_cohort_trim(daily_user_cums, cohort_users, e, trim_pct=pct_used)
    else:
        pct_used = cfg.get('pct', 0)
    return trimmed, caps, method, pct_used


def sum_cum_at_idx(daily_user_cums, *, cohort_users, idx, caps=None):
    """Sum cumulative revenue across all users in cohort_users at day index idx."""
    grp_cols = ['population', 'cost_date']
    if idx < 0:
        out = cohort_users.groupby(grp_cols, observed=True)['__uid__'].nunique().reset_index()
        out['sum_cum'] = 0.0
        return out[grp_cols + ['sum_cum']]
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= idx].copy()
    if du.empty:
        out = cohort_users.groupby(grp_cols, observed=True)['__uid__'].nunique().reset_index()
        out['sum_cum'] = 0.0
        return out[grp_cols + ['sum_cum']]
    per_user = (
        du.groupby(grp_cols + ['__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum')
    )
    per_user = cohort_users.merge(per_user, on=grp_cols + ['__uid__'], how='left')
    per_user['cum'] = per_user['cum'].fillna(0.0)
    if caps is not None:
        per_user = per_user.merge(caps, on=grp_cols + ['__uid__'], how='left')
        per_user['cap_e'] = per_user['cap_e'].fillna(np.inf)
        per_user['cum']   = np.minimum(per_user['cum'], per_user['cap_e'])
    sums = per_user.groupby(grp_cols, observed=True)['cum'].sum().reset_index(name='sum_cum')
    return sums


print('Trim + summation helpers defined.')
# Out:
# Trim + summation helpers defined.

# %%
# ══════════════════════════════════════════════════════════════
# ADAPTIVE CV ANALYSIS — persistent trim
# ══════════════════════════════════════════════════════════════

# ADDED: winsor escalation ladder (per patch). Start at TRIM_CONFIG floor; climb
# only until cv_after <= CV_THRESHOLD. Never go below floor; never overshoot past first clear.
WINSOR_ESCALATION_STEPS = [0.0, 0.005, 0.01, 0.02, 0.03, 0.05]

# ADDED: second stop — do not escalate into a pct that caps away too much revenue.
# If a candidate would cut more than this fraction of total_rev_before_trim, reject it
# and keep the previous (lower) pct's result (even if still flagged).
MAX_REVENUE_CUT_FRACTION = 0.15


def patch_cv_adaptive(
    u_base, daily_user_cums, *,
    population, s, e, as_of_date,
    excluded_uids=None,
    lookback_cohorts=None,
    cv_threshold=None,
    cv_good_enough=None,
    max_remove_fraction=None,
    debug=True,
):
    # Resolve defaults at call time (after brand config applied)
    if lookback_cohorts is None:
        lookback_cohorts = LOOKBACK_COHORTS
    if cv_threshold is None:
        cv_threshold = CV_THRESHOLD
    if cv_good_enough is None:
        cv_good_enough = CV_GOOD_ENOUGH
    if max_remove_fraction is None:
        max_remove_fraction = MAX_REMOVE_FRACTION
    as_of_date   = pd.to_datetime(as_of_date).normalize()
    cohort_end   = (as_of_date - pd.Timedelta(days=e)).date()
    cohort_start = (as_of_date - pd.Timedelta(days=e + (lookback_cohorts - 1))).date()

    cohort_users = u_base.loc[
        (u_base['population'] == population) &
        (u_base['cost_date'] >= cohort_start) &
        (u_base['cost_date'] <= cohort_end)
    ][['population', 'cost_date', '__uid__']].copy()

    if cohort_users.empty:
        return pd.DataFrame(), {}, [], False, set()

    all_cohort_users = cohort_users.copy()
    n_users_in_cohort = int(cohort_users['__uid__'].nunique())

    if excluded_uids:
        cohort_users = cohort_users.loc[
            ~cohort_users['__uid__'].isin(excluded_uids)
        ].copy()

    n_users_after_prior = int(cohort_users['__uid__'].nunique())
    n_users_excluded_prior = n_users_in_cohort - n_users_after_prior

    if cohort_users.empty:
        return pd.DataFrame(), {}, [], False, set()

    # ADDED: winsor escalation — candidate pcts from config floor upward
    cfg = TRIM_CONFIG.get(population, {})
    floor_pct = cfg.get('pct', 0)
    method_cfg = cfg.get('method', 'none')
    if method_cfg != 'winsor':
        candidates = [floor_pct]
    else:
        candidates = sorted(set([floor_pct] + [p for p in WINSOR_ESCALATION_STEPS if p >= floor_pct]))

    sum_e_all = sum_cum_at_idx(
        daily_user_cums, cohort_users=all_cohort_users, idx=e - 1, caps=None
    ).rename(columns={'sum_cum': 'sum_cum_e_all'})
    total_rev_before_trim = float(sum_e_all['sum_cum_e_all'].sum())

    # Final state = last acceptable candidate (within revenue-cut limit), or first clear.
    patch = pd.DataFrame()
    remaining = pd.DataFrame()
    removed = []
    newly_excluded = set()
    n_users_pre_trim = n_users_after_prior
    n_users_post_trim = n_users_after_prior
    cv_before = np.nan
    cv_after = np.nan
    mean_a = np.nan
    flagged = False
    pct_used = floor_pct
    trim_method = method_cfg
    n_escalation_steps_tried = 0
    total_rev_after_trim = 0.0
    revenue_cut_fraction = 0.0
    capped_by_revenue_limit = False
    has_acceptable = False  # True once we have a result within the revenue-cut limit

    for pct_try in candidates:
        n_escalation_steps_tried += 1

        # CHANGED: unpack method + pct_used; pass pct_override for this attempt
        trimmed_users, caps, trim_method_try, pct_used_try = get_trimmed_cohort_and_caps(
            population, cohort_users, daily_user_cums, e, pct_override=pct_try
        )
        n_users_pre_trim_try  = n_users_after_prior
        n_users_post_trim_try = int(trimmed_users['__uid__'].nunique())

        newly_excluded_try = (
            set(cohort_users['__uid__'].unique()) - set(trimmed_users['__uid__'].unique())
        )

        denom_w = (
            trimmed_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                         .nunique().reset_index(name='N_users')
        )
        sum_s = sum_cum_at_idx(
            daily_user_cums, cohort_users=trimmed_users, idx=s - 1, caps=caps
        ).rename(columns={'sum_cum': 'sum_cum_s'})
        sum_e = sum_cum_at_idx(
            daily_user_cums, cohort_users=trimmed_users, idx=e - 1, caps=caps
        ).rename(columns={'sum_cum': 'sum_cum_e'})

        patch_try = (
            denom_w
            .merge(sum_s, on=['population', 'cost_date'])
            .merge(sum_e, on=['population', 'cost_date'])
        )
        patch_try['ARPU_s']       = patch_try['sum_cum_s'] / patch_try['N_users']
        patch_try['ARPU_e']       = patch_try['sum_cum_e'] / patch_try['N_users']
        patch_try['growth_ratio'] = np.where(
            patch_try['ARPU_s'] > 0, patch_try['ARPU_e'] / patch_try['ARPU_s'], np.nan
        )

        _, _, cv_before_try = weighted_mean_std_cv(
            patch_try['growth_ratio'].values, patch_try['sum_cum_s'].values
        )

        mu_unw = np.nanmean(patch_try['growth_ratio'].values)
        patch_try['abs_dev'] = (patch_try['growth_ratio'] - mu_unw).abs()
        sorted_dates  = patch_try.sort_values('abs_dev', ascending=False)['cost_date'].tolist()
        max_removable = max(1, int(np.floor(len(patch_try) * max_remove_fraction)))

        removed_try   = []
        remaining_try = patch_try.copy()

        for candidate in sorted_dates:
            _, _, cv_now = weighted_mean_std_cv(
                remaining_try['growth_ratio'].values, remaining_try['sum_cum_s'].values
            )
            if np.isnan(cv_now) or cv_now <= cv_good_enough:
                break
            if len(removed_try) >= max_removable:
                break
            removed_try.append(candidate)
            remaining_try = remaining_try.loc[~remaining_try['cost_date'].isin(removed_try)]

        mean_a_try, _, cv_after_try = weighted_mean_std_cv(
            remaining_try['growth_ratio'].values, remaining_try['sum_cum_s'].values
        )
        total_rev_after_trim_try = float(patch_try['sum_cum_e'].sum())
        # ADDED: revenue-cut check at EVERY candidate (independent of CV)
        if total_rev_before_trim > 0:
            revenue_cut_try = 1.0 - (total_rev_after_trim_try / total_rev_before_trim)
        else:
            revenue_cut_try = 0.0

        # STOP 1: this pct over-cuts revenue — reject it, keep previous acceptable result
        if revenue_cut_try > MAX_REVENUE_CUT_FRACTION:
            capped_by_revenue_limit = True
            if not has_acceptable:
                # Floor itself exceeds the cut limit: keep floor (no lower pct available)
                patch = patch_try
                remaining = remaining_try
                removed = removed_try
                newly_excluded = newly_excluded_try
                n_users_pre_trim = n_users_pre_trim_try
                n_users_post_trim = n_users_post_trim_try
                cv_before = cv_before_try
                cv_after = cv_after_try
                mean_a = mean_a_try
                total_rev_after_trim = total_rev_after_trim_try
                revenue_cut_fraction = revenue_cut_try
                pct_used = pct_used_try
                trim_method = trim_method_try
                flagged = (not np.isnan(cv_after)) and (cv_after > cv_threshold)
                has_acceptable = True
            # else: leave prior acceptable state unchanged
            break

        # Accept this candidate as current best within the revenue-cut limit
        patch = patch_try
        remaining = remaining_try
        removed = removed_try
        newly_excluded = newly_excluded_try
        n_users_pre_trim = n_users_pre_trim_try
        n_users_post_trim = n_users_post_trim_try
        cv_before = cv_before_try
        cv_after = cv_after_try
        mean_a = mean_a_try
        total_rev_after_trim = total_rev_after_trim_try
        revenue_cut_fraction = revenue_cut_try
        pct_used = pct_used_try
        trim_method = trim_method_try
        flagged = (not np.isnan(cv_after)) and (cv_after > cv_threshold)
        has_acceptable = True

        # STOP 2: CV cleared — first pct that works without over-cutting
        if (not np.isnan(cv_after)) and (cv_after <= cv_threshold):
            break
        # STOP 3: else if more candidates remain, loop continues; if last, keep this result

    escalated = bool(pct_used > floor_pct)

    if debug:
        flag_tag = f'  >>> FLAGGED (cv={cv_after:.4f} > {cv_threshold})' if flagged else ''
        esc_tag = f'  winsor={pct_used:.3f}' + (f' (escalated from {floor_pct:.3f})' if escalated else '')
        cut_tag = f'  rev_cut={revenue_cut_fraction:.1%}'
        if capped_by_revenue_limit:
            cut_tag += f'  >>> CAPPED BY REVENUE LIMIT ({MAX_REVENUE_CUT_FRACTION:.0%})'
        print(
            f'  [{population}] {s}->{e}  '
            f'cv {cv_before:.4f}->{cv_after:.4f}  '
            f'removed={len(removed)}/{len(patch)}  '
            f'excl_prior={n_users_excluded_prior:,}  '
            f'pre/post={n_users_pre_trim:,}/{n_users_post_trim:,}  '
            f'newly_excl={len(newly_excluded):,}{esc_tag}{cut_tag}{flag_tag}'
        )

    stats = dict(
        population              = population,
        patch                   = f'{s}->{e}',
        cohort_start            = str(cohort_start),
        cohort_end              = str(cohort_end),
        n_cohort_dates_total    = int(len(patch)),
        n_cohort_dates_kept     = int(len(remaining)),
        n_users_excluded_prior  = n_users_excluded_prior,
        n_users_pre_trim        = n_users_pre_trim,
        n_users_post_trim       = n_users_post_trim,
        n_users_dropped_by_trim = n_users_pre_trim - n_users_post_trim,
        total_rev_before_trim   = total_rev_before_trim,
        total_rev_after_trim    = total_rev_after_trim,
        cv_before               = float(cv_before) if not np.isnan(cv_before) else None,
        cv_after                = float(cv_after)  if not np.isnan(cv_after)  else None,
        mean_after              = float(mean_a)    if not np.isnan(mean_a)    else None,
        flagged                 = bool(flagged),
        removed_dates           = removed,
        trim_method             = trim_method,
        trim_pct                = pct_used,  # CHANGED: actual pct used (may be escalated)
        # ADDED: winsor escalation diagnostics
        floor_pct               = floor_pct,
        pct_used                = pct_used,
        escalated               = escalated,
        n_escalation_steps_tried = n_escalation_steps_tried,
        revenue_cut_fraction    = float(revenue_cut_fraction),
        capped_by_revenue_limit = bool(capped_by_revenue_limit),
    )
    return patch, stats, removed, flagged, newly_excluded


print('Adaptive CV function defined (persistent trim + winsor escalation + rev-cut cap).')
# Out:
# Adaptive CV function defined (persistent trim + winsor escalation + rev-cut cap).

# %%
# ══════════════════════════════════════════════════════════════
# PERSISTENT TRIM CURVE BUILDER (two-pass)
# ══════════════════════════════════════════════════════════════

def build_curve(
    u_base, daily_user_cums, *,
    population, as_of_date, debug=True,
):
    """Build ARPU curve with persistent trim — excluded users carry forward.
    Two-pass: first pass accumulates all exclusions unconditionally,
    second pass builds step ratios using frozen snapshots."""
    as_of_date = pd.to_datetime(as_of_date).normalize()

    cv_rows      = []
    effective    = []
    excluded_uids = set()

    # ── First pass: determine valid patches & accumulate exclusions ──
    for (s, e) in PATCHES:
        patch, stats, removed, flagged, newly_excluded = patch_cv_adaptive(
            u_base, daily_user_cums,
            population=population, s=s, e=e,
            as_of_date=as_of_date,
            excluded_uids=excluded_uids,
            debug=debug,
        )
        excluded_uids |= newly_excluded

        if not stats:
            continue

        min_cohort_dates = globals().get('MIN_COHORT_DATES', 1)
        if stats.get('n_cohort_dates_total', 0) < min_cohort_dates:
            if debug:
                print(f'  [{population}] {s}->{e}  insufficient data '
                      f'({stats["n_cohort_dates_total"]} < {min_cohort_dates}) — skipping')
            continue

        cv_rows.append(stats)
        effective.append({
            's': s, 'e': e,
            'removed_dates': removed,
            'excluded_snapshot': frozenset(excluded_uids),
        })

    if not effective:
        return pd.DataFrame(cv_rows), pd.DataFrame()

    if debug:
        print(f'  Total unique users excluded across all patches: {len(excluded_uids):,}')

    # ── Second pass: build step ratios using frozen snapshots ──
    step_rows = []
    for ep in effective:
        s, e      = ep['s'], ep['e']
        bad_dates = set(ep['removed_dates'])
        excl      = ep['excluded_snapshot']
        start_k   = 2 if s == 1 else (s + 1)

        cohort_end   = (as_of_date - pd.Timedelta(days=e)).date()
        cohort_start = (as_of_date - pd.Timedelta(days=e + (LOOKBACK_COHORTS - 1))).date()

        cohort_users = u_base.loc[
            (u_base['population'] == population) &
            (u_base['cost_date'] >= cohort_start) &
            (u_base['cost_date'] <= cohort_end)
        ][['population', 'cost_date', '__uid__']].copy()

        if bad_dates:
            cohort_users = cohort_users.loc[~cohort_users['cost_date'].isin(bad_dates)].copy()
        if excl:
            cohort_users = cohort_users.loc[~cohort_users['__uid__'].isin(excl)].copy()
        if cohort_users.empty:
            continue

        # CHANGED: unpack new return values (method, pct_used); day-steps still use config floor
        _, caps, _, _ = get_trimmed_cohort_and_caps(population, cohort_users, daily_user_cums, e)
        denom_w = (
            cohort_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                        .nunique().reset_index(name='N_users')
        )

        for k in range(start_k, e + 1):
            sum_prev = sum_cum_at_idx(
                daily_user_cums, cohort_users=cohort_users, idx=k - 2, caps=caps
            ).rename(columns={'sum_cum': 'sum_prev'})
            sum_curr = sum_cum_at_idx(
                daily_user_cums, cohort_users=cohort_users, idx=k - 1, caps=caps
            ).rename(columns={'sum_cum': 'sum_curr'})
            tmp = (
                denom_w
                .merge(sum_prev, on=['population', 'cost_date'])
                .merge(sum_curr, on=['population', 'cost_date'])
            )
            tmp['ARPU_prev']  = tmp['sum_prev'] / tmp['N_users']
            tmp['ARPU_curr']  = tmp['sum_curr'] / tmp['N_users']
            tmp['step_ratio'] = np.where(
                tmp['ARPU_prev'] > 0, tmp['ARPU_curr'] / tmp['ARPU_prev'], np.nan
            )
            mean_step, _, _ = weighted_mean_std_cv(
                tmp['step_ratio'].values, tmp['sum_prev'].values
            )
            step_rows.append({
                'population':      population,
                'day':             int(k),
                'growth_step':     float(mean_step),
                'effective_patch': f'{s}->{e}',
            })

    if not step_rows:
        return pd.DataFrame(cv_rows), pd.DataFrame()

    step_df = pd.DataFrame(step_rows).sort_values('day').reset_index(drop=True)

    # ── Base ARPU from first effective patch ──
    first      = effective[0]
    fs, fe     = first['s'], first['e']
    excl_first = first['excluded_snapshot']
    base_end   = (as_of_date - pd.Timedelta(days=fe)).date()
    base_start = (as_of_date - pd.Timedelta(days=fe + (LOOKBACK_COHORTS - 1))).date()

    base_users = u_base.loc[
        (u_base['population'] == population) &
        (u_base['cost_date'] >= base_start) &
        (u_base['cost_date'] <= base_end)
    ][['population', 'cost_date', '__uid__']].copy()
    bad_first = set(first['removed_dates'])
    if bad_first:
        base_users = base_users.loc[~base_users['cost_date'].isin(bad_first)].copy()
    if excl_first:
        base_users = base_users.loc[~base_users['__uid__'].isin(excl_first)].copy()

    # CHANGED: unpack new return values (method, pct_used); base ARPU still uses config floor
    _, base_caps, _, _ = get_trimmed_cohort_and_caps(population, base_users, daily_user_cums, fe)
    denom_base = (
        base_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                  .nunique().reset_index(name='N_users')
    )
    start_idx = 0 if fs == 1 else (fs - 1)
    sum_day1 = sum_cum_at_idx(
        daily_user_cums, cohort_users=base_users, idx=start_idx, caps=base_caps
    ).rename(columns={'sum_cum': 'sum_day1'})
    base = denom_base.merge(sum_day1, on=['population', 'cost_date'], how='inner')
    pooled_arpu_1 = (
        base['sum_day1'].sum() / base['N_users'].sum()
        if base['N_users'].sum() > 0 else 0.0
    )

    start_day = 1 if fs == 1 else fs
    out_rows  = [{'population': population, 'day': start_day,
                  'ARPU_nominal': float(pooled_arpu_1),
                  'growth_step':  np.nan,
                  'effective_patch': f'{fs}->{fe}'}]
    arpu = float(pooled_arpu_1)
    for _, row in step_df.iterrows():
        g = row['growth_step']
        if not np.isfinite(g):
            continue
        arpu *= float(g)
        out_rows.append({'population': population, 'day': int(row['day']),
                         'ARPU_nominal': float(arpu),
                         'growth_step':  float(g),
                         'effective_patch': row['effective_patch']})

    curve = pd.DataFrame(out_rows).sort_values('day').reset_index(drop=True)
    all_days = pd.DataFrame({'day': range(start_day, 366)})
    curve    = all_days.merge(curve, on='day', how='left')
    curve['population']      = population
    curve['effective_patch'] = curve['effective_patch'].ffill()
    curve['ARPU_nominal']    = curve['ARPU_nominal'].interpolate(
        method='linear', limit_area='inside'
    )
    curve = curve.dropna(subset=['ARPU_nominal']).reset_index(drop=True)
    curve['is_extrapolated'] = False

    return pd.DataFrame(cv_rows), curve


def extrapolate_curve_tail(curve, *, up_to_day=365, tail_days=30, debug=True):
    """Extend curve to up_to_day using geometric mean of last tail_days daily growth steps."""
    if curve.empty:
        return curve

    population    = curve['population'].iloc[0]
    last_real_day = int(curve['day'].max())
    if last_real_day >= up_to_day:
        return curve

    real = curve.loc[~curve['is_extrapolated']].sort_values('day')
    tail = real.tail(tail_days)
    if len(tail) < 2:
        if debug:
            print(f'  [{population}] Not enough tail data ({len(tail)}) to extrapolate.')
        return curve

    arpu_vals = tail['ARPU_nominal'].values
    ratios    = arpu_vals[1:] / arpu_vals[:-1]
    ratios    = ratios[np.isfinite(ratios) & (ratios > 0)]
    if len(ratios) == 0:
        return curve

    avg_daily_growth = float(np.exp(np.mean(np.log(ratios))))

    if debug:
        print(
            f'  [{population}] Extrapolating D{last_real_day + 1}→D{up_to_day}  '
            f'rate={avg_daily_growth:.6f}/day  (geom. mean of last {len(ratios)} daily ratios)'
        )

    last_arpu  = float(curve.loc[curve['day'] == last_real_day, 'ARPU_nominal'].iloc[0])
    last_patch = curve.loc[curve['day'] == last_real_day, 'effective_patch'].iloc[0]
    tag_patch  = f'{last_patch} (extrapolated)'

    new_rows = []
    arpu = last_arpu
    for d in range(last_real_day + 1, up_to_day + 1):
        arpu *= avg_daily_growth
        new_rows.append({
            'population':      population,
            'day':             d,
            'ARPU_nominal':    float(arpu),
            'growth_step':     avg_daily_growth,
            'effective_patch': tag_patch,
            'is_extrapolated': True,
        })

    return pd.concat([curve, pd.DataFrame(new_rows)], ignore_index=True)


def build_all_populations(
    u_base, daily_user_cums, *,
    as_of_date, debug=True,
    extrapolate_tail=False, tail_days=30, extrapolate_up_to=365,
):
    all_cv_rows = []
    all_curves  = []
    for pop in POPULATIONS:
        if debug:
            print(f'\n{"=" * 55}')
            print(f'POPULATION: {pop}')
            print(f'{"=" * 55}')
        cv_df, curve = build_curve(
            u_base, daily_user_cums,
            population=pop, as_of_date=as_of_date, debug=debug,
        )
        if not cv_df.empty:
            all_cv_rows.append(cv_df)
        if not curve.empty and extrapolate_tail:
            curve = extrapolate_curve_tail(
                curve, up_to_day=extrapolate_up_to, tail_days=tail_days, debug=debug,
            )
        if not curve.empty:
            all_curves.append(curve)
    cv_out    = pd.concat(all_cv_rows, ignore_index=True) if all_cv_rows else pd.DataFrame()
    curve_out = pd.concat(all_curves, ignore_index=True) if all_curves else pd.DataFrame()
    return cv_out, curve_out

print('Persistent trim curve builder defined.')
# Out:
# Persistent trim curve builder defined.

# %%
# ══════════════════════════════════════════════════════════════
# ORGANIC SHARE — multi-config cohort progression with scope
# Supports winsor, cohort_trim (with persistent trim), or none.
# Percentiles always computed from depositors only.
#
# If users_df has 'scope' and 'bucket' columns, uses them directly
# (RP: app vs non_app). Otherwise defaults to scope='all' and
# derives bucket from population == ORGANIC_LABEL (LS).
# ══════════════════════════════════════════════════════════════

def organic_share_cohort_progression(
    users_df, revenue_df, *,
    as_of_date,
    goal_horizons=GOAL_HORIZONS,
    checkpoints=CHECKPOINTS,
    lookback_cohorts=None,
    positive_amount_only=True,
    trim_configs,
    persistent_trim=True,
):
    if lookback_cohorts is None:
        lookback_cohorts = LOOKBACK_COHORTS
    as_of_date = pd.to_datetime(as_of_date).normalize()

    has_scope = 'scope' in users_df.columns and 'bucket' in users_df.columns
    cols = ['id', 'cost_date']
    if has_scope:
        cols += ['scope', 'bucket']
    if 'population' in users_df.columns:
        cols.append('population')

    u = users_df[cols].copy()
    u['cost_date'] = pd.to_datetime(u['cost_date'], errors='coerce').dt.date
    u = u.loc[pd.notna(u['cost_date'])].copy()

    if not has_scope:
        u['scope'] = 'all'
        u['bucket'] = np.where(u['population'] == ORGANIC_LABEL, 'organic', 'acquired')

    u = u.drop_duplicates(subset=['id'])

    r = revenue_df[['playerid', 'date', 'amount']].copy()
    r['date'] = pd.to_datetime(r['date'], errors='coerce').dt.date
    r = r.loc[pd.notna(r['date'])].copy()
    if positive_amount_only:
        r = r[r['amount'] > 0]

    rr = r.merge(
        u.rename(columns={'id': '__uid__'}),
        left_on='playerid', right_on='__uid__', how='inner'
    )
    rr['dsi'] = (pd.to_datetime(rr['date']) - pd.to_datetime(rr['cost_date'])).dt.days
    rr = rr.loc[(rr['dsi'] >= 0) & (rr['dsi'] <= (max(checkpoints) - 1))].copy()

    daily_user = (
        rr.groupby(['scope', 'bucket', 'cost_date', '__uid__', 'dsi'], observed=True)['amount']
          .sum().reset_index()
          .sort_values(['scope', 'bucket', 'cost_date', '__uid__', 'dsi'])
    )
    daily_user['cum_amount'] = (
        daily_user.groupby(['scope', 'bucket', 'cost_date', '__uid__'], observed=True)['amount']
                  .cumsum()
    )

    rows = []
    scopes = sorted(u['scope'].unique())

    for horizon in goal_horizons:
        cohort_end   = (as_of_date - pd.Timedelta(days=horizon)).date()
        cohort_start = (as_of_date - pd.Timedelta(days=horizon + (lookback_cohorts - 1))).date()

        elig = u.loc[
            (u['cost_date'] >= cohort_start) &
            (u['cost_date'] <= cohort_end)
        ].copy()

        if elig.empty:
            print(f'[horizon={horizon}] No eligible users — skipping.')
            continue

        eligible_cps = sorted(c for c in checkpoints if c <= horizon)

        for scope in scopes:
            scope_elig = elig.loc[elig['scope'] == scope]
            if scope_elig.empty:
                continue

            scope_du_h = daily_user.merge(
                scope_elig[['scope', 'bucket', 'id', 'cost_date']].rename(columns={'id': '__uid__'}),
                on=['scope', 'bucket', '__uid__', 'cost_date'], how='inner'
            )

            excluded = {
                cfg['label']: set()
                for cfg in trim_configs
                if cfg['method'] == 'cohort_trim' and persistent_trim
            }

            for cp in eligible_cps:
                du_cp = scope_du_h.loc[scope_du_h['dsi'] <= (cp - 1)]

                row = dict(
                    scope          = scope,
                    goal_horizon   = horizon,
                    cohort_start   = cohort_start,
                    cohort_end     = cohort_end,
                    checkpoint_day = cp,
                )

                if du_cp.empty:
                    for cfg in trim_configs:
                        lbl = cfg['label']
                        row.update({
                            f'organic_sum_{lbl}'       : 0.0,
                            f'acquired_sum_{lbl}'      : 0.0,
                            f'total_sum_{lbl}'         : 0.0,
                            f'organic_share_pct_{lbl}' : np.nan,
                            f'users_org_{lbl}'         : 0,
                            f'users_acq_{lbl}'         : 0,
                        })
                    rows.append(row)
                    continue

                cum_cp = (
                    du_cp.groupby(['bucket', 'cost_date', '__uid__'], observed=True)['cum_amount']
                         .max().reset_index(name='cum_cp')
                )
                cum_cp = (
                    scope_elig.rename(columns={'id': '__uid__'})
                              .merge(cum_cp, on=['bucket', 'cost_date', '__uid__'], how='left')
                )
                cum_cp['cum_cp'] = cum_cp['cum_cp'].fillna(0.0)

                print_line = f'  [{scope}] D{cp:>3}:'

                for cfg in trim_configs:
                    method, pct, lbl = cfg['method'], cfg['pct'], cfg['label']

                    if method == 'none' or pct == 0.0:
                        kept = cum_cp.copy()

                    elif method == 'cohort_trim':
                        working = cum_cp.copy()
                        if persistent_trim and excluded.get(lbl):
                            working = working.loc[~working['__uid__'].isin(excluded[lbl])]

                        depositors = working.loc[working['cum_cp'] > 0]
                        if not depositors.empty:
                            thresh_map = (
                                depositors.groupby('bucket', observed=True)['cum_cp']
                                          .quantile(1.0 - pct)
                                          .to_dict()
                            )
                            thresh_series = working['bucket'].map(thresh_map).fillna(np.inf)
                            above_mask = (working['cum_cp'] > 0) & (working['cum_cp'] > thresh_series)
                            if persistent_trim:
                                excluded[lbl] |= set(working.loc[above_mask, '__uid__'].unique())
                            kept = working.loc[~above_mask]
                        else:
                            kept = working

                    elif method == 'winsor':
                        depositors = cum_cp.loc[cum_cp['cum_cp'] > 0]
                        if not depositors.empty:
                            cap_map = (
                                depositors.groupby('bucket', observed=True)['cum_cp']
                                          .quantile(1.0 - pct)
                                          .to_dict()
                            )
                            kept = cum_cp.copy()
                            caps = kept['bucket'].map(cap_map).fillna(np.inf)
                            kept['cum_cp'] = np.minimum(kept['cum_cp'], caps)
                        else:
                            kept = cum_cp.copy()

                    else:
                        raise ValueError(f"Unknown trim method: {method}")

                    sums = kept.groupby('bucket', observed=True)['cum_cp'].sum().to_dict()
                    cnts = kept.groupby('bucket', observed=True)['__uid__'].nunique().to_dict()

                    org_sum = float(sums.get('organic',  0.0))
                    acq_sum = float(sums.get('acquired', 0.0))
                    total   = org_sum + acq_sum
                    share   = (org_sum / total) if total > 0 else np.nan

                    row.update({
                        f'organic_sum_{lbl}'       : org_sum,
                        f'acquired_sum_{lbl}'      : acq_sum,
                        f'total_sum_{lbl}'         : total,
                        f'organic_share_pct_{lbl}' : share,
                        f'users_org_{lbl}'         : int(cnts.get('organic',  0)),
                        f'users_acq_{lbl}'         : int(cnts.get('acquired', 0)),
                    })

                    print_line += (f'  [{lbl}] org={org_sum:>10,.0f} '
                                   f'acq={acq_sum:>10,.0f} share={share:.1%}')

                print(print_line)
                rows.append(row)

    if not rows:
        return pd.DataFrame()
    df = pd.DataFrame(rows).sort_values(['scope', 'goal_horizon', 'checkpoint_day']).reset_index(drop=True)
    id_cols = ['scope', 'goal_horizon', 'cohort_start', 'cohort_end', 'checkpoint_day']
    metric_cols = []
    for cfg in trim_configs:
        lbl = cfg['label']
        metric_cols += [
            f'organic_sum_{lbl}', f'acquired_sum_{lbl}', f'total_sum_{lbl}',
            f'organic_share_pct_{lbl}', f'users_org_{lbl}', f'users_acq_{lbl}',
        ]
    return df[id_cols + metric_cols]


print('Organic share function defined.')
# Out:
# Organic share function defined.

# %%
# ══════════════════════════════════════════════════════════════
# PART 4 helpers — Goal construction + brand pipeline
# Per-population: adjusted = (ARPU_day / ARPU_horizon) × (1 − organic_share_at_horizon)
# Blended:        adjusted = raw_goal_ratio (no organic adjustment)
# ──
# Organic share rule: for every day inside a horizon, use the share measured AT
# the horizon endpoint (not the share at the day's nearest checkpoint).
# RP: pin lookup to min(horizon, ORGANIC_SHARE_CAP_HORIZON) when cap is set.
# LS: no cap (cap is None).
# ══════════════════════════════════════════════════════════════

def build_goals(curve_df, organic_df, populations, goal_horizons=None,
                organic_share_cap_horizon=None):
    if goal_horizons is None:
        goal_horizons = GOAL_HORIZONS

    has_scope = 'scope' in organic_df.columns
    available_scopes = set(organic_df['scope'].unique()) if has_scope else {'all'}

    org_lookup = {}
    scope_col = 'scope' if has_scope else None
    endpoint = organic_df.loc[organic_df['checkpoint_day'] == organic_df['goal_horizon']]
    if scope_col:
        for scope, grp in endpoint.groupby(scope_col):
            org_lookup[scope] = grp.set_index('goal_horizon')['organic_share_pct'].to_dict()
    else:
        org_lookup['all'] = endpoint.set_index('goal_horizon')['organic_share_pct'].to_dict()

    def pop_to_scope(pop):
        if pop == 'App' and 'app' in available_scopes:
            return 'app'
        if 'non_app' in available_scopes:
            return 'non_app'
        return next(iter(available_scopes))

    rows = []
    all_pops = list(populations) + ['Blended']

    for pop in all_pops:
        is_blended = (pop == 'Blended')

        pop_curve = curve_df.loc[curve_df['population'] == pop].copy()
        if pop_curve.empty:
            continue
        pop_curve = pop_curve.drop_duplicates(subset='day').set_index('day')

        for horizon in goal_horizons:
            if horizon not in pop_curve.index:
                print(f'[{pop}] Day {horizon} missing from curve — skipping horizon.')
                continue
            arpu_horizon = pop_curve.loc[horizon, 'ARPU_nominal']
            if not np.isfinite(arpu_horizon) or arpu_horizon == 0:
                continue

            if is_blended:
                org_share = 0.0
            else:
                scope = pop_to_scope(pop)
                if organic_share_cap_horizon is not None:
                    lookup_horizon = min(horizon, organic_share_cap_horizon)
                else:
                    lookup_horizon = horizon
                org_share = org_lookup.get(scope, {}).get(lookup_horizon, np.nan)

            for day in range(1, horizon + 1):
                if day not in pop_curve.index:
                    continue
                arpu_day  = pop_curve.loc[day, 'ARPU_nominal']
                eff_patch = pop_curve.loc[day, 'effective_patch'] if 'effective_patch' in pop_curve.columns else ''
                is_extrap = bool(pop_curve.loc[day, 'is_extrapolated']) if 'is_extrapolated' in pop_curve.columns else False
                raw_goal  = arpu_day / arpu_horizon

                if np.isfinite(org_share):
                    adj_goal = raw_goal * (1 - org_share)
                else:
                    adj_goal = np.nan

                rows.append(dict(
                    population           = pop,
                    goal_horizon         = horizon,
                    day                  = day,
                    ARPU_nominal         = float(arpu_day),
                    ARPU_at_horizon      = float(arpu_horizon),
                    raw_goal_ratio       = float(raw_goal),
                    organic_share        = float(org_share) if np.isfinite(org_share) else None,
                    adjusted_goal_ratio  = float(adj_goal)  if np.isfinite(adj_goal)  else None,
                    effective_patch      = eff_patch,
                    is_extrapolated      = is_extrap,
                ))

    return pd.DataFrame(rows)


def _banner(title: str):
    print('\n' + '─' * 60)
    print(title)
    print('─' * 60)


def monitor_show_users(brand, users_df):
    """After SQL load: population counts + date span."""
    _banner(f'[{brand}] MONITOR · DATA LOAD')
    print(f'users_df rows:   {len(users_df):,}')
    print('population counts:')
    print(users_df['population'].value_counts().to_string())
    cd = pd.to_datetime(users_df['cost_date'], errors='coerce')
    print(f"cost_date span: {cd.min().date()} → {cd.max().date()}")
    if 'scope' in users_df.columns:
        print('\nscope × bucket:')
        print(users_df.groupby(['scope', 'bucket'], observed=True).size().to_string())


def monitor_show_cv_curve(brand, stage, cv_df, curve_df, populations):
    """After ARPU curve build: CV table + milestone ARPU."""
    _banner(f'[{brand}] MONITOR · {stage}')
    if cv_df is not None and not cv_df.empty:
        display_cols = [
            'population', 'patch', 'n_dates_before', 'n_dates_after',
            'cv_before', 'cv_after', 'removed_dates',
            'total_rev_before_trim', 'total_rev_after_trim',
            'flagged', 'trim_method',
            # ADDED: winsor escalation diagnostics
            'floor_pct', 'pct_used', 'escalated',
            'capped_by_revenue_limit', 'revenue_cut_fraction',
        ]
        display_cols = [c for c in display_cols if c in cv_df.columns]
        print('CV summary:')
        print(cv_df[display_cols].to_string(index=False))
        if 'flagged' in cv_df.columns:
            flagged = cv_df.loc[cv_df['flagged'] == True]
            if not flagged.empty:
                print('\n>>> FLAGGED PATCHES:')
                for _, r in flagged.iterrows():
                    patch = r['patch'] if 'patch' in r.index else '?'
                    print(f"    {r.get('population', '?')} / {patch}  CV={r.get('cv_after', float('nan')):.4f}")
            else:
                print('\nNo flagged patches in this stage.')
    else:
        print('CV summary: (empty)')

    if curve_df is not None and not curve_df.empty:
        milestones = list(MONITOR_PREVIEW_DAYS)
        for pop in populations:
            sub = curve_df.loc[curve_df['population'] == pop]
            if sub.empty:
                continue
            cols = [c for c in ['day', 'ARPU_nominal', 'effective_patch', 'is_extrapolated'] if c in sub.columns]
            ms = sub.loc[sub['day'].isin(milestones)][cols]
            print(f'\nARPU curve milestones — {pop}  (n_days={sub["day"].nunique()})')
            print(ms.to_string(index=False))
            if 'is_extrapolated' in sub.columns and sub['is_extrapolated'].any():
                n_ex = int(sub['is_extrapolated'].sum())
                last_real = int(sub.loc[~sub['is_extrapolated'], 'day'].max()) if (~sub['is_extrapolated']).any() else None
                print(f'  extrapolated days: {n_ex:,}  last real day: {last_real}')
    else:
        print('ARPU curve: (empty)')


def monitor_show_organic(brand, organic_df):
    """After organic share computation."""
    _banner(f'[{brand}] MONITOR · ORGANIC SHARE')
    if organic_df is None or organic_df.empty:
        print('organic_df: (empty)')
        return
    print(f'rows: {len(organic_df):,}')
    # endpoint only (checkpoint_day == goal_horizon) — what goals actually use
    if 'checkpoint_day' in organic_df.columns and 'goal_horizon' in organic_df.columns:
        ep = organic_df.loc[organic_df['checkpoint_day'] == organic_df['goal_horizon']].copy()
        cols = [c for c in ['scope', 'goal_horizon', 'organic_share_pct', 'users_org', 'users_acq'] if c in ep.columns]
        for scope in ep['scope'].unique() if 'scope' in ep.columns else [None]:
            sub = ep if scope is None else ep.loc[ep['scope'] == scope]
            title = f'endpoint shares — scope={scope}' if scope is not None else 'endpoint shares'
            print(f'\n{title}:')
            print(sub[cols].to_string(index=False))
    else:
        print(organic_df.head(20).to_string(index=False))


def monitor_show_goals(brand, goals_df, populations):
    """After goal construction: sample horizons × days."""
    _banner(f'[{brand}] MONITOR · GOALS')
    if goals_df is None or goals_df.empty:
        print('goals_df: (empty)')
        return
    print(f'total goal rows: {len(goals_df):,}')
    print('counts by population:')
    print(goals_df.groupby('population', observed=True).size().to_string())

    preview_days = list(MONITOR_PREVIEW_DAYS)
    preview_horizons = list(MONITOR_PREVIEW_HORIZONS)
    preview_cols = [
        c for c in [
            'population', 'goal_horizon', 'day',
            'raw_goal_ratio', 'organic_share', 'adjusted_goal_ratio',
            'ARPU_nominal', 'is_extrapolated',
        ] if c in goals_df.columns
    ]
    for pop in list(populations) + ['Blended']:
        for horizon in preview_horizons:
            sub = goals_df.loc[
                (goals_df['population'] == pop) &
                (goals_df['goal_horizon'] == horizon) &
                (goals_df['day'].isin(preview_days))
            ]
            if sub.empty:
                continue
            print(f'\n── {pop} │ horizon D{horizon} ──')
            print(sub[preview_cols].to_string(index=False))


def run_brand_pipeline(cfg, users_df, revenue_df, as_of_date=AS_OF_DATE, monitor=None):
    """Parts 1-4 for one brand. Returns dict of frames with brand column.

    monitor=True  -> print intermediate tables after every part (for Colab monitoring)
    monitor=False -> banners only
    monitor=None  -> use global MONITOR_STEPS
    """
    global POPULATIONS  # reassigned briefly for Blended pass; must be declared before first use

    if monitor is None:
        monitor = bool(globals().get('MONITOR_STEPS', True))

    apply_brand_globals(cfg)
    brand = cfg['brand']

    if monitor:
        monitor_show_users(brand, users_df)

    # ── PART 1 — per-population ARPU curves ──
    _banner(f'[{brand}] PART 1/4 — per-population ARPU curves')
    print(f'[{brand}] Building base cums + adaptive CV patches (debug lines below)...')
    u_pop, daily_pop = build_user_revenue_cums(
        users_df.loc[users_df['population'].isin(POPULATIONS)].copy(),
        revenue_df,
        max_day=365,
    )
    print(f'[{brand}] base users in ARPU pops: {len(u_pop):,}  daily_user rows: {len(daily_pop):,}')

    cv_pop_df, curve_pop_df = build_all_populations(
        u_pop, daily_pop,
        as_of_date=as_of_date,
        extrapolate_tail=EXTRAPOLATE_TAIL,
        tail_days=EXTRAPOLATION_TAIL_DAYS,
        extrapolate_up_to=365,
        debug=True,
    )
    if monitor:
        monitor_show_cv_curve(brand, 'PART 1 done — per-pop CV + curve', cv_pop_df, curve_pop_df, POPULATIONS)

    # ── PART 2 — Blended ──
    _banner(f'[{brand}] PART 2/4 — Blended ARPU curve')
    print(f'[{brand}] Building BLENDED...')
    users_blend = users_df.copy()
    users_blend['population'] = 'Blended'
    u_blend, daily_blend = build_user_revenue_cums(
        users_blend, revenue_df, max_day=365
    )
    print(f'[{brand}] blended users: {len(u_blend):,}')
    # Temporarily set POPULATIONS so build_all_populations iterates Blended only
    _BLENDED_POPS_BACKUP = list(POPULATIONS)
    POPULATIONS = ['Blended']
    try:
        cv_blend_df, curve_blend_df = build_all_populations(
            u_blend, daily_blend,
            as_of_date=as_of_date,
            extrapolate_tail=EXTRAPOLATE_TAIL,
            tail_days=EXTRAPOLATION_TAIL_DAYS,
            extrapolate_up_to=365,
            debug=True,
        )
    finally:
        POPULATIONS = _BLENDED_POPS_BACKUP

    if monitor:
        monitor_show_cv_curve(brand, 'PART 2 done — Blended CV + curve', cv_blend_df, curve_blend_df, ['Blended'])

    cv_df    = pd.concat([cv_pop_df,    cv_blend_df],    ignore_index=True)
    curve_df = pd.concat([curve_pop_df, curve_blend_df], ignore_index=True)

    # ── PART 3 — organic share ──
    _banner(f'[{brand}] PART 3/4 — organic share')
    org_label = f'{ORGANIC_TRIM_METHOD}_{round(ORGANIC_TRIM_PCT * 100):g}pct'
    org_config = [{'method': ORGANIC_TRIM_METHOD, 'pct': ORGANIC_TRIM_PCT, 'label': org_label}]
    print(f'[{brand}] Computing organic share [{org_label}] for horizons {GOAL_HORIZONS}...')
    organic_full = organic_share_cohort_progression(
        users_df, revenue_df,
        as_of_date=as_of_date,
        goal_horizons=GOAL_HORIZONS,
        checkpoints=CHECKPOINTS,
        lookback_cohorts=LOOKBACK_COHORTS,
        positive_amount_only=True,
        trim_configs=org_config,
        persistent_trim=True,
    )
    organic_df = organic_full[['scope', 'goal_horizon', 'cohort_start', 'cohort_end',
                               'checkpoint_day',
                               f'organic_share_pct_{org_label}',
                               f'users_org_{org_label}',
                               f'users_acq_{org_label}']].copy()
    organic_df = organic_df.rename(columns={
        f'organic_share_pct_{org_label}': 'organic_share_pct',
        f'users_org_{org_label}': 'users_org',
        f'users_acq_{org_label}': 'users_acq',
    })
    if monitor:
        monitor_show_organic(brand, organic_df)
    else:
        print(f'[{brand}] organic rows: {len(organic_df):,}')

    # ── PART 4 — goals ──
    _banner(f'[{brand}] PART 4/4 — goal construction')
    goals_df = build_goals(
        curve_df, organic_df, POPULATIONS,
        goal_horizons=GOAL_HORIZONS,
        organic_share_cap_horizon=ORGANIC_SHARE_CAP_HORIZON,
    )
    if monitor:
        monitor_show_goals(brand, goals_df, POPULATIONS)
    else:
        print(f'[{brand}] goals rows: {len(goals_df):,}')

    # stamp brand
    for df in (cv_df, curve_df, organic_df, goals_df):
        if not df.empty:
            df.insert(0, 'brand', brand)

    print(f'\n[{brand}] COMPLETE — goals {len(goals_df):,} | curve {len(curve_df):,} | organic {len(organic_df):,} | cv {len(cv_df):,}')
    return {
        'cv': cv_df,
        'curve': curve_df,
        'organic': organic_df,
        'goals': goals_df,
        'populations': list(cfg['populations']),
    }

print('run_brand_pipeline + monitors ready.')
print('Set MONITOR_STEPS=True in config cell to print intermediate tables after each part.')
# Out:
# run_brand_pipeline + monitors ready.
# Set MONITOR_STEPS=True in config cell to print intermediate tables after each part.

# %%
# ══════════════════════════════════════════════════════════════
# LS APP + WINSOR WIRING (this Colab only)
# ══════════════════════════════════════════════════════════════
# 1) Wire pct_used from the CV pass into curve day-steps (v2 archive
#    still builds the curve on the config-floor winsor).
# 2) LS App: keep winsor at 0% — do not climb the escalation ladder.
# 3) native_early_rp_tail: keep LS App native through last measured day,
#    then RP App day-to-day growth.

_orig_patch_cv_adaptive = patch_cv_adaptive
_orig_get_trimmed = get_trimmed_cohort_and_caps
_pct_used_by_pop_e = {}


def patch_cv_adaptive(*args, **kwargs):
    global WINSOR_ESCALATION_STEPS
    population = kwargs.get('population')
    saved_steps = list(WINSOR_ESCALATION_STEPS)
    if ACTIVE_BRAND == 'lonestar' and population == 'App':
        WINSOR_ESCALATION_STEPS = [0.0]
    try:
        patch, stats, removed, flagged, newly = _orig_patch_cv_adaptive(*args, **kwargs)
    finally:
        WINSOR_ESCALATION_STEPS = saved_steps
    if stats:
        pop = stats.get('population') or population
        e = kwargs.get('e')
        if e is None and stats.get('patch'):
            try:
                e = int(str(stats['patch']).split('->')[1])
            except Exception:
                e = None
        if pop is not None and e is not None and 'pct_used' in stats:
            _pct_used_by_pop_e[(pop, int(e))] = stats['pct_used']
    return patch, stats, removed, flagged, newly


def get_trimmed_cohort_and_caps(population, cohort_users, daily_user_cums, e, pct_override=None):
    if pct_override is None:
        pct_override = _pct_used_by_pop_e.get((population, int(e)))
    return _orig_get_trimmed(
        population, cohort_users, daily_user_cums, e, pct_override=pct_override
    )


def _curve_for_pop(curve_df, population):
    out = curve_df.loc[curve_df['population'] == population].copy()
    if out.empty:
        return out
    return out.drop_duplicates(subset='day').sort_values('day').reset_index(drop=True)


def last_measured_day(native):
    """Last life day from measured patches, not LS tail extrapolation."""
    if native.empty:
        raise RuntimeError('Native LS App curve is empty.')
    if 'is_extrapolated' in native.columns:
        flag = native['is_extrapolated'].fillna(False).astype(bool)
        real = native.loc[~flag]
        if not real.empty:
            return int(real['day'].max())
    return int(native['day'].max())


def native_early_rp_tail_curve(native_curve, rp_app_curve, *, target_pop='App', max_day=None):
    """Keep native LS App through last measured day; dress RP App growth after that.

    After splice day S:
      ARPU(d) = ARPU(d-1) × (ARPU_RP(d) / ARPU_RP(d-1))
    """
    native = _curve_for_pop(native_curve, target_pop)
    rp = _curve_for_pop(rp_app_curve, 'App')
    if native.empty:
        raise RuntimeError('native_early_rp_tail needs a native LS App curve.')
    if rp.empty:
        raise RuntimeError('native_early_rp_tail needs an RP App curve.')

    horizon = int(max_day) if max_day is not None else max(GOAL_HORIZONS)
    splice = last_measured_day(native)
    native = native.sort_values('day')
    rp = rp.drop_duplicates(subset='day').set_index('day')

    keep = native.loc[native['day'] <= splice].copy()
    keep['population'] = target_pop
    keep['is_extrapolated'] = False

    last_arpu = float(keep.loc[keep['day'] == splice, 'ARPU_nominal'].iloc[0])
    extra_rows = []
    for day in range(splice + 1, horizon + 1):
        if day not in rp.index or (day - 1) not in rp.index:
            continue
        rp_prev = float(rp.loc[day - 1, 'ARPU_nominal'])
        rp_now = float(rp.loc[day, 'ARPU_nominal'])
        growth = 1.0 if (not np.isfinite(rp_prev) or rp_prev <= 0) else rp_now / rp_prev
        last_arpu = last_arpu * growth
        row = rp.loc[day].to_dict()
        row['day'] = day
        row['population'] = target_pop
        row['ARPU_nominal'] = last_arpu
        row['is_extrapolated'] = True
        extra_rows.append(row)

    out = pd.concat([keep, pd.DataFrame(extra_rows)], ignore_index=True)
    out = out.sort_values('day').drop_duplicates(subset='day').reset_index(drop=True)
    out['brand'] = 'lonestar'
    out['population'] = target_pop
    end_day = int(out['day'].max())
    print(
        f'native_early_rp_tail: splice after day {splice}  '
        f'ARPU({splice})=${float(keep.loc[keep["day"] == splice, "ARPU_nominal"].iloc[0]):.4f}  '
        f'ARPU({end_day})=${float(out.loc[out["day"] == end_day, "ARPU_nominal"].iloc[0]):.2f}'
    )
    return out, splice

print('LS App helpers ready: pct_used wired, App winsor locked at 0%, native_early_rp_tail defined.')
# Out:
# LS App helpers ready: pct_used wired, App winsor locked at 0%, native_early_rp_tail defined.

# %%
# ══════════════════════════════════════════════════════════════
# RUN — RP + LS winsor_esc, then LS App native_early_rp_tail
# ══════════════════════════════════════════════════════════════
import copy

brand_results = {}
_pct_used_by_pop_e.clear()

print('\n[realprize] capped winsor_esc (all pops)')
rp_cfg = copy.deepcopy(BRAND_CONFIGS['realprize'])
rp_users, rp_rev = load_brand_tables(rp_cfg, as_of_date=AS_OF_DATE)
rp_res = run_brand_pipeline(rp_cfg, rp_users, rp_rev, as_of_date=AS_OF_DATE)
brand_results['realprize'] = rp_res

print('\n[lonestar] capped winsor_esc Web + Affiliate + Blended (no App)')
_pct_used_by_pop_e.clear()
ls_cfg = copy.deepcopy(BRAND_CONFIGS['lonestar'])
ls_users, ls_rev = load_brand_tables(ls_cfg, as_of_date=AS_OF_DATE)
ls_core_cfg = copy.deepcopy(ls_cfg)
ls_core_cfg['populations'] = ['Web', 'Affiliate']
ls_core = run_brand_pipeline(ls_core_cfg, ls_users, ls_rev, as_of_date=AS_OF_DATE)
brand_results['lonestar'] = ls_core

print('\n[lonestar/App] native measured patches (winsor 0%), then RP App tail')
_pct_used_by_pop_e.clear()
ls_app_cfg = copy.deepcopy(ls_cfg)
ls_app_cfg['populations'] = ['App']
ls_app_native = run_brand_pipeline(ls_app_cfg, ls_users, ls_rev, as_of_date=AS_OF_DATE)

spliced, splice_day = native_early_rp_tail_curve(
    ls_app_native['curve'],
    rp_res['curve'],
    max_day=max(GOAL_HORIZONS),
)
apply_brand_globals(ls_cfg)
app_goals = build_goals(
    spliced,
    ls_core['organic'],
    ['App'],
    goal_horizons=GOAL_HORIZONS,
    organic_share_cap_horizon=None,
)
if 'brand' not in app_goals.columns:
    app_goals.insert(0, 'brand', 'lonestar')
else:
    app_goals['brand'] = 'lonestar'
# Provisional: no App organic haircut until App has enough horizon history.
app_goals['organic_share'] = 0.0
app_goals['adjusted_goal_ratio'] = app_goals['raw_goal_ratio']
print(f'[lonestar/App] splice_day={splice_day}  goals={len(app_goals):,}  organic=0 (off)')

cv_df = pd.concat(
    [rp_res['cv'], ls_core['cv'], ls_app_native['cv']],
    ignore_index=True,
)
curve_df = pd.concat(
    [rp_res['curve'], ls_core['curve'], spliced],
    ignore_index=True,
)
organic_df = pd.concat([rp_res['organic'], ls_core['organic']], ignore_index=True)
goals_detail_df = pd.concat(
    [rp_res['goals'], ls_core['goals'], app_goals],
    ignore_index=True,
)

MAIN_GOAL_COLS = [
    'brand', 'population', 'goal_horizon', 'day',
    'raw_goal_ratio', 'organic_share', 'adjusted_goal_ratio',
]
goals_df = (
    goals_detail_df[MAIN_GOAL_COLS].copy()
    if not goals_detail_df.empty
    else pd.DataFrame(columns=MAIN_GOAL_COLS)
)

print('\n' + '=' * 60)
print('UNIFIED RUN COMPLETE — v2 winsor_esc + LS App native_early_rp_tail')
print(f'  as_of_date     = {AS_OF_DATE.date()}')
print(f'  brands         = {RUN_BRANDS}')
print(f'  LS App splice  = day {splice_day}')
print(f'  cv rows        = {len(cv_df):,}')
print(f'  curve rows     = {len(curve_df):,}')
print(f'  organic rows   = {len(organic_df):,}')
print(f'  goals (main)   = {len(goals_df):,}')
print(f'  goals (detail) = {len(goals_detail_df):,}')
print('=' * 60)

if not goals_df.empty:
    print('\nRow counts by brand × population:')
    print(
        goals_df.groupby(['brand', 'population'], observed=True)
                .size().rename('n_rows').reset_index()
                .to_string(index=False)
    )
# Out:
# [realprize] capped winsor_esc (all pops)
# [realprize] SQL floor date: 2025-06-24  (AS_OF_DATE = 2026-08-03)
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# [realprize] users_df:   971,875 rows
# [realprize] revenue_df: 1,810,415 rows
# population
# App          304186
# Affiliate    262394
# Organic      193448
# Web          128613
# PPC           83234
#
# ============================================================
# BRAND: realprize
#   populations = ['Web', 'App', 'Affiliate']
#   CV threshold = 0.15  good_enough = 0.1
#   min_cohort_dates = 1
#   extrapolate_tail = False
#   organic_share_cap_horizon = 120
# ============================================================
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · DATA LOAD
# ────────────────────────────────────────────────────────────
# users_df rows:   971,875
# population counts:
# population
# App          304186
# Affiliate    262394
# Organic      193448
# Web          128613
# PPC           83234
# cost_date span: 2025-06-24 → 2026-08-18
#
# scope × bucket:
# scope    bucket
# app      acquired    248642
#          organic      55544
# non_app  acquired    474241
#          organic     193448
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 1/4 — per-population ARPU curves
# ────────────────────────────────────────────────────────────
# [realprize] Building base cums + adaptive CV patches (debug lines below)...
# [realprize] base users in ARPU pops: 695,193  daily_user rows: 419,689
#
# =======================================================
# POPULATION: Web
# =======================================================
#   [Web] 1->7  cv 0.3590->0.2446  removed=5/35  excl_prior=0  pre/post=6,241/6,241  newly_excl=0  winsor=0.010  rev_cut=10.6%  >>> CAPPED BY REVENUE LIMIT (15%)  >>> FLAGGED (cv=0.2446 > 0.15)
#   [Web] 7->14  cv 0.2038->0.1368  removed=5/35  excl_prior=0  pre/post=6,565/6,565  newly_excl=0  winsor=0.020 (escalated from 0.010)  rev_cut=11.3%
#   [Web] 14->30  cv 0.4930->0.1943  removed=5/35  excl_prior=0  pre/post=5,061/5,061  newly_excl=0  winsor=0.020 (escalated from 0.010)  rev_cut=11.2%  >>> CAPPED BY REVENUE LIMIT (15%)  >>> FLAGGED (cv=0.1943 > 0.15)
#   [Web] 30->60  cv 0.2716->0.1935  removed=5/35  excl_prior=0  pre/post=1,277/1,277  newly_excl=0  winsor=0.050 (escalated from 0.010)  rev_cut=12.5%  >>> FLAGGED (cv=0.1935 > 0.15)
#   [Web] 60->90  cv 0.3931->0.1254  removed=5/35  excl_prior=0  pre/post=497/497  newly_excl=0  winsor=0.010  rev_cut=0.9%
#   [Web] 90->120  cv 0.1588->0.1251  removed=5/35  excl_prior=0  pre/post=2,295/2,295  newly_excl=0  winsor=0.010  rev_cut=3.9%
#   [Web] 120->150  cv 0.1957->0.0878  removed=3/35  excl_prior=0  pre/post=1,780/1,780  newly_excl=0  winsor=0.010  rev_cut=2.7%
#   [Web] 150->180  cv 0.0878->0.0878  removed=0/35  excl_prior=0  pre/post=3,337/3,337  newly_excl=0  winsor=0.010  rev_cut=6.4%
#   [Web] 180->270  cv 0.2329->0.1111  removed=5/35  excl_prior=0  pre/post=15,743/15,743  newly_excl=0  winsor=0.010  rev_cut=14.1%
#   [Web] 270->365  cv 0.3441->0.1075  removed=5/35  excl_prior=0  pre/post=21,064/21,064  newly_excl=0  winsor=0.010  rev_cut=15.2%  >>> CAPPED BY REVENUE LIMIT (15%)
#   Total unique users excluded across all patches: 0
#
# =======================================================
# POPULATION: App
# =======================================================
#   [App] 1->7  cv 0.2702->0.1506  removed=5/35  excl_prior=0  pre/post=31,002/31,002  newly_excl=0  winsor=0.005 (escalated from 0.000)  rev_cut=14.5%  >>> CAPPED BY REVENUE LIMIT (15%)  >>> FLAGGED (cv=0.1506 > 0.15)
#   [App] 7->14  cv 0.1700->0.1116  removed=5/35  excl_prior=0  pre/post=32,104/32,104  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 14->30  cv 0.2551->0.0937  removed=4/35  excl_prior=0  pre/post=33,327/33,327  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 30->60  cv 0.1638->0.1176  removed=5/35  excl_prior=0  pre/post=29,595/29,595  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 60->90  cv 0.2425->0.1324  removed=5/35  excl_prior=0  pre/post=21,618/21,618  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 90->120  cv 0.1404->0.0795  removed=3/35  excl_prior=0  pre/post=19,076/19,076  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 120->150  cv 0.0523->0.0523  removed=0/35  excl_prior=0  pre/post=13,650/13,650  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 150->180  cv 0.0727->0.0727  removed=0/35  excl_prior=0  pre/post=19,839/19,839  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 180->270  cv 0.3084->0.1093  removed=5/35  excl_prior=0  pre/post=13,298/13,298  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [App] 270->365  cv 0.2065->0.0859  removed=2/35  excl_prior=0  pre/post=24,384/24,384  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   Total unique users excluded across all patches: 0
#
# =======================================================
# POPULATION: Affiliate
# =======================================================
#   [Affiliate] 1->7  cv 0.4255->0.1414  removed=5/35  excl_prior=0  pre/post=15,067/15,067  newly_excl=0  winsor=0.010  rev_cut=25.3%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 7->14  cv 0.1114->0.0902  removed=2/35  excl_prior=0  pre/post=15,218/15,218  newly_excl=0  winsor=0.010  rev_cut=35.3%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 14->30  cv 0.1664->0.0945  removed=5/35  excl_prior=0  pre/post=15,260/15,260  newly_excl=0  winsor=0.010  rev_cut=32.0%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 30->60  cv 0.1236->0.0997  removed=3/35  excl_prior=0  pre/post=9,833/9,833  newly_excl=0  winsor=0.010  rev_cut=49.1%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 60->90  cv 0.0760->0.0760  removed=0/35  excl_prior=0  pre/post=11,745/11,745  newly_excl=0  winsor=0.010  rev_cut=45.6%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 90->120  cv 0.0758->0.0758  removed=0/35  excl_prior=0  pre/post=18,358/18,358  newly_excl=0  winsor=0.010  rev_cut=43.3%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 120->150  cv 0.0961->0.0961  removed=0/35  excl_prior=0  pre/post=19,097/19,097  newly_excl=0  winsor=0.010  rev_cut=31.7%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 150->180  cv 0.0529->0.0529  removed=0/35  excl_prior=0  pre/post=24,238/24,238  newly_excl=0  winsor=0.010  rev_cut=40.1%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 180->270  cv 0.0678->0.0678  removed=0/35  excl_prior=0  pre/post=23,385/23,385  newly_excl=0  winsor=0.010  rev_cut=43.8%  >>> CAPPED BY REVENUE LIMIT (15%)
#   [Affiliate] 270->365  cv 0.0861->0.0861  removed=0/35  excl_prior=0  pre/post=39,709/39,709  newly_excl=0  winsor=0.010  rev_cut=37.0%  >>> CAPPED BY REVENUE LIMIT (15%)
#   Total unique users excluded across all patches: 0
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · PART 1 done — per-pop CV + curve
# ────────────────────────────────────────────────────────────
# CV summary:
# population    patch  cv_before  cv_after                                                removed_dates  total_rev_before_trim  total_rev_after_trim  flagged trim_method  floor_pct  pct_used  escalated  capped_by_revenue_limit  revenue_cut_fraction
#        Web     1->7   0.359043  0.244573 [2026-07-26, 2026-07-07, 2026-07-23, 2026-07-15, 2026-06-26]               66824.43          5.976461e+04     True      winsor       0.01     0.010      False                     True              0.105647
#        Web    7->14   0.203850  0.136769 [2026-06-30, 2026-07-03, 2026-06-25, 2026-07-11, 2026-06-19]               60337.28          5.353716e+04    False      winsor       0.01     0.020       True                    False              0.112702
#        Web   14->30   0.493037  0.194259 [2026-06-30, 2026-06-15, 2026-06-04, 2026-07-03, 2026-06-18]               54085.50          4.802475e+04     True      winsor       0.01     0.020       True                     True              0.112059
#        Web   30->60   0.271584  0.193513 [2026-05-12, 2026-05-31, 2026-05-26, 2026-05-02, 2026-05-22]               18320.95          1.603556e+04     True      winsor       0.01     0.050       True                    False              0.124742
#        Web   60->90   0.393106  0.125433 [2026-04-21, 2026-04-02, 2026-04-19, 2026-04-04, 2026-04-03]                3463.58          3.432043e+03    False      winsor       0.01     0.010      False                    False              0.009105
#        Web  90->120   0.158812  0.125078 [2026-03-31, 2026-03-13, 2026-03-04, 2026-03-08, 2026-03-20]               14135.91          1.357779e+04    False      winsor       0.01     0.010      False                    False              0.039482
#        Web 120->150   0.195702  0.087775                         [2026-02-26, 2026-02-01, 2026-02-12]               23593.86          2.294938e+04    False      winsor       0.01     0.010      False                    False              0.027315
#        Web 150->180   0.087759  0.087759                                                           []               66798.23          6.251976e+04    False      winsor       0.01     0.010      False                    False              0.064051
#        Web 180->270   0.232851  0.111117 [2025-10-05, 2025-10-11, 2025-10-14, 2025-10-26, 2025-10-12]              222543.68          1.910678e+05    False      winsor       0.01     0.010      False                    False              0.141437
#        Web 270->365   0.344060  0.107542 [2025-07-23, 2025-07-28, 2025-07-30, 2025-07-18, 2025-07-08]              327596.72          2.777224e+05    False      winsor       0.01     0.010      False                     True              0.152243
#        App     1->7   0.270180  0.150555 [2026-07-08, 2026-07-13, 2026-06-27, 2026-06-30, 2026-07-24]              411808.73          3.522142e+05     True      winsor       0.00     0.005       True                     True              0.144714
#        App    7->14   0.170033  0.111584 [2026-07-14, 2026-06-30, 2026-07-19, 2026-06-27, 2026-06-19]              551877.89          5.518779e+05    False      winsor       0.00     0.000      False                    False              0.000000
#        App   14->30   0.255102  0.093723             [2026-06-24, 2026-06-04, 2026-06-13, 2026-06-27]              787255.22          7.872552e+05    False      winsor       0.00     0.000      False                    False              0.000000
#        App   30->60   0.163753  0.117578 [2026-05-21, 2026-05-05, 2026-05-07, 2026-05-22, 2026-05-14]             1106648.92          1.106649e+06    False      winsor       0.00     0.000      False                    False              0.000000
#        App   60->90   0.242505  0.132429 [2026-05-03, 2026-04-28, 2026-05-02, 2026-05-04, 2026-04-26]             1304184.93          1.304185e+06    False      winsor       0.00     0.000      False                    False              0.000000
#        App  90->120   0.140358  0.079481                         [2026-03-13, 2026-03-11, 2026-03-21]             1192681.77          1.192682e+06    False      winsor       0.00     0.000      False                    False              0.000000
#        App 120->150   0.052292  0.052292                                                           []              719706.82          7.197068e+05    False      winsor       0.00     0.000      False                    False              0.000000
#        App 150->180   0.072651  0.072651                                                           []              646209.10          6.462091e+05    False      winsor       0.00     0.000      False                    False              0.000000
#        App 180->270   0.308391  0.109293 [2025-10-29, 2025-10-27, 2025-10-30, 2025-11-02, 2025-10-16]              458512.97          4.585130e+05    False      winsor       0.00     0.000      False                    False              0.000000
#        App 270->365   0.206491  0.085927                                     [2025-07-07, 2025-07-16]              695695.85          6.956958e+05    False      winsor       0.00     0.000      False                    False              0.000000
#  Affiliate     1->7   0.425545  0.141403 [2026-07-10, 2026-07-21, 2026-07-12, 2026-07-22, 2026-07-13]              252735.23          1.888929e+05    False      winsor       0.01     0.010      False                     True              0.252606
#  Affiliate    7->14   0.111384  0.090185                                     [2026-06-22, 2026-07-13]              347911.87          2.251340e+05    False      winsor       0.01     0.010      False                     True              0.352899
#  Affiliate   14->30   0.166376  0.094532 [2026-06-02, 2026-06-30, 2026-06-25, 2026-06-08, 2026-06-12]              445858.88          3.030407e+05    False      winsor       0.01     0.010      False                     True              0.320321
#  Affiliate   30->60   0.123578  0.099726                         [2026-05-08, 2026-05-20, 2026-05-21]              639681.73          3.255145e+05    False      winsor       0.01     0.010      False                     True              0.491131
#  Affiliate   60->90   0.075978  0.075978                                                           []              781544.95          4.248228e+05    False      winsor       0.01     0.010      False                     True              0.456432
#  Affiliate  90->120   0.075816  0.075816                                                           []             1020010.28          5.783672e+05    False      winsor       0.01     0.010      False                     True              0.432979
#  Affiliate 120->150   0.096103  0.096103                                                           []             1662133.41          1.135794e+06    False      winsor       0.01     0.010      False                     True              0.316665
#  Affiliate 150->180   0.052901  0.052901                                                           []             2446404.59          1.466308e+06    False      winsor       0.01     0.010      False                     True              0.400627
#  Affiliate 180->270   0.067774  0.067774                                                           []             2053339.88          1.154881e+06    False      winsor       0.01     0.010      False                     True              0.437560
#  Affiliate 270->365   0.086077  0.086077                                                           []             5850877.84          3.686759e+06    False      winsor       0.01     0.010      False                     True              0.369879
#
# >>> FLAGGED PATCHES:
#     Web / 1->7  CV=0.2446
#     Web / 14->30  CV=0.1943
#     Web / 30->60  CV=0.1935
#     App / 1->7  CV=0.1506
#
# ARPU curve milestones — Web  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      4.594260            1->7            False
#    7      8.391303            1->7            False
#   14     10.872010           7->14            False
#   30     13.940817          14->30            False
#   60     17.298373          30->60            False
#   90     18.628458          60->90            False
#  120     22.181479         90->120            False
#  180     25.913238        150->180            False
#  270     30.157824        180->270            False
#  365     36.250564        270->365            False
#
# ARPU curve milestones — App  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      5.081969            1->7            False
#    7     10.425623            1->7            False
#   14     13.616533           7->14            False
#   30     19.324009          14->30            False
#   60     27.938688          30->60            False
#   90     34.937353          60->90            False
#  120     39.087031         90->120            False
#  180     46.826744        150->180            False
#  270     57.390635        180->270            False
#  365     64.608198        270->365            False
#
# ARPU curve milestones — Affiliate  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      6.984837            1->7            False
#    7     11.670300            1->7            False
#   14     14.292979           7->14            False
#   30     17.788616          14->30            False
#   60     22.323265          30->60            False
#   90     25.667640          60->90            False
#  120     28.806988         90->120            False
#  180     33.891067        150->180            False
#  270     38.580576        180->270            False
#  365     43.031867        270->365            False
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 2/4 — Blended ARPU curve
# ────────────────────────────────────────────────────────────
# [realprize] Building BLENDED...
# [realprize] blended users: 971,875
#
# =======================================================
# POPULATION: Blended
# =======================================================
#   [Blended] 1->7  cv 0.2779->0.1920  removed=5/35  excl_prior=0  pre/post=72,344/72,344  newly_excl=0  winsor=0.000  rev_cut=0.0%  >>> CAPPED BY REVENUE LIMIT (15%)  >>> FLAGGED (cv=0.1920 > 0.15)
#   [Blended] 7->14  cv 0.1331->0.1007  removed=5/35  excl_prior=0  pre/post=73,327/73,327  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 14->30  cv 0.1676->0.0986  removed=4/35  excl_prior=0  pre/post=72,263/72,263  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 30->60  cv 0.1929->0.0852  removed=4/35  excl_prior=0  pre/post=60,379/60,379  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 60->90  cv 0.1430->0.0944  removed=3/35  excl_prior=0  pre/post=55,203/55,203  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 90->120  cv 0.1133->0.0908  removed=1/35  excl_prior=0  pre/post=57,762/57,762  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 120->150  cv 0.0414->0.0414  removed=0/35  excl_prior=0  pre/post=55,160/55,160  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 150->180  cv 0.0533->0.0533  removed=0/35  excl_prior=0  pre/post=65,068/65,068  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 180->270  cv 0.1353->0.0975  removed=4/35  excl_prior=0  pre/post=78,716/78,716  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   [Blended] 270->365  cv 0.0744->0.0744  removed=0/35  excl_prior=0  pre/post=117,012/117,012  newly_excl=0  winsor=0.000  rev_cut=0.0%
#   Total unique users excluded across all patches: 0
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · PART 2 done — Blended CV + curve
# ────────────────────────────────────────────────────────────
# CV summary:
# population    patch  cv_before  cv_after                                                removed_dates  total_rev_before_trim  total_rev_after_trim  flagged trim_method  floor_pct  pct_used  escalated  capped_by_revenue_limit  revenue_cut_fraction
#    Blended     1->7   0.277866  0.192041 [2026-06-24, 2026-06-27, 2026-07-02, 2026-07-04, 2026-07-12]             1151598.83            1151598.83     True      winsor          0         0      False                     True                   0.0
#    Blended    7->14   0.133136  0.100730 [2026-07-05, 2026-06-18, 2026-06-29, 2026-06-24, 2026-07-18]             1497261.81            1497261.81    False      winsor          0         0      False                    False                   0.0
#    Blended   14->30   0.167582  0.098605             [2026-06-16, 2026-06-04, 2026-06-27, 2026-06-01]             1949601.23            1949601.23    False      winsor          0         0      False                    False                   0.0
#    Blended   30->60   0.192888  0.085180             [2026-05-20, 2026-05-12, 2026-05-06, 2026-05-21]             2630786.56            2630786.56    False      winsor          0         0      False                    False                   0.0
#    Blended   60->90   0.142963  0.094387                         [2026-04-30, 2026-04-28, 2026-05-02]             3597502.92            3597502.92    False      winsor          0         0      False                    False                   0.0
#    Blended  90->120   0.113289  0.090758                                                 [2026-03-21]             3994131.25            3994131.25    False      winsor          0         0      False                    False                   0.0
#    Blended 120->150   0.041437  0.041437                                                           []             4123491.42            4123491.42    False      winsor          0         0      False                    False                   0.0
#    Blended 150->180   0.053310  0.053310                                                           []             5110836.71            5110836.71    False      winsor          0         0      False                    False                   0.0
#    Blended 180->270   0.135293  0.097453             [2025-10-25, 2025-10-04, 2025-10-26, 2025-10-29]             6302363.64            6302363.64    False      winsor          0         0      False                    False                   0.0
#    Blended 270->365   0.074368  0.074368                                                           []            11588206.64           11588206.64    False      winsor          0         0      False                    False                   0.0
#
# >>> FLAGGED PATCHES:
#     Blended / 1->7  CV=0.1920
#
# ARPU curve milestones — Blended  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      6.966958            1->7            False
#    7     16.211477            1->7            False
#   14     22.366179           7->14            False
#   30     33.046046          14->30            False
#   60     46.254703          30->60            False
#   90     59.079987          60->90            False
#  120     70.238495         90->120            False
#  180     86.763517        150->180            False
#  270    110.444504        180->270            False
#  365    133.160139        270->365            False
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 3/4 — organic share
# ────────────────────────────────────────────────────────────
# [realprize] Computing organic share [winsor_0pct] for horizons [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]...
#   [app] D  7:  [winsor_0pct] org=    53,744 acq=   358,065 share=13.1%
#   [non_app] D  7:  [winsor_0pct] org=   419,954 acq=   319,837 share=56.8%
#   [app] D  7:  [winsor_0pct] org=    51,054 acq=   293,442 share=14.8%
#   [app] D 30:  [winsor_0pct] org=   117,692 acq=   669,563 share=14.9%
#   [non_app] D  7:  [winsor_0pct] org=   326,582 acq=   247,028 share=56.9%
#   [non_app] D 30:  [winsor_0pct] org=   660,578 acq=   501,768 share=56.8%
#   [app] D  7:  [winsor_0pct] org=    93,056 acq=   271,651 share=25.5%
#   [app] D 30:  [winsor_0pct] org=   177,901 acq=   555,280 share=24.3%
#   [app] D 60:  [winsor_0pct] org=   241,237 acq=   865,412 share=21.8%
#   [non_app] D  7:  [winsor_0pct] org=   318,486 acq=   191,899 share=62.4%
#   [non_app] D 30:  [winsor_0pct] org=   620,624 acq=   407,746 share=60.4%
#   [non_app] D 60:  [winsor_0pct] org=   861,036 acq=   663,101 share=56.5%
#   [app] D  7:  [winsor_0pct] org=    65,503 acq=   237,203 share=21.6%
#   [app] D 30:  [winsor_0pct] org=   145,564 acq=   473,450 share=23.5%
#   [app] D 60:  [winsor_0pct] org=   261,376 acq=   706,672 share=27.0%
#   [app] D 90:  [winsor_0pct] org=   362,635 acq=   941,550 share=27.8%
#   [non_app] D  7:  [winsor_0pct] org=   417,204 acq=   193,535 share=68.3%
#   [non_app] D 30:  [winsor_0pct] org=   769,673 acq=   429,714 share=64.2%
#   [non_app] D 60:  [winsor_0pct] org= 1,124,157 acq=   627,923 share=64.2%
#   [non_app] D 90:  [winsor_0pct] org= 1,501,323 acq=   791,995 share=65.5%
#   [app] D  7:  [winsor_0pct] org=    20,610 acq=   161,964 share=11.3%
#   [app] D 30:  [winsor_0pct] org=    84,684 acq=   366,596 share=18.8%
#   [app] D 60:  [winsor_0pct] org=   115,869 acq=   685,037 share=14.5%
#   [app] D 90:  [winsor_0pct] org=   129,314 acq=   902,651 share=12.5%
#   [app] D120:  [winsor_0pct] org=   145,611 acq= 1,047,071 share=12.2%
#   [non_app] D  7:  [winsor_0pct] org=   389,775 acq=   248,895 share=61.0%
#   [non_app] D 30:  [winsor_0pct] org=   784,810 acq=   491,345 share=61.5%
#   [non_app] D 60:  [winsor_0pct] org= 1,181,474 acq=   666,076 share=63.9%
#   [non_app] D 90:  [winsor_0pct] org= 1,456,997 acq=   833,801 share=63.6%
#   [non_app] D120:  [winsor_0pct] org= 1,760,299 acq= 1,041,150 share=62.8%
#   [app] D  7:  [winsor_0pct] org=    23,582 acq=   123,521 share=16.0%
#   [app] D 30:  [winsor_0pct] org=    52,411 acq=   274,876 share=16.0%
#   [app] D 60:  [winsor_0pct] org=    68,027 acq=   378,732 share=15.2%
#   [app] D 90:  [winsor_0pct] org=    82,587 acq=   501,578 share=14.1%
#   [app] D120:  [winsor_0pct] org=    86,653 acq=   573,005 share=13.1%
#   [app] D150:  [winsor_0pct] org=    93,452 acq=   626,254 share=13.0%
#   [non_app] D  7:  [winsor_0pct] org=   276,596 acq=   417,422 share=39.9%
#   [non_app] D 30:  [winsor_0pct] org=   618,149 acq=   803,632 share=43.5%
#   [non_app] D 60:  [winsor_0pct] org= 1,031,599 acq= 1,105,702 share=48.3%
#   [non_app] D 90:  [winsor_0pct] org= 1,318,671 acq= 1,351,635 share=49.4%
#   [non_app] D120:  [winsor_0pct] org= 1,514,779 acq= 1,542,266 share=49.6%
#   [non_app] D150:  [winsor_0pct] org= 1,669,960 acq= 1,733,825 share=49.1%
#   [app] D  7:  [winsor_0pct] org=    16,197 acq=   126,525 share=11.3%
#   [app] D 30:  [winsor_0pct] org=    25,565 acq=   240,067 share=9.6%
#   [app] D 60:  [winsor_0pct] org=    35,106 acq=   344,214 share=9.3%
#   [app] D 90:  [winsor_0pct] org=    43,784 acq=   415,298 share=9.5%
#   [app] D120:  [winsor_0pct] org=    57,750 acq=   478,500 share=10.8%
#   [app] D150:  [winsor_0pct] org=    71,753 acq=   516,749 share=12.2%
#   [app] D180:  [winsor_0pct] org=    79,981 acq=   566,229 share=12.4%
#   [non_app] D  7:  [winsor_0pct] org=   251,335 acq=   395,991 share=38.8%
#   [non_app] D 30:  [winsor_0pct] org=   551,598 acq=   961,886 share=36.4%
#   [non_app] D 60:  [winsor_0pct] org=   865,804 acq= 1,393,631 share=38.3%
#   [non_app] D 90:  [winsor_0pct] org= 1,117,271 acq= 1,746,387 share=39.0%
#   [non_app] D120:  [winsor_0pct] org= 1,410,398 acq= 2,076,191 share=40.5%
#   [non_app] D150:  [winsor_0pct] org= 1,641,108 acq= 2,360,650 share=41.0%
#   [non_app] D180:  [winsor_0pct] org= 1,830,736 acq= 2,633,891 share=41.0%
#   [app] D  7:  [winsor_0pct] org=    20,491 acq=   129,966 share=13.6%
#   [app] D 30:  [winsor_0pct] org=    37,235 acq=   331,978 share=10.1%
#   [app] D 60:  [winsor_0pct] org=    67,506 acq=   485,119 share=12.2%
#   [app] D 90:  [winsor_0pct] org=    91,161 acq=   596,527 share=13.3%
#   [app] D120:  [winsor_0pct] org=   122,686 acq=   676,120 share=15.4%
#   [app] D150:  [winsor_0pct] org=   194,058 acq=   749,156 share=20.6%
#   [app] D180:  [winsor_0pct] org=   232,456 acq=   842,303 share=21.6%
#   [app] D210:  [winsor_0pct] org=   264,469 acq=   921,653 share=22.3%
#   [non_app] D  7:  [winsor_0pct] org=   243,651 acq=   373,685 share=39.5%
#   [non_app] D 30:  [winsor_0pct] org=   581,720 acq=   797,197 share=42.2%
#   [non_app] D 60:  [winsor_0pct] org=   811,246 acq= 1,178,498 share=40.8%
#   [non_app] D 90:  [winsor_0pct] org= 1,051,013 acq= 1,549,216 share=40.4%
#   [non_app] D120:  [winsor_0pct] org= 1,492,015 acq= 1,906,742 share=43.9%
#   [non_app] D150:  [winsor_0pct] org= 1,794,192 acq= 2,208,050 share=44.8%
#   [non_app] D180:  [winsor_0pct] org= 1,969,295 acq= 2,409,010 share=45.0%
#   [non_app] D210:  [winsor_0pct] org= 2,141,789 acq= 2,616,675 share=45.0%
#   [app] D  7:  [winsor_0pct] org=    29,084 acq=    37,118 share=43.9%
#   [app] D 30:  [winsor_0pct] org=    45,744 acq=   134,225 share=25.4%
#   [app] D 60:  [winsor_0pct] org=    71,482 acq=   231,001 share=23.6%
#   [app] D 90:  [winsor_0pct] org=   101,161 acq=   315,170 share=24.3%
#   [app] D120:  [winsor_0pct] org=   122,752 acq=   373,461 share=24.7%
#   [app] D150:  [winsor_0pct] org=   159,564 acq=   444,112 share=26.4%
#   [app] D180:  [winsor_0pct] org=   184,845 acq=   523,693 share=26.1%
#   [app] D210:  [winsor_0pct] org=   198,170 acq=   579,175 share=25.5%
#   [app] D240:  [winsor_0pct] org=   208,280 acq=   616,395 share=25.3%
#   [non_app] D  7:  [winsor_0pct] org=   283,340 acq=   323,304 share=46.7%
#   [non_app] D 30:  [winsor_0pct] org=   669,994 acq=   684,505 share=49.5%
#   [non_app] D 60:  [winsor_0pct] org=   854,679 acq= 1,001,009 share=46.1%
#   [non_app] D 90:  [winsor_0pct] org= 1,065,778 acq= 1,218,149 share=46.7%
#   [non_app] D120:  [winsor_0pct] org= 1,482,562 acq= 1,453,654 share=50.5%
#   [non_app] D150:  [winsor_0pct] org= 1,757,256 acq= 1,612,593 share=52.1%
#   [non_app] D180:  [winsor_0pct] org= 1,969,356 acq= 1,830,052 share=51.8%
#   [non_app] D210:  [winsor_0pct] org= 2,088,103 acq= 2,024,160 share=50.8%
#   [non_app] D240:  [winsor_0pct] org= 2,396,668 acq= 2,225,989 share=51.8%
#   [app] D  7:  [winsor_0pct] org=    20,749 acq=    11,603 share=64.1%
#   [app] D 30:  [winsor_0pct] org=    36,945 acq=    36,536 share=50.3%
#   [app] D 60:  [winsor_0pct] org=    94,047 acq=    49,303 share=65.6%
#   [app] D 90:  [winsor_0pct] org=   123,923 acq=    63,921 share=66.0%
#   [app] D120:  [winsor_0pct] org=   183,424 acq=    75,603 share=70.8%
#   [app] D150:  [winsor_0pct] org=   219,578 acq=    85,282 share=72.0%
#   [app] D180:  [winsor_0pct] org=   254,092 acq=   100,703 share=71.6%
#   [app] D210:  [winsor_0pct] org=   283,064 acq=   112,065 share=71.6%
#   [app] D240:  [winsor_0pct] org=   288,456 acq=   142,000 share=67.0%
#   [app] D270:  [winsor_0pct] org=   298,022 acq=   160,491 share=65.0%
#   [non_app] D  7:  [winsor_0pct] org=   192,981 acq=   476,709 share=28.8%
#   [non_app] D 30:  [winsor_0pct] org=   393,886 acq= 1,056,204 share=27.2%
#   [non_app] D 60:  [winsor_0pct] org=   598,172 acq= 1,592,558 share=27.3%
#   [non_app] D 90:  [winsor_0pct] org=   791,505 acq= 2,006,105 share=28.3%
#   [non_app] D120:  [winsor_0pct] org=   937,751 acq= 2,467,281 share=27.5%
#   [non_app] D150:  [winsor_0pct] org= 1,097,480 acq= 2,877,985 share=27.6%
#   [non_app] D180:  [winsor_0pct] org= 1,247,731 acq= 3,229,498 share=27.9%
#   [non_app] D210:  [winsor_0pct] org= 1,379,839 acq= 3,599,571 share=27.7%
#   [non_app] D240:  [winsor_0pct] org= 1,477,335 acq= 3,922,833 share=27.4%
#   [non_app] D270:  [winsor_0pct] org= 1,598,411 acq= 4,245,440 share=27.4%
#   [app] D  7:  [winsor_0pct] org=    59,297 acq=     6,892 share=89.6%
#   [app] D 30:  [winsor_0pct] org=   129,627 acq=    20,704 share=86.2%
#   [app] D 60:  [winsor_0pct] org=   191,662 acq=    30,068 share=86.4%
#   [app] D 90:  [winsor_0pct] org=   239,825 acq=    39,789 share=85.8%
#   [app] D120:  [winsor_0pct] org=   276,922 acq=    49,962 share=84.7%
#   [app] D150:  [winsor_0pct] org=   315,340 acq=    60,721 share=83.9%
#   [app] D180:  [winsor_0pct] org=   354,343 acq=    71,826 share=83.1%
#   [app] D210:  [winsor_0pct] org=   398,344 acq=    88,366 share=81.8%
#   [app] D240:  [winsor_0pct] org=   428,685 acq=   104,235 share=80.4%
#   [app] D270:  [winsor_0pct] org=   458,502 acq=   123,358 share=78.8%
#   [app] D365:  [winsor_0pct] org=   541,183 acq=   154,513 share=77.8%
#   [non_app] D  7:  [winsor_0pct] org=   198,845 acq=   973,793 share=17.0%
#   [non_app] D 30:  [winsor_0pct] org=   414,801 acq= 2,101,880 share=16.5%
#   [non_app] D 60:  [winsor_0pct] org=   570,040 acq= 3,224,544 share=15.0%
#   [non_app] D 90:  [winsor_0pct] org=   749,138 acq= 4,045,942 share=15.6%
#   [non_app] D120:  [winsor_0pct] org=   862,669 acq= 4,823,455 share=15.2%
#   [non_app] D150:  [winsor_0pct] org=   952,416 acq= 5,452,064 share=14.9%
#   [non_app] D180:  [winsor_0pct] org= 1,055,936 acq= 6,093,928 share=14.8%
#   [non_app] D210:  [winsor_0pct] org= 1,138,535 acq= 6,712,909 share=14.5%
#   [non_app] D240:  [winsor_0pct] org= 1,211,133 acq= 7,249,721 share=14.3%
#   [non_app] D270:  [winsor_0pct] org= 1,306,057 acq= 7,723,470 share=14.5%
#   [non_app] D365:  [winsor_0pct] org= 1,581,730 acq= 9,310,781 share=14.5%
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · ORGANIC SHARE
# ────────────────────────────────────────────────────────────
# rows: 132
#
# endpoint shares — scope=app:
# scope  goal_horizon  organic_share_pct  users_org  users_acq
#   app             7           0.130506       1594      29408
#   app            30           0.149497       2629      30698
#   app            60           0.217989       3015      26580
#   app            90           0.278055       1876      19742
#   app           120           0.122087       1204      17872
#   app           150           0.129848        861      12789
#   app           180           0.123769       1574      18265
#   app           210           0.222970       3444      58419
#   app           240           0.252560       3509      29888
#   app           270           0.649975       3006      10292
#   app           365           0.777902      21261       3123
#
# endpoint shares — scope=non_app:
#   scope  goal_horizon  organic_share_pct  users_org  users_acq
# non_app             7           0.567666      19825      21517
# non_app            30           0.568315      18373      20563
# non_app            60           0.564933      19307      11477
# non_app            90           0.654651      20838      12747
# non_app           120           0.628353      17593      21093
# non_app           150           0.490619      19205      22305
# non_app           180           0.410054      16407      28822
# non_app           210           0.450101      15080      51772
# non_app           240           0.518461      13205      55914
# non_app           270           0.273520      11603      53815
# non_app           365           0.145213      12494      80134
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 4/4 — goal construction
# ────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · GOALS
# ────────────────────────────────────────────────────────────
# total goal rows: 6,888
# counts by population:
# population
# Affiliate    1722
# App          1722
# Blended      1722
# Web          1722
#
# ── Web │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web             7    1        0.547503       0.567666             0.236704      4.594260            False
#        Web             7    7        1.000000       0.567666             0.432334      8.391303            False
#
# ── Web │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web            30    1        0.329555       0.568315             0.142264      4.594260            False
#        Web            30    7        0.601923       0.568315             0.259841      8.391303            False
#        Web            30   14        0.779869       0.568315             0.336658     10.872010            False
#        Web            30   30        1.000000       0.568315             0.431685     13.940817            False
#
# ── Web │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           120    1        0.207121       0.628353             0.076976      4.594260            False
#        Web           120    7        0.378302       0.628353             0.140595      8.391303            False
#        Web           120   14        0.490139       0.628353             0.182159     10.872010            False
#        Web           120   30        0.628489       0.628353             0.233576     13.940817            False
#        Web           120   60        0.779857       0.628353             0.289831     17.298373            False
#        Web           120   90        0.839820       0.628353             0.312117     18.628458            False
#        Web           120  120        1.000000       0.628353             0.371647     22.181479            False
#
# ── Web │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           365    1        0.126736       0.628353             0.047101      4.594260            False
#        Web           365    7        0.231481       0.628353             0.086029      8.391303            False
#        Web           365   14        0.299913       0.628353             0.111462     10.872010            False
#        Web           365   30        0.384568       0.628353             0.142924     13.940817            False
#        Web           365   60        0.477189       0.628353             0.177346     17.298373            False
#        Web           365   90        0.513880       0.628353             0.190982     18.628458            False
#        Web           365  120        0.611893       0.628353             0.227408     22.181479            False
#        Web           365  180        0.714837       0.628353             0.265667     25.913238            False
#        Web           365  270        0.831927       0.628353             0.309183     30.157824            False
#        Web           365  365        1.000000       0.628353             0.371647     36.250564            False
#
# ── App │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App             7    1         0.48745       0.130506             0.423835      5.081969            False
#        App             7    7         1.00000       0.130506             0.869494     10.425623            False
#
# ── App │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App            30    1        0.262987       0.149497             0.223671      5.081969            False
#        App            30    7        0.539517       0.149497             0.458860     10.425623            False
#        App            30   14        0.704643       0.149497             0.599301     13.616533            False
#        App            30   30        1.000000       0.149497             0.850503     19.324009            False
#
# ── App │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           120    1        0.130017       0.122087             0.114143      5.081969            False
#        App           120    7        0.266728       0.122087             0.234164     10.425623            False
#        App           120   14        0.348364       0.122087             0.305834     13.616533            False
#        App           120   30        0.494384       0.122087             0.434026     19.324009            False
#        App           120   60        0.714782       0.122087             0.627516     27.938688            False
#        App           120   90        0.893835       0.122087             0.784709     34.937353            False
#        App           120  120        1.000000       0.122087             0.877913     39.087031            False
#
# ── App │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           365    1        0.078658       0.122087             0.069055      5.081969            False
#        App           365    7        0.161367       0.122087             0.141666     10.425623            False
#        App           365   14        0.210756       0.122087             0.185025     13.616533            False
#        App           365   30        0.299095       0.122087             0.262580     19.324009            False
#        App           365   60        0.432433       0.122087             0.379638     27.938688            False
#        App           365   90        0.540757       0.122087             0.474738     34.937353            False
#        App           365  120        0.604986       0.122087             0.531125     39.087031            False
#        App           365  180        0.724780       0.122087             0.636294     46.826744            False
#        App           365  270        0.888287       0.122087             0.779839     57.390635            False
#        App           365  365        1.000000       0.122087             0.877913     64.608198            False
#
# ── Affiliate │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate             7    1        0.598514       0.567666             0.258758      6.984837            False
#  Affiliate             7    7        1.000000       0.567666             0.432334     11.670300            False
#
# ── Affiliate │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate            30    1        0.392658       0.568315             0.169505      6.984837            False
#  Affiliate            30    7        0.656054       0.568315             0.283209     11.670300            False
#  Affiliate            30   14        0.803490       0.568315             0.346855     14.292979            False
#  Affiliate            30   30        1.000000       0.568315             0.431685     17.788616            False
#
# ── Affiliate │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           120    1        0.242470       0.628353             0.090113      6.984837            False
#  Affiliate           120    7        0.405120       0.628353             0.150562     11.670300            False
#  Affiliate           120   14        0.496164       0.628353             0.184398     14.292979            False
#  Affiliate           120   30        0.617510       0.628353             0.229496     17.788616            False
#  Affiliate           120   60        0.774925       0.628353             0.287999     22.323265            False
#  Affiliate           120   90        0.891021       0.628353             0.331145     25.667640            False
#  Affiliate           120  120        1.000000       0.628353             0.371647     28.806988            False
#
# ── Affiliate │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           365    1        0.162318       0.628353             0.060325      6.984837            False
#  Affiliate           365    7        0.271201       0.628353             0.100791     11.670300            False
#  Affiliate           365   14        0.332149       0.628353             0.123442     14.292979            False
#  Affiliate           365   30        0.413382       0.628353             0.153632     17.788616            False
#  Affiliate           365   60        0.518761       0.628353             0.192796     22.323265            False
#  Affiliate           365   90        0.596480       0.628353             0.221680     25.667640            False
#  Affiliate           365  120        0.669434       0.628353             0.248793     28.806988            False
#  Affiliate           365  180        0.787581       0.628353             0.292702     33.891067            False
#  Affiliate           365  270        0.896558       0.628353             0.333203     38.580576            False
#  Affiliate           365  365        1.000000       0.628353             0.371647     43.031867            False
#
# ── Blended │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended             7    1        0.429755            0.0             0.429755      6.966958            False
#    Blended             7    7        1.000000            0.0             1.000000     16.211477            False
#
# ── Blended │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended            30    1        0.210826            0.0             0.210826      6.966958            False
#    Blended            30    7        0.490572            0.0             0.490572     16.211477            False
#    Blended            30   14        0.676819            0.0             0.676819     22.366179            False
#    Blended            30   30        1.000000            0.0             1.000000     33.046046            False
#
# ── Blended │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           120    1        0.099190            0.0             0.099190      6.966958            False
#    Blended           120    7        0.230806            0.0             0.230806     16.211477            False
#    Blended           120   14        0.318432            0.0             0.318432     22.366179            False
#    Blended           120   30        0.470483            0.0             0.470483     33.046046            False
#    Blended           120   60        0.658538            0.0             0.658538     46.254703            False
#    Blended           120   90        0.841134            0.0             0.841134     59.079987            False
#    Blended           120  120        1.000000            0.0             1.000000     70.238495            False
#
# ── Blended │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           365    1        0.052320            0.0             0.052320      6.966958            False
#    Blended           365    7        0.121744            0.0             0.121744     16.211477            False
#    Blended           365   14        0.167965            0.0             0.167965     22.366179            False
#    Blended           365   30        0.248168            0.0             0.248168     33.046046            False
#    Blended           365   60        0.347361            0.0             0.347361     46.254703            False
#    Blended           365   90        0.443676            0.0             0.443676     59.079987            False
#    Blended           365  120        0.527474            0.0             0.527474     70.238495            False
#    Blended           365  180        0.651573            0.0             0.651573     86.763517            False
#    Blended           365  270        0.829411            0.0             0.829411    110.444504            False
#    Blended           365  365        1.000000            0.0             1.000000    133.160139            False
#
# [realprize] COMPLETE — goals 6,888 | curve 1,460 | organic 132 | cv 40
#
# [lonestar] capped winsor_esc Web + Affiliate + Blended (no App)
# [lonestar] SQL floor date: 2025-06-24  (AS_OF_DATE = 2026-08-03)
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# [lonestar] users_df:   1,213,857 rows
# [lonestar] revenue_df: 1,473,113 rows
# population
# Affiliate    478738
# Organic      259733
# Web          249664
# PPC          199929
# App           25793
#
# ============================================================
# BRAND: lonestar
#   populations = ['Web', 'Affiliate']
#   CV threshold = 0.15  good_enough = 0.1
#   min_cohort_dates = 20
#   extrapolate_tail = True
#   organic_share_cap_horizon = None
# ============================================================
#
# ────────────────────────────────────────────────────────────
# [lonestar] MONITOR · DATA LOAD
# ────────────────────────────────────────────────────────────
# users_df rows:   1,213,857
# population counts:
# population
# Affiliate    478738
# Organic      259733
# Web          249664
# PPC          199929
# App           25793
# cost_date span: 2025-06-24 → 2026-08-18
#
# scope × bucket:
# scope    bucket
# app      acquired     21467
#          organic       4326
# non_app  acquired    928331
#          organic     259733
#
# ────────────────────────────────────────────────────────────
# [lonestar] PART 1/4 — per-population ARPU curves
# ...
#    Blended 180->270   0.102565  0.084959                                                 [2025-10-05]            15848114.85           15848114.85    False      winsor          0         0      False                    False                   0.0
#    Blended 270->365   0.135469  0.092311                                     [2025-08-01, 2025-07-24]            17557796.40           17557796.40    False      winsor          0         0      False                    False                   0.0
#
# >>> FLAGGED PATCHES:
#     Blended / 1->7  CV=0.2382
#
# ARPU curve milestones — Blended  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      7.023108            1->7            False
#    7     17.820846            1->7            False
#   14     24.260840           7->14            False
#   30     36.959607          14->30            False
#   60     57.165964          30->60            False
#   90     73.670712          60->90            False
#  120     87.672900         90->120            False
#  180    117.009225        150->180            False
#  270    155.568482        180->270            False
#  365    196.778392        270->365            False
#
# ────────────────────────────────────────────────────────────
# [lonestar] PART 3/4 — organic share
# ────────────────────────────────────────────────────────────
# [lonestar] Computing organic share [winsor_0pct] for horizons [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]...
#   [app] D  7:  [winsor_0pct] org=    51,106 acq=    33,520 share=60.4%
#   [non_app] D  7:  [winsor_0pct] org=   610,592 acq=   898,950 share=40.4%
#   [app] D  7:  [winsor_0pct] org=     7,250 acq=         0 share=100.0%
#   [app] D 30:  [winsor_0pct] org=    18,430 acq=         0 share=100.0%
#   [non_app] D  7:  [winsor_0pct] org=   561,266 acq=   871,742 share=39.2%
#   [non_app] D 30:  [winsor_0pct] org= 1,156,113 acq= 2,029,931 share=36.3%
#   [non_app] D  7:  [winsor_0pct] org=   532,015 acq=   743,420 share=41.7%
#   [non_app] D 30:  [winsor_0pct] org= 1,158,989 acq= 1,546,204 share=42.8%
#   [non_app] D 60:  [winsor_0pct] org= 1,927,634 acq= 2,399,520 share=44.5%
#   [non_app] D  7:  [winsor_0pct] org=   537,992 acq=   789,177 share=40.5%
#   [non_app] D 30:  [winsor_0pct] org= 1,033,861 acq= 1,789,082 share=36.6%
#   [non_app] D 60:  [winsor_0pct] org= 1,503,548 acq= 2,857,409 share=34.5%
#   [non_app] D 90:  [winsor_0pct] org= 1,938,831 acq= 3,943,858 share=33.0%
#   [non_app] D  7:  [winsor_0pct] org=   714,162 acq= 1,075,520 share=39.9%
#   [non_app] D 30:  [winsor_0pct] org= 1,470,690 acq= 2,406,266 share=37.9%
#   [non_app] D 60:  [winsor_0pct] org= 2,148,717 acq= 3,466,849 share=38.3%
#   [non_app] D 90:  [winsor_0pct] org= 2,660,104 acq= 4,444,365 share=37.4%
#   [non_app] D120:  [winsor_0pct] org= 3,165,095 acq= 5,289,681 share=37.4%
#   [non_app] D  7:  [winsor_0pct] org=   681,831 acq= 1,103,097 share=38.2%
#   [non_app] D 30:  [winsor_0pct] org= 1,527,163 acq= 2,640,927 share=36.6%
#   [non_app] D 60:  [winsor_0pct] org= 2,114,486 acq= 3,935,068 share=35.0%
#   [non_app] D 90:  [winsor_0pct] org= 2,489,773 acq= 5,205,960 share=32.4%
#   [non_app] D120:  [winsor_0pct] org= 2,872,921 acq= 6,265,108 share=31.4%
#   [non_app] D150:  [winsor_0pct] org= 3,332,521 acq= 7,392,336 share=31.1%
#   [non_app] D  7:  [winsor_0pct] org=   457,999 acq=   937,539 share=32.8%
#   [non_app] D 30:  [winsor_0pct] org= 1,045,350 acq= 2,118,398 share=33.0%
#   [non_app] D 60:  [winsor_0pct] org= 1,620,983 acq= 3,383,742 share=32.4%
#   [non_app] D 90:  [winsor_0pct] org= 2,246,444 acq= 4,472,272 share=33.4%
#   [non_app] D120:  [winsor_0pct] org= 2,716,303 acq= 5,358,356 share=33.6%
#   [non_app] D150:  [winsor_0pct] org= 3,114,510 acq= 6,406,955 share=32.7%
#   [non_app] D180:  [winsor_0pct] org= 3,492,285 acq= 7,334,999 share=32.3%
#   [non_app] D  7:  [winsor_0pct] org=   392,352 acq= 1,052,668 share=27.2%
#   [non_app] D 30:  [winsor_0pct] org=   933,645 acq= 2,364,654 share=28.3%
#   [non_app] D 60:  [winsor_0pct] org= 1,549,220 acq= 3,693,138 share=29.6%
#   [non_app] D 90:  [winsor_0pct] org= 2,238,514 acq= 4,985,734 share=31.0%
#   [non_app] D120:  [winsor_0pct] org= 2,726,988 acq= 6,140,241 share=30.8%
#   [non_app] D150:  [winsor_0pct] org= 3,055,669 acq= 7,300,197 share=29.5%
#   [non_app] D180:  [winsor_0pct] org= 3,348,234 acq= 8,328,395 share=28.7%
#   [non_app] D210:  [winsor_0pct] org= 3,773,058 acq= 9,214,388 share=29.1%
#   [non_app] D  7:  [winsor_0pct] org=   414,876 acq= 1,112,163 share=27.2%
#   [non_app] D 30:  [winsor_0pct] org=   768,357 acq= 2,531,410 share=23.3%
#   [non_app] D 60:  [winsor_0pct] org= 1,152,739 acq= 3,822,560 share=23.2%
#   [non_app] D 90:  [winsor_0pct] org= 1,419,652 acq= 4,874,312 share=22.6%
#   [non_app] D120:  [winsor_0pct] org= 1,732,235 acq= 5,735,529 share=23.2%
#   [non_app] D150:  [winsor_0pct] org= 2,051,109 acq= 6,560,613 share=23.8%
#   [non_app] D180:  [winsor_0pct] org= 2,309,850 acq= 7,275,104 share=24.1%
#   [non_app] D210:  [winsor_0pct] org= 2,564,802 acq= 8,107,049 share=24.0%
#   [non_app] D240:  [winsor_0pct] org= 2,795,272 acq= 8,932,623 share=23.8%
#   [non_app] D  7:  [winsor_0pct] org=   321,155 acq= 1,500,425 share=17.6%
#   [non_app] D 30:  [winsor_0pct] org=   804,466 acq= 3,341,795 share=19.4%
#   [non_app] D 60:  [winsor_0pct] org= 1,107,494 acq= 4,828,301 share=18.7%
#   [non_app] D 90:  [winsor_0pct] org= 1,379,857 acq= 6,068,652 share=18.5%
#   [non_app] D120:  [winsor_0pct] org= 1,619,542 acq= 7,199,693 share=18.4%
#   [non_app] D150:  [winsor_0pct] org= 1,909,024 acq= 8,332,873 share=18.6%
#   [non_app] D180:  [winsor_0pct] org= 2,163,685 acq= 9,632,813 share=18.3%
#   [non_app] D210:  [winsor_0pct] org= 2,399,308 acq=10,893,106 share=18.1%
#   [non_app] D240:  [winsor_0pct] org= 2,609,062 acq=11,913,376 share=18.0%
#   [non_app] D270:  [winsor_0pct] org= 2,794,647 acq=13,053,468 share=17.6%
#   [non_app] D  7:  [winsor_0pct] org=   203,371 acq= 1,337,297 share=13.2%
#   [non_app] D 30:  [winsor_0pct] org=   520,846 acq= 2,765,629 share=15.8%
#   [non_app] D 60:  [winsor_0pct] org=   770,354 acq= 4,034,552 share=16.0%
#   [non_app] D 90:  [winsor_0pct] org= 1,006,043 acq= 5,079,343 share=16.5%
#   [non_app] D120:  [winsor_0pct] org= 1,191,069 acq= 6,078,329 share=16.4%
#   [non_app] D150:  [winsor_0pct] org= 1,544,929 acq= 7,031,426 share=18.0%
#   [non_app] D180:  [winsor_0pct] org= 1,754,867 acq= 7,918,404 share=18.1%
#   [non_app] D210:  [winsor_0pct] org= 1,998,462 acq= 8,897,291 share=18.3%
#   [non_app] D240:  [winsor_0pct] org= 2,251,929 acq= 9,958,703 share=18.4%
#   [non_app] D270:  [winsor_0pct] org= 2,535,946 acq=10,883,575 share=18.9%
#   [non_app] D365:  [winsor_0pct] org= 3,751,560 acq=13,806,237 share=21.4%
#
# ────────────────────────────────────────────────────────────
# [lonestar] MONITOR · ORGANIC SHARE
# ────────────────────────────────────────────────────────────
# rows: 74
#
# endpoint shares — scope=app:
# scope  goal_horizon  organic_share_pct  users_org  users_acq
#   app             7           0.603906       1988       3984
#   app            30           1.000000        368          0
#   app           120                NaN          0          0
#
# endpoint shares — scope=non_app:
#   scope  goal_horizon  organic_share_pct  users_org  users_acq
# non_app             7           0.404488      21269      56615
# non_app            30           0.362868      20807      58829
# non_app            60           0.445474      25467      43144
# non_app            90           0.329582      23916      52430
# non_app           120           0.374356      24938      50417
# non_app           150           0.310729      27428      60188
# non_app           180           0.322545      28158      54491
# non_app           210           0.290516      23971      94323
# non_app           240           0.238344      20794      99098
# non_app           270           0.176339      19308     109178
# non_app           365           0.213669      14481     105525
#
# ────────────────────────────────────────────────────────────
# [lonestar] PART 4/4 — goal construction
# ────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# [lonestar] MONITOR · GOALS
# ────────────────────────────────────────────────────────────
# total goal rows: 3,444
# counts by population:
# population
# App        1722
# Blended    1722
#
# ── App │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App             7    1        0.492013       0.603906             0.194883      6.235239            False
#        App             7    7        1.000000       0.603906             0.396094     12.672920            False
#
# ── App │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App            30    1        0.107183            1.0                  0.0      6.235239            False
#        App            30    7        0.217846            1.0                  0.0     12.672920            False
#        App            30   14        0.291673            1.0                  0.0     16.967755            False
#        App            30   30        1.000000            1.0                  0.0     58.173804             True
#
# ── App │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           120    1        0.000105            NaN                  NaN      6.235239            False
#        App           120    7        0.000213            NaN                  NaN     12.672920            False
#        App           120   14        0.000285            NaN                  NaN     16.967755            False
#        App           120   30        0.000977            NaN                  NaN     58.173804             True
#        App           120   60        0.009848            NaN                  NaN    586.199911             True
#        App           120   90        0.099239            NaN                  NaN   5906.960085             True
#        App           120  120        1.000000            NaN                  NaN  59522.659022             True
#
# ── App │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           365    1    6.705093e-13            NaN                  NaN  6.235239e+00            False
#        App           365    7    1.362788e-12            NaN                  NaN  1.267292e+01            False
#        App           365   14    1.824635e-12            NaN                  NaN  1.696775e+01            False
#        App           365   30    6.255746e-12            NaN                  NaN  5.817380e+01             True
#        App           365   60    6.303727e-11            NaN                  NaN  5.861999e+02             True
#        App           365   90    6.352076e-10            NaN                  NaN  5.906960e+03             True
#        App           365  120    6.400796e-09            NaN                  NaN  5.952266e+04             True
#        App           365  180    6.499359e-07            NaN                  NaN  6.043923e+06             True
#        App           365  270    6.650058e-04            NaN                  NaN  6.184061e+09             True
#        App           365  365    1.000000e+00            NaN                  NaN  9.299259e+12             True
#
# ── Blended │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended             7    1        0.394095            0.0             0.394095      7.023108            False
#    Blended             7    7        1.000000            0.0             1.000000     17.820846            False
#
# ── Blended │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended            30    1        0.190021            0.0             0.190021      7.023108            False
#    Blended            30    7        0.482171            0.0             0.482171     17.820846            False
#    Blended            30   14        0.656415            0.0             0.656415     24.260840            False
#    Blended            30   30        1.000000            0.0             1.000000     36.959607            False
#
# ── Blended │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           120    1        0.080106            0.0             0.080106      7.023108            False
#    Blended           120    7        0.203265            0.0             0.203265     17.820846            False
#    Blended           120   14        0.276720            0.0             0.276720     24.260840            False
#    Blended           120   30        0.421563            0.0             0.421563     36.959607            False
#    Blended           120   60        0.652037            0.0             0.652037     57.165964            False
#    Blended           120   90        0.840291            0.0             0.840291     73.670712            False
#    Blended           120  120        1.000000            0.0             1.000000     87.672900            False
#
# ── Blended │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           365    1        0.035690            0.0             0.035690      7.023108            False
#    Blended           365    7        0.090563            0.0             0.090563     17.820846            False
#    Blended           365   14        0.123290            0.0             0.123290     24.260840            False
#    Blended           365   30        0.187824            0.0             0.187824     36.959607            False
#    Blended           365   60        0.290509            0.0             0.290509     57.165964            False
#    Blended           365   90        0.374384            0.0             0.374384     73.670712            False
#    Blended           365  120        0.445541            0.0             0.445541     87.672900            False
#    Blended           365  180        0.594624            0.0             0.594624    117.009225            False
#    Blended           365  270        0.790577            0.0             0.790577    155.568482            False
#    Blended           365  365        1.000000            0.0             1.000000    196.778392            False
#
# [lonestar] COMPLETE — goals 3,444 | curve 730 | organic 74 | cv 12
# native_early_rp_tail: splice after day 14  ARPU(14)=$16.9678  ARPU(365)=$80.51
#
# ============================================================
# BRAND: lonestar
#   populations = ['Web', 'Affiliate']
#   CV threshold = 0.15  good_enough = 0.1
#   min_cohort_dates = 20
#   extrapolate_tail = True
#   organic_share_cap_horizon = None
# ============================================================
# [lonestar/App] splice_day=14  goals=1,722
#
# ============================================================
# UNIFIED RUN COMPLETE — v2 winsor_esc + LS App native_early_rp_tail
#   as_of_date     = 2026-08-03
#   brands         = ['realprize', 'lonestar']
#   LS App splice  = day 14
#   cv rows        = 82
#   curve rows     = 2,920
#   organic rows   = 206
#   goals (main)   = 13,776
#   goals (detail) = 13,776
# ============================================================
#
# Row counts by brand × population:
#     brand population  n_rows
#  lonestar  Affiliate    1722
#  lonestar        App    1722
#  lonestar    Blended    1722
#  lonestar        Web    1722
# realprize  Affiliate    1722
# realprize        App    1722
# realprize    Blended    1722
# realprize        Web    1722

# %%
# ══════════════════════════════════════════════════════════════
# PREVIEW — main goals table + Combined-style spot checks
# ══════════════════════════════════════════════════════════════

print('MAIN GOALS (head):')
print(goals_df.head(20).to_string(index=False))

preview_days = [1, 7, 14, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
preview_horizons = [7, 30, 120, 365]

for brand in RUN_BRANDS:
    pops = list(BRAND_CONFIGS[brand]['populations']) + ['Blended']
    if brand == 'lonestar' and 'App' not in pops:
        pops = pops[:-1] + ['App', 'Blended']
    for pop in pops:
        for horizon in preview_horizons:
            sub = goals_df.loc[
                (goals_df['brand'] == brand) &
                (goals_df['population'] == pop) &
                (goals_df['goal_horizon'] == horizon) &
                (goals_df['day'].isin(preview_days))
            ]
            if sub.empty:
                continue
            print(f'\n── {brand} │ {pop} │ horizon D{horizon} ──')
            print(sub[MAIN_GOAL_COLS].to_string(index=False))

# CV flags
if not cv_df.empty and 'flagged' in cv_df.columns:
    flagged = cv_df.loc[cv_df['flagged'] == True]
    if not flagged.empty:
        print('\n>>> FLAGGED PATCHES:')
        cols = [c for c in ['brand', 'population', 'patch', 'cv_after'] if c in flagged.columns]
        print(flagged[cols].to_string(index=False))
    else:
        print('\nNo flagged patches.')

# ADDED: winsor escalation report (one row per brand × population × patch)
if not cv_df.empty:
    esc_cols = [
        c for c in [
            'brand', 'population', 'patch',
            'floor_pct', 'pct_used', 'escalated',
            'capped_by_revenue_limit', 'revenue_cut_fraction',
            'cv_before', 'cv_after', 'flagged',
        ] if c in cv_df.columns
    ]
    print('\n>>> WINSOR ESCALATION REPORT:')
    print(cv_df[esc_cols].to_string(index=False))
# Out:
# MAIN GOALS (head):
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web             7    1        0.547503       0.567666             0.236704
# realprize        Web             7    2        0.676041       0.567666             0.292276
# realprize        Web             7    3        0.740984       0.567666             0.320353
# realprize        Web             7    4        0.822616       0.567666             0.355645
# realprize        Web             7    5        0.877077       0.567666             0.379190
# realprize        Web             7    6        0.937281       0.567666             0.405219
# realprize        Web             7    7        1.000000       0.567666             0.432334
# realprize        Web            30    1        0.329555       0.568315             0.142264
# realprize        Web            30    2        0.406925       0.568315             0.175663
# realprize        Web            30    3        0.446016       0.568315             0.192538
# realprize        Web            30    4        0.495152       0.568315             0.213750
# realprize        Web            30    5        0.527933       0.568315             0.227901
# realprize        Web            30    6        0.564171       0.568315             0.243545
# realprize        Web            30    7        0.601923       0.568315             0.259841
# realprize        Web            30    8        0.640672       0.568315             0.276568
# realprize        Web            30    9        0.664994       0.568315             0.287068
# realprize        Web            30   10        0.704451       0.568315             0.304101
# realprize        Web            30   11        0.724292       0.568315             0.312666
# realprize        Web            30   12        0.737635       0.568315             0.318426
# realprize        Web            30   13        0.760458       0.568315             0.328279
#
# ── realprize │ Web │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web             7    1        0.547503       0.567666             0.236704
# realprize        Web             7    7        1.000000       0.567666             0.432334
#
# ── realprize │ Web │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web            30    1        0.329555       0.568315             0.142264
# realprize        Web            30    7        0.601923       0.568315             0.259841
# realprize        Web            30   14        0.779869       0.568315             0.336658
# realprize        Web            30   30        1.000000       0.568315             0.431685
#
# ── realprize │ Web │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web           120    1        0.207121       0.628353             0.076976
# realprize        Web           120    7        0.378302       0.628353             0.140595
# realprize        Web           120   14        0.490139       0.628353             0.182159
# realprize        Web           120   30        0.628489       0.628353             0.233576
# realprize        Web           120   60        0.779857       0.628353             0.289831
# realprize        Web           120   90        0.839820       0.628353             0.312117
# realprize        Web           120  120        1.000000       0.628353             0.371647
#
# ── realprize │ Web │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web           365    1        0.126736       0.628353             0.047101
# realprize        Web           365    7        0.231481       0.628353             0.086029
# realprize        Web           365   14        0.299913       0.628353             0.111462
# realprize        Web           365   30        0.384568       0.628353             0.142924
# realprize        Web           365   60        0.477189       0.628353             0.177346
# realprize        Web           365   90        0.513880       0.628353             0.190982
# realprize        Web           365  120        0.611893       0.628353             0.227408
# realprize        Web           365  150        0.665410       0.628353             0.247297
# realprize        Web           365  180        0.714837       0.628353             0.265667
# realprize        Web           365  210        0.761205       0.628353             0.282900
# realprize        Web           365  240        0.795845       0.628353             0.295773
# realprize        Web           365  270        0.831927       0.628353             0.309183
# realprize        Web           365  365        1.000000       0.628353             0.371647
#
# ── realprize │ App │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App             7    1         0.48745       0.130506             0.423835
# realprize        App             7    7         1.00000       0.130506             0.869494
#
# ── realprize │ App │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App            30    1        0.262987       0.149497             0.223671
# realprize        App            30    7        0.539517       0.149497             0.458860
# realprize        App            30   14        0.704643       0.149497             0.599301
# realprize        App            30   30        1.000000       0.149497             0.850503
#
# ── realprize │ App │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App           120    1        0.130017       0.122087             0.114143
# realprize        App           120    7        0.266728       0.122087             0.234164
# realprize        App           120   14        0.348364       0.122087             0.305834
# realprize        App           120   30        0.494384       0.122087             0.434026
# realprize        App           120   60        0.714782       0.122087             0.627516
# realprize        App           120   90        0.893835       0.122087             0.784709
# realprize        App           120  120        1.000000       0.122087             0.877913
#
# ── realprize │ App │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App           365    1        0.078658       0.122087             0.069055
# realprize        App           365    7        0.161367       0.122087             0.141666
# realprize        App           365   14        0.210756       0.122087             0.185025
# realprize        App           365   30        0.299095       0.122087             0.262580
# realprize        App           365   60        0.432433       0.122087             0.379638
# realprize        App           365   90        0.540757       0.122087             0.474738
# realprize        App           365  120        0.604986       0.122087             0.531125
# realprize        App           365  150        0.660057       0.122087             0.579473
# realprize        App           365  180        0.724780       0.122087             0.636294
# realprize        App           365  210        0.809207       0.122087             0.710413
# realprize        App           365  240        0.844652       0.122087             0.741531
# realprize        App           365  270        0.888287       0.122087             0.779839
# realprize        App           365  365        1.000000       0.122087             0.877913
#
# ── realprize │ Affiliate │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate             7    1        0.598514       0.567666             0.258758
# realprize  Affiliate             7    7        1.000000       0.567666             0.432334
#
# ── realprize │ Affiliate │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate            30    1        0.392658       0.568315             0.169505
# realprize  Affiliate            30    7        0.656054       0.568315             0.283209
# realprize  Affiliate            30   14        0.803490       0.568315             0.346855
# realprize  Affiliate            30   30        1.000000       0.568315             0.431685
#
# ── realprize │ Affiliate │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate           120    1        0.242470       0.628353             0.090113
# realprize  Affiliate           120    7        0.405120       0.628353             0.150562
# realprize  Affiliate           120   14        0.496164       0.628353             0.184398
# realprize  Affiliate           120   30        0.617510       0.628353             0.229496
# realprize  Affiliate           120   60        0.774925       0.628353             0.287999
# realprize  Affiliate           120   90        0.891021       0.628353             0.331145
# realprize  Affiliate           120  120        1.000000       0.628353             0.371647
#
# ── realprize │ Affiliate │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate           365    1        0.162318       0.628353             0.060325
# realprize  Affiliate           365    7        0.271201       0.628353             0.100791
# realprize  Affiliate           365   14        0.332149       0.628353             0.123442
# realprize  Affiliate           365   30        0.413382       0.628353             0.153632
# realprize  Affiliate           365   60        0.518761       0.628353             0.192796
# realprize  Affiliate           365   90        0.596480       0.628353             0.221680
# realprize  Affiliate           365  120        0.669434       0.628353             0.248793
# realprize  Affiliate           365  150        0.728681       0.628353             0.270812
# realprize  Affiliate           365  180        0.787581       0.628353             0.292702
# realprize  Affiliate           365  210        0.830991       0.628353             0.308835
# realprize  Affiliate           365  240        0.866446       0.628353             0.322012
# realprize  Affiliate           365  270        0.896558       0.628353             0.333203
# realprize  Affiliate           365  365        1.000000       0.628353             0.371647
#
# ── realprize │ Blended │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended             7    1        0.429755            0.0             0.429755
# realprize    Blended             7    7        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended            30    1        0.210826            0.0             0.210826
# realprize    Blended            30    7        0.490572            0.0             0.490572
# realprize    Blended            30   14        0.676819            0.0             0.676819
# realprize    Blended            30   30        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended           120    1        0.099190            0.0             0.099190
# realprize    Blended           120    7        0.230806            0.0             0.230806
# realprize    Blended           120   14        0.318432            0.0             0.318432
# realprize    Blended           120   30        0.470483            0.0             0.470483
# realprize    Blended           120   60        0.658538            0.0             0.658538
# realprize    Blended           120   90        0.841134            0.0             0.841134
# realprize    Blended           120  120        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended           365    1        0.052320            0.0             0.052320
# realprize    Blended           365    7        0.121744            0.0             0.121744
# realprize    Blended           365   14        0.167965            0.0             0.167965
# realprize    Blended           365   30        0.248168            0.0             0.248168
# realprize    Blended           365   60        0.347361            0.0             0.347361
# realprize    Blended           365   90        0.443676            0.0             0.443676
# realprize    Blended           365  120        0.527474            0.0             0.527474
# realprize    Blended           365  150        0.585205            0.0             0.585205
# realprize    Blended           365  180        0.651573            0.0             0.651573
# realprize    Blended           365  210        0.716309            0.0             0.716309
# realprize    Blended           365  240        0.768545            0.0             0.768545
# realprize    Blended           365  270        0.829411            0.0             0.829411
# realprize    Blended           365  365        1.000000            0.0             1.000000
#
# ── lonestar │ Web │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web             7    1        0.429864       0.404488             0.255989
# lonestar        Web             7    7        1.000000       0.404488             0.595512
#
# ── lonestar │ Web │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web            30    1        0.221352       0.362868             0.141030
# lonestar        Web            30    7        0.514934       0.362868             0.328081
# lonestar        Web            30   14        0.695111       0.362868             0.442878
# lonestar        Web            30   30        1.000000       0.362868             0.637132
#
# ── lonestar │ Web │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web           120    1        0.105426       0.374356             0.065959
# lonestar        Web           120    7        0.245255       0.374356             0.153442
# lonestar        Web           120   14        0.331071       0.374356             0.207133
# lonestar        Web           120   30        0.476285       0.374356             0.297985
# lonestar        Web           120   60        0.666054       0.374356             0.416713
# lonestar        Web           120   90        0.866619       0.374356             0.542195
# lonestar        Web           120  120        1.000000       0.374356             0.625644
#
# ── lonestar │ Web │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web           365    1        0.049741       0.213669             0.039113
# lonestar        Web           365    7        0.115712       0.213669             0.090988
# lonestar        Web           365   14        0.156201       0.213669             0.122825
# lonestar        Web           365   30        0.224713       0.213669             0.176699
# lonestar        Web           365   60        0.314247       0.213669             0.247102
# lonestar        Web           365   90        0.408875       0.213669             0.321511
# lonestar        Web           365  120        0.471805       0.213669             0.370995
# lonestar        Web           365  150        0.515658       0.213669             0.405478
# lonestar        Web           365  180        0.571559       0.213669             0.449434
# lonestar        Web           365  210        0.673351       0.213669             0.529476
# lonestar        Web           365  240        0.733514       0.213669             0.576785
# lonestar        Web           365  270        0.794553       0.213669             0.624782
# lonestar        Web           365  365        1.000000       0.213669             0.786331
#
# ── lonestar │ Affiliate │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate             7    1        0.564217       0.404488             0.335998
# lonestar  Affiliate             7    7        1.000000       0.404488             0.595512
#
# ── lonestar │ Affiliate │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate            30    1        0.371599       0.362868             0.236757
# lonestar  Affiliate            30    7        0.658609       0.362868             0.419621
# lonestar  Affiliate            30   14        0.795297       0.362868             0.506709
# lonestar  Affiliate            30   30        1.000000       0.362868             0.637132
#
# ── lonestar │ Affiliate │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate           120    1        0.234004       0.374356             0.146403
# lonestar  Affiliate           120    7        0.414741       0.374356             0.259480
# lonestar  Affiliate           120   14        0.500816       0.374356             0.313332
# lonestar  Affiliate           120   30        0.629722       0.374356             0.393982
# lonestar  Affiliate           120   60        0.751257       0.374356             0.470020
# lonestar  Affiliate           120   90        0.885634       0.374356             0.554092
# lonestar  Affiliate           120  120        1.000000       0.374356             0.625644
#
# ── lonestar │ Affiliate │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate           365    1        0.144657       0.213669             0.113748
# lonestar  Affiliate           365    7        0.256385       0.213669             0.201603
# lonestar  Affiliate           365   14        0.309595       0.213669             0.243444
# lonestar  Affiliate           365   30        0.389282       0.213669             0.306105
# lonestar  Affiliate           365   60        0.464413       0.213669             0.365182
# lonestar  Affiliate           365   90        0.547483       0.213669             0.430502
# lonestar  Affiliate           365  120        0.618181       0.213669             0.486095
# lonestar  Affiliate           365  150        0.684516       0.213669             0.538256
# lonestar  Affiliate           365  180        0.731994       0.213669             0.575589
# lonestar  Affiliate           365  210        0.785745       0.213669             0.617856
# lonestar  Affiliate           365  240        0.835025       0.213669             0.656606
# lonestar  Affiliate           365  270        0.874741       0.213669             0.687836
# lonestar  Affiliate           365  365        1.000000       0.213669             0.786331
#
# ── lonestar │ App │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        App             7    1        0.492013       0.603906             0.194883
# lonestar        App             7    7        1.000000       0.603906             0.396094
#
# ── lonestar │ App │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        App            30    1        0.258939            1.0                  0.0
# lonestar        App            30    7        0.526286            1.0                  0.0
# lonestar        App            30   14        0.704643            1.0                  0.0
# lonestar        App            30   30        1.000000            1.0                  0.0
#
# ── lonestar │ App │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        App           120    1        0.128016            NaN                  NaN
# lonestar        App           120    7        0.260187            NaN                  NaN
# lonestar        App           120   14        0.348364            NaN                  NaN
# lonestar        App           120   30        0.494384            NaN                  NaN
# lonestar        App           120   60        0.714782            NaN                  NaN
# lonestar        App           120   90        0.893835            NaN                  NaN
# lonestar        App           120  120        1.000000            NaN                  NaN
#
# ── lonestar │ App │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        App           365    1        0.077448            NaN                  NaN
# lonestar        App           365    7        0.157410            NaN                  NaN
# lonestar        App           365   14        0.210756            NaN                  NaN
# lonestar        App           365   30        0.299095            NaN                  NaN
# lonestar        App           365   60        0.432433            NaN                  NaN
# lonestar        App           365   90        0.540757            NaN                  NaN
# lonestar        App           365  120        0.604986            NaN                  NaN
# lonestar        App           365  150        0.660057            NaN                  NaN
# lonestar        App           365  180        0.724780            NaN                  NaN
# lonestar        App           365  210        0.809207            NaN                  NaN
# lonestar        App           365  240        0.844652            NaN                  NaN
# lonestar        App           365  270        0.888287            NaN                  NaN
# lonestar        App           365  365        1.000000            NaN                  NaN
#
# ── lonestar │ Blended │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended             7    1        0.394095            0.0             0.394095
# lonestar    Blended             7    7        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended            30    1        0.190021            0.0             0.190021
# lonestar    Blended            30    7        0.482171            0.0             0.482171
# lonestar    Blended            30   14        0.656415            0.0             0.656415
# lonestar    Blended            30   30        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended           120    1        0.080106            0.0             0.080106
# lonestar    Blended           120    7        0.203265            0.0             0.203265
# lonestar    Blended           120   14        0.276720            0.0             0.276720
# lonestar    Blended           120   30        0.421563            0.0             0.421563
# lonestar    Blended           120   60        0.652037            0.0             0.652037
# lonestar    Blended           120   90        0.840291            0.0             0.840291
# lonestar    Blended           120  120        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended           365    1        0.035690            0.0             0.035690
# lonestar    Blended           365    7        0.090563            0.0             0.090563
# lonestar    Blended           365   14        0.123290            0.0             0.123290
# lonestar    Blended           365   30        0.187824            0.0             0.187824
# lonestar    Blended           365   60        0.290509            0.0             0.290509
# lonestar    Blended           365   90        0.374384            0.0             0.374384
# lonestar    Blended           365  120        0.445541            0.0             0.445541
# lonestar    Blended           365  150        0.522910            0.0             0.522910
# lonestar    Blended           365  180        0.594624            0.0             0.594624
# lonestar    Blended           365  210        0.667535            0.0             0.667535
# lonestar    Blended           365  240        0.729795            0.0             0.729795
# lonestar    Blended           365  270        0.790577            0.0             0.790577
# lonestar    Blended           365  365        1.000000            0.0             1.000000
#
# >>> FLAGGED PATCHES:
#     brand population    patch  cv_after
# realprize        Web     1->7  0.244573
# realprize        Web   14->30  0.194259
# realprize        Web   30->60  0.193513
# realprize        App     1->7  0.150555
# realprize    Blended     1->7  0.192041
#  lonestar        Web     1->7  0.258745
#  lonestar        Web 180->270  0.194077
#  lonestar  Affiliate     1->7  0.152894
#  lonestar    Blended     1->7  0.238197
#  lonestar        App     1->7  0.434442
#  lonestar        App    7->14  0.218157
#  lonestar    Blended     1->7  0.238197
#
# >>> WINSOR ESCALATION REPORT:
#     brand population    patch  floor_pct  pct_used  escalated  capped_by_revenue_limit  revenue_cut_fraction  cv_before  cv_after  flagged
# realprize        Web     1->7       0.01     0.010      False                     True              0.105647   0.359043  0.244573     True
# realprize        Web    7->14       0.01     0.020       True                    False              0.112702   0.203850  0.136769    False
# realprize        Web   14->30       0.01     0.020       True                     True              0.112059   0.493037  0.194259     True
# realprize        Web   30->60       0.01     0.050       True                    False              0.124742   0.271584  0.193513     True
# realprize        Web   60->90       0.01     0.010      False                    False              0.009105   0.393106  0.125433    False
# realprize        Web  90->120       0.01     0.010      False                    False              0.039482   0.158812  0.125078    False
# realprize        Web 120->150       0.01     0.010      False                    False              0.027315   0.195702  0.087775    False
# realprize        Web 150->180       0.01     0.010      False                    False              0.064051   0.087759  0.087759    False
# realprize        Web 180->270       0.01     0.010      False                    False              0.141437   0.232851  0.111117    False
# realprize        Web 270->365       0.01     0.010      False                     True              0.152243   0.344060  0.107542    False
# realprize        App     1->7       0.00     0.005       True                     True              0.144714   0.270180  0.150555     True
# realprize        App    7->14       0.00     0.000      False                    False              0.000000   0.170033  0.111584    False
# realprize        App   14->30       0.00     0.000      False                    False              0.000000   0.255102  0.093723    False
# realprize        App   30->60       0.00     0.000      False                    False              0.000000   0.163753  0.117578    False
# realprize        App   60->90       0.00     0.000      False                    False              0.000000   0.242505  0.132429    False
# realprize        App  90->120       0.00     0.000      False                    False              0.000000   0.140358  0.079481    False
# realprize        App 120->150       0.00     0.000      False                    False              0.000000   0.052292  0.052292    False
# realprize        App 150->180       0.00     0.000      False                    False              0.000000   0.072651  0.072651    False
# realprize        App 180->270       0.00     0.000      False                    False              0.000000   0.308391  0.109293    False
# realprize        App 270->365       0.00     0.000      False                    False              0.000000   0.206491  0.085927    False
# realprize  Affiliate     1->7       0.01     0.010      False                     True              0.252606   0.425545  0.141403    False
# realprize  Affiliate    7->14       0.01     0.010      False                     True              0.352899   0.111384  0.090185    False
# realprize  Affiliate   14->30       0.01     0.010      False                     True              0.320321   0.166376  0.094532    False
# realprize  Affiliate   30->60       0.01     0.010      False                     True              0.491131   0.123578  0.099726    False
# realprize  Affiliate   60->90       0.01     0.010      False                     True              0.456432   0.075978  0.075978    False
# realprize  Affiliate  90->120       0.01     0.010      False                     True              0.432979   0.075816  0.075816    False
# realprize  Affiliate 120->150       0.01     0.010      False                     True              0.316665   0.096103  0.096103    False
# realprize  Affiliate 150->180       0.01     0.010      False                     True              0.400627   0.052901  0.052901    False
# realprize  Affiliate 180->270       0.01     0.010      False                     True              0.437560   0.067774  0.067774    False
# realprize  Affiliate 270->365       0.01     0.010      False                     True              0.369879   0.086077  0.086077    False
# realprize    Blended     1->7       0.00     0.000      False                     True              0.000000   0.277866  0.192041     True
# realprize    Blended    7->14       0.00     0.000      False                    False              0.000000   0.133136  0.100730    False
# realprize    Blended   14->30       0.00     0.000      False                    False              0.000000   0.167582  0.098605    False
# realprize    Blended   30->60       0.00     0.000      False                    False              0.000000   0.192888  0.085180    False
# realprize    Blended   60->90       0.00     0.000      False                    False              0.000000   0.142963  0.094387    False
# realprize    Blended  90->120       0.00     0.000      False                    False              0.000000   0.113289  0.090758    False
# realprize    Blended 120->150       0.00     0.000      False                    False              0.000000   0.041437  0.041437    False
# realprize    Blended 150->180       0.00     0.000      False                    False              0.000000   0.053310  0.053310    False
# realprize    Blended 180->270       0.00     0.000      False                    False              0.000000   0.135293  0.097453    False
# realprize    Blended 270->365       0.00     0.000      False                    False              0.000000   0.074368  0.074368    False
#  lonestar        Web     1->7       0.00     0.005       True                     True              0.096237   0.377225  0.258745     True
#  lonestar        Web    7->14       0.00     0.000      False                    False              0.000000   0.216866  0.142392    False
#  lonestar        Web   14->30       0.00     0.005       True                    False              0.111852   0.179846  0.127187    False
#  lonestar        Web   30->60       0.00     0.005       True                    False              0.099696   0.232477  0.114525    False
#  lonestar        Web   60->90       0.00     0.000      False                    False              0.000000   0.226624  0.124878    False
#  lonestar        Web  90->120       0.00     0.000      False                    False              0.000000   0.153863  0.107416    False
#  lonestar        Web 120->150       0.00     0.000      False                    False              0.000000   0.175946  0.079299    False
#  lonestar        Web 150->180       0.00     0.000      False                    False              0.000000   0.177902  0.077723    False
#  lonestar        Web 180->270       0.00     0.000      False                     True              0.000000   2.070565  0.194077     True
#  lonestar        Web 270->365       0.00     0.000      False                    False              0.000000   0.306148  0.098877    False
#  lonestar  Affiliate     1->7       0.01     0.010      False                     True              0.386012   0.196664  0.152894     True
#  lonestar  Affiliate    7->14       0.01     0.010      False                     True              0.363269   0.116773  0.098471    False
#  lonestar  Affiliate   14->30       0.01     0.010      False                     True              0.439568   0.137360  0.098878    False
#  lonestar  Affiliate   30->60       0.01     0.010      False                     True              0.363297   0.159098  0.094078    False
#  lonestar  Affiliate   60->90       0.01     0.010      False                     True              0.451949   0.086208  0.086208    False
#  lonestar  Affiliate  90->120       0.01     0.010      False                     True              0.398797   0.068192  0.068192    False
#  lonestar  Affiliate 120->150       0.01     0.010      False                     True              0.480663   0.063555  0.063555    False
#  lonestar  Affiliate 150->180       0.01     0.010      False                     True              0.385047   0.031994  0.031994    False
#  lonestar  Affiliate 180->270       0.01     0.010      False                     True              0.405798   0.087892  0.087892    False
#  lonestar  Affiliate 270->365       0.01     0.010      False                     True              0.330135   0.094608  0.094608    False
#  lonestar    Blended     1->7       0.00     0.000      False                     True              0.000000   0.308099  0.238197     True
#  lonestar    Blended    7->14       0.00     0.000      False                    False              0.000000   0.112610  0.099335    False
#  lonestar    Blended   14->30       0.00     0.000      False                    False              0.000000   0.148877  0.101032    False
#  lonestar    Blended   30->60       0.00     0.000      False                    False              0.000000   0.225677  0.130171    False
#  lonestar    Blended   60->90       0.00     0.000      False                    False              0.000000   0.171523  0.086230    False
#  lonestar    Blended  90->120       0.00     0.000      False                    False              0.000000   0.083313  0.083313    False
#  lonestar    Blended 120->150       0.00     0.000      False                    False              0.000000   0.095312  0.095312    False
#  lonestar    Blended 150->180       0.00     0.000      False                    False              0.000000   0.052298  0.052298    False
#  lonestar    Blended 180->270       0.00     0.000      False                    False              0.000000   0.102565  0.084959    False
#  lonestar    Blended 270->365       0.00     0.000      False                    False              0.000000   0.135469  0.092311    False
#  lonestar        App     1->7       0.00     0.000      False                    False              0.000000   0.871105  0.434442     True
#  lonestar        App    7->14       0.00     0.000      False                    False              0.000000   0.373530  0.218157     True
#  lonestar    Blended     1->7       0.00     0.000      False                     True              0.000000   0.308099  0.238197     True
#  lonestar    Blended    7->14       0.00     0.000      False                    False              0.000000   0.112610  0.099335    False
#  lonestar    Blended   14->30       0.00     0.000      False                    False              0.000000   0.148877  0.101032    False
#  lonestar    Blended   30->60       0.00     0.000      False                    False              0.000000   0.225677  0.130171    False
#  lonestar    Blended   60->90       0.00     0.000      False                    False              0.000000   0.171523  0.086230    False
#  lonestar    Blended  90->120       0.00     0.000      False                    False              0.000000   0.083313  0.083313    False
#  lonestar    Blended 120->150       0.00     0.000      False                    False              0.000000   0.095312  0.095312    False
#  lonestar    Blended 150->180       0.00     0.000      False                    False              0.000000   0.052298  0.052298    False
#  lonestar    Blended 180->270       0.00     0.000      False                    False              0.000000   0.102565  0.084959    False
#  lonestar    Blended 270->365       0.00     0.000      False                    False              0.000000   0.135469  0.092311    False

# %%
# ══════════════════════════════════════════════════════════════
# EXPORT — unique run folder when re-run same day
# ══════════════════════════════════════════════════════════════
# Naming when you run more than once per day:
#   runs/<as_of>_<brands>_<run_ts>/
#   e.g. 2026-08-05_rp_142233/   or  2026-08-05_rp_ls_143015/
# run_ts = local clock when this export cell runs (HHMMSS) — never overwrites.
# as_of_date is the cohort anchor (today-2), not wall-clock time.
# ══════════════════════════════════════════════════════════════

from datetime import datetime
from pathlib import Path
import os
import re

# Brand slug: realprize → rp, lonestar → ls (stable short codes)
_BRAND_SLUG = {'realprize': 'rp', 'lonestar': 'ls'}
brand_slug = '_'.join(
    _BRAND_SLUG.get(b, re.sub(r'[^a-z0-9]+', '', b.lower())[:6])
    for b in RUN_BRANDS
)

# Unique per execution
exported_at = datetime.now()
run_ts = exported_at.strftime('%H%M%S')
run_tag = f"{AS_OF_DATE.date()}_{brand_slug}_winsor_esc_ls_app_{run_ts}"

main_goals_path    = f'combined_goals_{run_tag}.csv'
detail_goals_path  = f'combined_goals_detail_{run_tag}.csv'
curve_path         = f'combined_arpu_curve_{run_tag}.csv'
organic_path       = f'combined_organic_share_{run_tag}.csv'
# CHANGED: distinct filename so this adaptive-winsor test does not overwrite baseline cv_summary
cv_path            = f'combined_cv_summary_{run_tag}_adaptive_test.csv'

goals_df.to_csv(main_goals_path, index=False)
goals_detail_df.to_csv(detail_goals_path, index=False)
curve_df.to_csv(curve_path, index=False)
organic_df.to_csv(organic_path, index=False)
cv_df.to_csv(cv_path, index=False)

print(f'Run tag: {run_tag}')
print(f'  as_of_date (data) = {AS_OF_DATE.date()}')
print(f'  brands            = {RUN_BRANDS}')
print(f'  run_ts (export)   = {run_ts}  (unique each time this cell runs)')
print('Saved in working directory:')
for pth in [main_goals_path, detail_goals_path, curve_path, organic_path, cv_path]:
    print(f'  {pth}')

run_candidates = [
    Path('/content/drive/MyDrive/lee_project/marketing_goals/runs'),
    Path('/content/drive/My Drive/lee_project/marketing_goals/runs'),
]
drive_runs = next((c for c in run_candidates if c.is_dir()), None)

if drive_runs is not None:
    out_dir = drive_runs / run_tag
    out_dir.mkdir(parents=True, exist_ok=True)
    goals_df.to_csv(out_dir / 'combined_goals.csv', index=False)
    goals_detail_df.to_csv(out_dir / 'combined_goals_detail.csv', index=False)
    curve_df.to_csv(out_dir / 'combined_arpu_curve.csv', index=False)
    organic_df.to_csv(out_dir / 'combined_organic_share.csv', index=False)
    # CHANGED: adaptive-test name — keep side-by-side with prior combined_cv_summary.csv
    cv_df.to_csv(out_dir / 'combined_cv_summary_adaptive_test.csv', index=False)
    meta = pd.DataFrame([{
        'run_tag': run_tag,
        'as_of_date': str(AS_OF_DATE.date()),
        'brands': ','.join(RUN_BRANDS),
        'brand_slug': brand_slug,
        'run_ts': run_ts,
        'exported_at': exported_at.isoformat(timespec='seconds'),
        'main_columns': ','.join(MAIN_GOAL_COLS),
        'env': 'colab',
        'engine': 'v2 winsor_esc + lonestar/App native_early_rp_tail',
        'ls_app_winsor': '0% locked (no escalation)',
        'ls_app_organic': 'off (organic_share=0, adjusted=raw)',
        'ls_blended_includes_app': False,
        'ls_app_splice_day': int(splice_day) if 'splice_day' in dir() else None,
    }])
    meta.to_csv(out_dir / 'run_meta.csv', index=False)
    print(f'\nAlso wrote to: {out_dir}')
    print('(Each re-run creates a NEW folder under runs/ — previous runs stay.)')
else:
    print('\nDrive runs/ not found (mount skip or wrong path).')
    print('Browser downloads below still give you the full pack.')

from google.colab import files
for pth in [main_goals_path, detail_goals_path, curve_path, organic_path, cv_path]:
    files.download(pth)
print('Downloads started in browser.')
# Out:
# Run tag: 2026-08-03_rp_ls_winsor_esc_ls_app_110733
#   as_of_date (data) = 2026-08-03
#   brands            = ['realprize', 'lonestar']
#   run_ts (export)   = 110733  (unique each time this cell runs)
# Saved in working directory:
#   combined_goals_2026-08-03_rp_ls_winsor_esc_ls_app_110733.csv
#   combined_goals_detail_2026-08-03_rp_ls_winsor_esc_ls_app_110733.csv
#   combined_arpu_curve_2026-08-03_rp_ls_winsor_esc_ls_app_110733.csv
#   combined_organic_share_2026-08-03_rp_ls_winsor_esc_ls_app_110733.csv
#   combined_cv_summary_2026-08-03_rp_ls_winsor_esc_ls_app_110733_adaptive_test.csv
#
# Also wrote to: /content/drive/MyDrive/lee_project/marketing_goals/runs/2026-08-03_rp_ls_winsor_esc_ls_app_110733
# (Each re-run creates a NEW folder under runs/ — previous runs stay.)
# Downloads started in browser.
