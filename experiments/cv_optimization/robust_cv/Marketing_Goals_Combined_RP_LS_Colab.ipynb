# %% [markdown]
# # Marketing Goals — Combined (RealPrize + LoneStar) · **Colab**
#
# *Lee Jerusalmy*
#
# Unified goals run for **RP + LS** in Google Colab.
# Logic matches `Marketing_Goals_Combined_RP_LS.ipynb` (Cursor/local twin); this file is Colab-only auth + downloads.
#
# ### Locked main columns
# `brand`, `population`, `goal_horizon`, `day`, `raw_goal_ratio`, `organic_share`, `adjusted_goal_ratio`
#
# ### How to run
# 1. **Runtime → Run all** (or top → bottom).
# 2. First cell: click allow for Google auth.
# 3. Optional: mount Drive if you want CSVs under `lee_project/marketing_goals/runs/`.
# 4. Keep `MONITOR_STEPS = True` to see intermediate tables after each part.
#
# ### Monitoring
# While the RUN cell executes you will see, per brand:
# 1. **Data load** — population counts, cost_date span, scope×bucket (RP)
# 2. **Part 1** — CV table + ARPU milestones
# 3. **Part 2** — Blended
# 4. **Part 3** — organic share endpoints
# 5. **Part 4** — sample goals (raw / organic / adjusted)
#
# Do not edit `reference/`. Knobs mirror `config/realprize.yaml` + `config/lonestar.yaml`.
#
# ---
# ### CV experiment: **robust_cv**
# Lives under `experiments/cv_optimization/robust_cv/`.
# Keeps existing CV / trim / goals unchanged. Adds **Robust CV = 1.4826 × MAD / median** on the same growth ratios used for `cv_before` / `cv_after`.
# Also for this test: LS `cv_threshold` unified to **0.15**; `AS_OF_DATE` pinned to **2026-08-03**.
# Does **not** replace CV or change flagged logic.

# %%
# ── Auth (Google Colab) ──────────────────────────────────────────
from google.colab import auth
auth.authenticate_user()
IN_COLAB = True
print('Authenticated (Colab)')
# Out:
# Authenticated (Colab)

# %%
project_id = 'oceanic-citadel-454608-d2'
from google.cloud import bigquery
client = bigquery.Client(project=project_id)
print('BigQuery client ready for', project_id)
# Out:
# BigQuery client ready for oceanic-citadel-454608-d2

# %%
# ── Optional: mount Google Drive (to write under marketing_goals/runs/) ──
# Skip this cell if you only want browser downloads.

MOUNT_DRIVE = True  # set False to skip

if MOUNT_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    print('Drive mounted. Expected runs path:')
    print('  /content/drive/MyDrive/lee_project/marketing_goals/runs')
    print('  (or My Drive with a space — export cell checks both)')
else:
    print('Drive mount skipped — export will browser-download CSVs only.')
# Out:
# Mounted at /content/drive
# Drive mounted. Expected runs path:
#   /content/drive/MyDrive/lee_project/marketing_goals/runs
#   (or My Drive with a space — export cell checks both)

# %%
import pandas as pd
import numpy as np
from pandas_gbq import read_gbq

# ── Date anchor (shared for both brands) ──
# CHANGED (temporary for testing): pin AS_OF to match prior CV test runs.
# REVERT for production to: pd.Timestamp.now().normalize() - pd.Timedelta(days=2)
AS_OF_DATE = pd.Timestamp('2026-08-03')

# ── Shared patch / horizon calendar ──
PATCHES = (
    (1, 7), (7, 14), (14, 30), (30, 60), (60, 90),
    (90, 120), (120, 150), (150, 180), (180, 270), (270, 365),
)
GOAL_HORIZONS = [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
CHECKPOINTS   = [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
LOOKBACK_COHORTS = 35
EXPERIMENT_TAG = 'robust_cv'  # ADDED: distinct runs/ folder + CSV names
ORGANIC_LABEL = 'Organic'

# ── Which brands to run ──
RUN_BRANDS = ['realprize', 'lonestar']

# ── Per-brand knobs (from config/*.yaml / Combined predecessors) ──
BRAND_CONFIGS = {
    'realprize': {
        'brand': 'realprize',
        'cost_table': 'analytics.realprize_cost_per_user',
        'deposits_table': 'realprize.casino_astropay_dmn',
        # TikTok excluded entirely
        'exclude_affids': [4313],
        'populations': ['Web', 'App', 'Affiliate'],
        'trim_config': {
            'App':       {'method': 'winsor', 'pct': 0},
            'Web':       {'method': 'winsor', 'pct': 0.01},
            'Affiliate': {'method': 'winsor', 'pct': 0.01},
            'Blended':   {'method': 'winsor', 'pct': 0},
        },
        'organic_trim_method': 'winsor',
        'organic_trim_pct': 0,
        # App attribution change ~2025-08-12 — pin share above this horizon
        'organic_share_cap_horizon': 120,
        'cv_threshold': 0.15,
        'cv_good_enough': 0.10,
        'max_remove_fraction': 0.15,
        # RP Combined did not use a min-cohort-dates gate (default 1)
        'min_cohort_dates': 1,
        # Tail fill only in LS predecessor
        'extrapolate_tail': False,
        'extrapolation_tail_days': 30,
        'has_scope_bucket': True,  # app / non_app + app_organic
        'users_sql': None,  # filled below via builder
    },
    'lonestar': {
        'brand': 'lonestar',
        'cost_table': 'analytics.lonestar_cost_per_user',
        'deposits_table': 'lonestar.casino_astropay_dmn',
        # TikTok + TikTok Canada
        'exclude_affids': [4866, 7127],
        'populations': ['Web', 'Affiliate'],  # add App when LS App launches
        'trim_config': {
            'Web':       {'method': 'winsor', 'pct': 0},
            'Affiliate': {'method': 'winsor', 'pct': 0.01},
            'Blended':   {'method': 'winsor', 'pct': 0},
        },
        'organic_trim_method': 'winsor',
        'organic_trim_pct': 0,
        # No organic share cap on LS
        'organic_share_cap_horizon': None,
        'cv_threshold': 0.15,  # CHANGED: LS threshold now 0.15 (unified with RP for this test),
        'cv_good_enough': 0.10,
        'max_remove_fraction': 0.15,
        'min_cohort_dates': 20,
        'extrapolate_tail': True,
        'extrapolation_tail_days': 30,
        'has_scope_bucket': False,  # scope defaults to 'all' in organic helper
        'users_sql': None,
    },
}

# ── Monitoring (print sub-outputs after each pipeline step) ──
# True  = show intermediate tables in Colab after each part (recommended first runs)
# False = quieter (still prints step banners + row counts)
MONITOR_STEPS = True
MONITOR_PREVIEW_DAYS = [1, 7, 14, 30, 60, 90, 120, 180, 270, 365]
MONITOR_PREVIEW_HORIZONS = [7, 30, 120, 365]  # goals sample only

print('ENV: Google Colab')

# ── Seed Combined globals (overwritten per brand in apply_brand_globals) ──
# Helper cells use these names as defaults; they MUST exist before those cells run.
POPULATIONS = list(BRAND_CONFIGS['realprize']['populations'])  # first brand's list as placeholder
TRIM_CONFIG = dict(BRAND_CONFIGS['realprize']['trim_config'])
ORGANIC_TRIM_METHOD = BRAND_CONFIGS['realprize']['organic_trim_method']
ORGANIC_TRIM_PCT = BRAND_CONFIGS['realprize']['organic_trim_pct']
ORGANIC_SHARE_CAP_HORIZON = BRAND_CONFIGS['realprize']['organic_share_cap_horizon']
CV_THRESHOLD = BRAND_CONFIGS['realprize']['cv_threshold']
CV_GOOD_ENOUGH = BRAND_CONFIGS['realprize']['cv_good_enough']
MAX_REMOVE_FRACTION = BRAND_CONFIGS['realprize']['max_remove_fraction']
MIN_COHORT_DATES = BRAND_CONFIGS['realprize']['min_cohort_dates']
EXTRAPOLATE_TAIL = BRAND_CONFIGS['realprize']['extrapolate_tail']
EXTRAPOLATION_TAIL_DAYS = BRAND_CONFIGS['realprize']['extrapolation_tail_days']
ACTIVE_BRAND = None

print(f'Config loaded. as_of_date = {AS_OF_DATE.date()}')
print(f'Brands to run: {RUN_BRANDS}')
print(f'Monitor steps = {MONITOR_STEPS}')
print('Mode: PERSISTENT TRIM (excluded users carry forward)')
print('Main goals columns: brand, population, goal_horizon, day, raw_goal_ratio, organic_share, adjusted_goal_ratio')
# Out:
# ENV: Google Colab
# Config loaded. as_of_date = 2026-08-03
# Brands to run: ['realprize', 'lonestar']
# Monitor steps = True
# Mode: PERSISTENT TRIM (excluded users carry forward)
# Main goals columns: brand, population, goal_horizon, day, raw_goal_ratio, organic_share, adjusted_goal_ratio

# %%
# ══════════════════════════════════════════════════════════════
# APPLY BRAND CONFIG → module-level globals used by helpers
# (same variable names as Combined predecessors)
# ══════════════════════════════════════════════════════════════

def apply_brand_globals(cfg: dict) -> None:
    """Set Combined-style globals for one brand before running the pipeline."""
    global POPULATIONS, TRIM_CONFIG
    global ORGANIC_TRIM_METHOD, ORGANIC_TRIM_PCT, ORGANIC_SHARE_CAP_HORIZON
    global CV_THRESHOLD, CV_GOOD_ENOUGH, MAX_REMOVE_FRACTION
    global MIN_COHORT_DATES, EXTRAPOLATE_TAIL, EXTRAPOLATION_TAIL_DAYS
    global ACTIVE_BRAND

    ACTIVE_BRAND = cfg['brand']
    POPULATIONS = list(cfg['populations'])
    TRIM_CONFIG = dict(cfg['trim_config'])
    ORGANIC_TRIM_METHOD = cfg['organic_trim_method']
    ORGANIC_TRIM_PCT = cfg['organic_trim_pct']
    ORGANIC_SHARE_CAP_HORIZON = cfg['organic_share_cap_horizon']
    CV_THRESHOLD = cfg['cv_threshold']
    CV_GOOD_ENOUGH = cfg['cv_good_enough']
    MAX_REMOVE_FRACTION = cfg['max_remove_fraction']
    MIN_COHORT_DATES = cfg['min_cohort_dates']
    EXTRAPOLATE_TAIL = cfg['extrapolate_tail']
    EXTRAPOLATION_TAIL_DAYS = cfg['extrapolation_tail_days']

    print(f"\n{'=' * 60}")
    print(f"BRAND: {ACTIVE_BRAND}")
    print(f"  populations = {POPULATIONS}")
    print(f"  CV threshold = {CV_THRESHOLD}  good_enough = {CV_GOOD_ENOUGH}")
    print(f"  min_cohort_dates = {MIN_COHORT_DATES}")
    print(f"  extrapolate_tail = {EXTRAPOLATE_TAIL}")
    print(f"  organic_share_cap_horizon = {ORGANIC_SHARE_CAP_HORIZON}")
    print(f"{'=' * 60}")


def load_brand_tables(cfg: dict, as_of_date=AS_OF_DATE):
    """Pull cost-per-user population assignment + deposit revenue for one brand."""
    sql_floor = (
        as_of_date - pd.Timedelta(days=max(GOAL_HORIZONS) + LOOKBACK_COHORTS + 5)
    ).date()
    brand = cfg['brand']
    cost_table = cfg['cost_table']
    dep_table = cfg['deposits_table']
    excl = cfg['exclude_affids']
    excl_sql = ', '.join(str(a) for a in excl)

    print(f'[{brand}] SQL floor date: {sql_floor}  (AS_OF_DATE = {as_of_date.date()})')

    if brand == 'realprize':
        # scope + bucket for App organic vs non_app organic
        users_sql = f"""
        SELECT
          id,
          CASE
            WHEN affid IN (63, 2521, 2535, 4957, 4971, 5048, 5062, 5069) THEN 'Web'
            WHEN affid = 1                                    THEN 'App'
            WHEN affid IN (64, 71)                            THEN 'PPC'
            WHEN affid IN (0, 78, 2290)                       THEN 'Organic'
            ELSE 'Affiliate'
          END AS population,
          CASE WHEN affid = 1 THEN 'app' ELSE 'non_app' END AS scope,
          CASE
            WHEN affid = 1 AND channel_type = 'app_organic' THEN 'organic'
            WHEN affid = 1                                   THEN 'acquired'
            WHEN affid IN (0, 78, 2290)                      THEN 'organic'
            ELSE 'acquired'
          END AS bucket,
          DATE(MIN(cost_date)) AS cost_date
        FROM `{cost_table}`
        WHERE cost_date >= DATE('{sql_floor}')
          AND affid NOT IN ({excl_sql})
          AND id > 0
        GROUP BY id, population, scope, bucket
        """
    elif brand == 'lonestar':
        # No scope/bucket — organic helper defaults to scope='all'
        users_sql = f"""
        SELECT
          id,
          CASE
            WHEN affid IN (63, 4432, 4551, 4698, 5048, 5125, 7120, 7253, 7260, 8331, 8345) THEN 'Web'
            -- WHEN affid = 1 THEN 'App'   -- uncomment when LS App launches
            WHEN affid IN (64, 71)  THEN 'PPC'
            WHEN affid IN (0, 78)   THEN 'Organic'
            ELSE 'Affiliate'
          END AS population,
          DATE(MIN(cost_date)) AS cost_date
        FROM `{cost_table}`
        WHERE cost_date >= DATE('{sql_floor}')
          AND affid NOT IN ({excl_sql})
          AND id > 0
        GROUP BY 1, 2
        """
    else:
        raise ValueError(f'Unknown brand: {brand}')

    revenue_sql = f"""
    SELECT
      playerId AS playerid,
      DATE(date) AS date,
      SUM(amount) / 100.0 AS amount
    FROM `{dep_table}`
    WHERE Status = 'APPROVED'
      AND date >= DATE('{sql_floor}')
    GROUP BY 1, 2
    """

    users_df = read_gbq(users_sql, project_id=project_id, use_bqstorage_api=True)
    revenue_df = read_gbq(revenue_sql, project_id=project_id, use_bqstorage_api=True)

    print(f'[{brand}] users_df:   {len(users_df):,} rows')
    print(f'[{brand}] revenue_df: {len(revenue_df):,} rows')
    print(users_df['population'].value_counts().to_string())
    return users_df, revenue_df

print('Brand loader + apply_brand_globals ready.')
# Out:
# Brand loader + apply_brand_globals ready.

# %%
# ══════════════════════════════════════════════════════════════
# HELPERS — math & base table construction
# ══════════════════════════════════════════════════════════════

def weighted_mean_std_cv(x, w):
    x = np.asarray(x, dtype=float)
    w = np.asarray(w, dtype=float)
    m = np.isfinite(x) & np.isfinite(w) & (w > 0)
    x, w = x[m], w[m]
    if x.size == 0:
        return np.nan, np.nan, np.nan
    mu  = np.average(x, weights=w)
    var = np.average((x - mu) ** 2, weights=w)
    sd  = np.sqrt(var)
    cv  = sd / mu if mu != 0 else np.nan
    return mu, sd, cv


def build_user_revenue_cums(users_df, revenue_df, *, max_day=365):
    """
    Precompute cumulative per-user revenue indexed by (population, cost_date, user, dsi).
    Returns:
      u          — one row per (population, user) with their earliest cost_date
      daily_user — cumulative revenue at each (population, cost_date, user, dsi)
    """
    u = users_df[['id', 'population', 'cost_date']].copy()
    u['population'] = u['population'].astype(str).str.strip()
    u['cost_date']  = pd.to_datetime(u['cost_date'], errors='coerce').dt.date
    u = u.loc[pd.notna(u['cost_date'])].copy()
    u = u.groupby(['population', 'id'], as_index=False)['cost_date'].min()
    u = u.rename(columns={'id': '__uid__'})

    r = revenue_df[['playerid', 'date', 'amount']].copy()
    r['date'] = pd.to_datetime(r['date'], errors='coerce').dt.date
    r = r.loc[pd.notna(r['date'])].copy()

    rr = r.merge(u, left_on='playerid', right_on='__uid__', how='inner')
    rr['dsi'] = (pd.to_datetime(rr['date']) - pd.to_datetime(rr['cost_date'])).dt.days
    rr = rr.loc[(rr['dsi'] >= 0) & (rr['dsi'] <= (max_day - 1))].copy()

    daily_user = (
        rr.groupby(['population', 'cost_date', '__uid__', 'dsi'], observed=True)['amount']
          .sum().reset_index()
          .sort_values(['population', 'cost_date', '__uid__', 'dsi'])
    )
    daily_user['cum_amount'] = (
        daily_user.groupby(['population', 'cost_date', '__uid__'], observed=True)['amount']
                  .cumsum()
    )
    return u, daily_user




# ══════════════════════════════════════════════════════════════
# ADDED: robust CV experiment helpers (does NOT replace existing CV)
# Robust CV = 1.4826 * MAD / median  on the same growth_ratio values
# used for cv_before / cv_after (finite observations only).
# ══════════════════════════════════════════════════════════════

ROBUST_CV_CONST = 1.4826  # ADDED: Gaussian consistency constant for MAD

# ADDED: relative classification vs standard CV (easy to retune)
# OUTLIER_DRIVEN:        robust_to_standard_cv_ratio <= ROBUST_OUTLIER_RATIO_MAX
# CONSISTENT_VARIABILITY: ratio in (ROBUST_OUTLIER_RATIO_MAX, ROBUST_CONSISTENT_RATIO_MAX]
# REVIEW:                otherwise / missing
ROBUST_OUTLIER_RATIO_MAX = 0.70
ROBUST_CONSISTENT_RATIO_MAX = 1.15


def robust_cv_mad(x):
    """ADDED: unweighted Robust CV on cohort-level growth ratios."""
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    if x.size < 2:
        return np.nan
    med = np.median(x)
    if med == 0:
        return np.nan
    mad = np.median(np.abs(x - med))
    return ROBUST_CV_CONST * mad / med


def _finite_or_none(v):
    """ADDED: JSON/CSV-safe float."""
    if v is None:
        return None
    try:
        v = float(v)
    except (TypeError, ValueError):
        return None
    if np.isnan(v) or np.isinf(v):
        return None
    return v


def variability_diagnosis(cv_after, robust_cv_after, ratio):
    """ADDED: relative CV vs Robust CV label (no absolute Robust threshold)."""
    if ratio is None or cv_after is None or robust_cv_after is None:
        return 'REVIEW'
    if ratio <= ROBUST_OUTLIER_RATIO_MAX:
        return 'OUTLIER_DRIVEN'
    if ratio <= ROBUST_CONSISTENT_RATIO_MAX:
        return 'CONSISTENT_VARIABILITY'
    return 'REVIEW'


def robust_cv_compare_fields(cv_after, robust_cv_before, robust_cv_after):
    """ADDED: comparison diagnostics; safe on zero/null."""
    cv_a = _finite_or_none(cv_after)
    r_b = _finite_or_none(robust_cv_before)
    r_a = _finite_or_none(robust_cv_after)
    if cv_a is None or r_a is None:
        diff = None
        ratio = None
    else:
        diff = cv_a - r_a
        ratio = (r_a / cv_a) if cv_a != 0 else None
    return dict(
        robust_cv_before=r_b,
        robust_cv_after=r_a,
        cv_minus_robust_cv_after=diff,
        robust_to_standard_cv_ratio=ratio,
        variability_diagnosis=variability_diagnosis(cv_a, r_a, ratio),
    )


print('Math + base table helpers defined (+ robust CV experiment helpers).')
# Out:
# Math + base table helpers defined (+ robust CV experiment helpers).

# %%
# ══════════════════════════════════════════════════════════════
# HELPERS — trimming & cohort revenue summation
# ══════════════════════════════════════════════════════════════

def compute_winsor_caps(daily_user_cums, cohort_users, e, top_pct=0.01):
    """Cap per-user cumulative revenue at the (1-top_pct) quantile within each cohort date."""
    if top_pct <= 0:
        caps = cohort_users[['population', 'cost_date', '__uid__']].copy()
        caps['cap_e'] = np.inf
        return caps
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= (e - 1)].copy()
    if du.empty:
        caps = cohort_users[['population', 'cost_date', '__uid__']].copy()
        caps['cap_e'] = np.inf
        return caps
    per_user = (
        du.groupby(['population', 'cost_date', '__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum_e')
    )
    per_user = cohort_users.merge(per_user, on=['population', 'cost_date', '__uid__'], how='left')
    per_user['cum_e'] = per_user['cum_e'].fillna(0.0)
    per_user['cap_e'] = (
        per_user.groupby(['population', 'cost_date'], observed=True)['cum_e']
                .transform(lambda s: s[s > 0].quantile(1.0 - top_pct) if (s > 0).any() else np.inf)
    )
    return per_user[['population', 'cost_date', '__uid__', 'cap_e']]


def apply_cohort_trim(daily_user_cums, cohort_users, e, trim_pct=0.10):
    """Remove the top trim_pct of depositors (by cumulative revenue) from each cohort date."""
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= (e - 1)].copy()
    if du.empty:
        return cohort_users.copy()
    per_user = (
        du.groupby(['population', 'cost_date', '__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum_e')
    )
    per_user = cohort_users.merge(per_user, on=['population', 'cost_date', '__uid__'], how='left')
    per_user['cum_e'] = per_user['cum_e'].fillna(0.0)
    depositors = per_user.loc[per_user['cum_e'] > 0].copy()
    if depositors.empty:
        return cohort_users.copy()
    thresholds = (
        depositors.groupby(['population', 'cost_date'], observed=True)['cum_e']
                  .quantile(1.0 - trim_pct).reset_index(name='threshold')
    )
    per_user = per_user.merge(thresholds, on=['population', 'cost_date'], how='left')
    per_user['threshold'] = per_user['threshold'].fillna(np.inf)
    keep = per_user.loc[
        (per_user['cum_e'] == 0) | (per_user['cum_e'] <= per_user['threshold'])
    ][['population', 'cost_date', '__uid__']]
    return keep.copy()


def get_trimmed_cohort_and_caps(population, cohort_users, daily_user_cums, e):
    cfg = TRIM_CONFIG.get(population, {'method': 'cohort_trim', 'pct': 0.10})
    caps, trimmed = None, cohort_users
    if cfg['method'] == 'winsor':
        caps = compute_winsor_caps(daily_user_cums, cohort_users, e, top_pct=cfg['pct'])
    elif cfg['method'] == 'cohort_trim':
        trimmed = apply_cohort_trim(daily_user_cums, cohort_users, e, trim_pct=cfg['pct'])
    return trimmed, caps


def sum_cum_at_idx(daily_user_cums, *, cohort_users, idx, caps=None):
    """Sum cumulative revenue across all users in cohort_users at day index idx."""
    grp_cols = ['population', 'cost_date']
    if idx < 0:
        out = cohort_users.groupby(grp_cols, observed=True)['__uid__'].nunique().reset_index()
        out['sum_cum'] = 0.0
        return out[grp_cols + ['sum_cum']]
    du = daily_user_cums.loc[daily_user_cums['dsi'] <= idx].copy()
    if du.empty:
        out = cohort_users.groupby(grp_cols, observed=True)['__uid__'].nunique().reset_index()
        out['sum_cum'] = 0.0
        return out[grp_cols + ['sum_cum']]
    per_user = (
        du.groupby(grp_cols + ['__uid__'], observed=True)['cum_amount']
          .max().reset_index(name='cum')
    )
    per_user = cohort_users.merge(per_user, on=grp_cols + ['__uid__'], how='left')
    per_user['cum'] = per_user['cum'].fillna(0.0)
    if caps is not None:
        per_user = per_user.merge(caps, on=grp_cols + ['__uid__'], how='left')
        per_user['cap_e'] = per_user['cap_e'].fillna(np.inf)
        per_user['cum']   = np.minimum(per_user['cum'], per_user['cap_e'])
    sums = per_user.groupby(grp_cols, observed=True)['cum'].sum().reset_index(name='sum_cum')
    return sums


print('Trim + summation helpers defined.')
# Out:
# Trim + summation helpers defined.

# %%
# ══════════════════════════════════════════════════════════════
# ADAPTIVE CV ANALYSIS — persistent trim
# ══════════════════════════════════════════════════════════════

def patch_cv_adaptive(
    u_base, daily_user_cums, *,
    population, s, e, as_of_date,
    excluded_uids=None,
    lookback_cohorts=None,
    cv_threshold=None,
    cv_good_enough=None,
    max_remove_fraction=None,
    debug=True,
):
    # Resolve defaults at call time (after brand config applied)
    if lookback_cohorts is None:
        lookback_cohorts = LOOKBACK_COHORTS
    if cv_threshold is None:
        cv_threshold = CV_THRESHOLD
    if cv_good_enough is None:
        cv_good_enough = CV_GOOD_ENOUGH
    if max_remove_fraction is None:
        max_remove_fraction = MAX_REMOVE_FRACTION
    as_of_date   = pd.to_datetime(as_of_date).normalize()
    cohort_end   = (as_of_date - pd.Timedelta(days=e)).date()
    cohort_start = (as_of_date - pd.Timedelta(days=e + (lookback_cohorts - 1))).date()

    cohort_users = u_base.loc[
        (u_base['population'] == population) &
        (u_base['cost_date'] >= cohort_start) &
        (u_base['cost_date'] <= cohort_end)
    ][['population', 'cost_date', '__uid__']].copy()

    if cohort_users.empty:
        return pd.DataFrame(), {}, [], False, set()

    all_cohort_users = cohort_users.copy()
    n_users_in_cohort = int(cohort_users['__uid__'].nunique())

    if excluded_uids:
        cohort_users = cohort_users.loc[
            ~cohort_users['__uid__'].isin(excluded_uids)
        ].copy()

    n_users_after_prior = int(cohort_users['__uid__'].nunique())
    n_users_excluded_prior = n_users_in_cohort - n_users_after_prior

    if cohort_users.empty:
        return pd.DataFrame(), {}, [], False, set()

    trimmed_users, caps = get_trimmed_cohort_and_caps(
        population, cohort_users, daily_user_cums, e
    )
    n_users_pre_trim  = n_users_after_prior
    n_users_post_trim = int(trimmed_users['__uid__'].nunique())

    newly_excluded = (
        set(cohort_users['__uid__'].unique()) - set(trimmed_users['__uid__'].unique())
    )

    denom_w = (
        trimmed_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                     .nunique().reset_index(name='N_users')
    )
    sum_s = sum_cum_at_idx(
        daily_user_cums, cohort_users=trimmed_users, idx=s - 1, caps=caps
    ).rename(columns={'sum_cum': 'sum_cum_s'})
    sum_e = sum_cum_at_idx(
        daily_user_cums, cohort_users=trimmed_users, idx=e - 1, caps=caps
    ).rename(columns={'sum_cum': 'sum_cum_e'})

    sum_e_all = sum_cum_at_idx(
        daily_user_cums, cohort_users=all_cohort_users, idx=e - 1, caps=None
    ).rename(columns={'sum_cum': 'sum_cum_e_all'})
    total_rev_before_trim = float(sum_e_all['sum_cum_e_all'].sum())

    patch = (
        denom_w
        .merge(sum_s, on=['population', 'cost_date'])
        .merge(sum_e, on=['population', 'cost_date'])
    )
    patch['ARPU_s']       = patch['sum_cum_s'] / patch['N_users']
    patch['ARPU_e']       = patch['sum_cum_e'] / patch['N_users']
    patch['growth_ratio'] = np.where(
        patch['ARPU_s'] > 0, patch['ARPU_e'] / patch['ARPU_s'], np.nan
    )

    _, _, cv_before = weighted_mean_std_cv(patch['growth_ratio'].values, patch['sum_cum_s'].values)
    # ADDED: robust CV on the SAME pre-removal growth_ratio observations
    robust_cv_before = robust_cv_mad(patch['growth_ratio'].values)

    mu_unw = np.nanmean(patch['growth_ratio'].values)
    patch['abs_dev'] = (patch['growth_ratio'] - mu_unw).abs()
    sorted_dates  = patch.sort_values('abs_dev', ascending=False)['cost_date'].tolist()
    max_removable = max(1, int(np.floor(len(patch) * max_remove_fraction)))

    removed   = []
    remaining = patch.copy()

    for candidate in sorted_dates:
        _, _, cv_now = weighted_mean_std_cv(
            remaining['growth_ratio'].values, remaining['sum_cum_s'].values
        )
        if np.isnan(cv_now) or cv_now <= cv_good_enough:
            break
        if len(removed) >= max_removable:
            break
        removed.append(candidate)
        remaining = remaining.loc[~remaining['cost_date'].isin(removed)]

    mean_a, _, cv_after = weighted_mean_std_cv(
        remaining['growth_ratio'].values, remaining['sum_cum_s'].values
    )
    # ADDED: robust CV on the SAME post-removal growth_ratio observations
    robust_cv_after = robust_cv_mad(remaining['growth_ratio'].values)
    flagged = (not np.isnan(cv_after)) and (cv_after > cv_threshold)
    total_rev_after_trim = float(patch['sum_cum_e'].sum())
    cfg = TRIM_CONFIG.get(population, {})

    if debug:
        flag_tag = f'  >>> FLAGGED (cv={cv_after:.4f} > {cv_threshold})' if flagged else ''
        rcv_b = robust_cv_before if not np.isnan(robust_cv_before) else float('nan')
        rcv_a = robust_cv_after if not np.isnan(robust_cv_after) else float('nan')
        print(
            f'  [{population}] {s}->{e}  '
            f'cv {cv_before:.4f}->{cv_after:.4f}  '
            f'robust_cv {rcv_b:.4f}->{rcv_a:.4f}  '  # ADDED
            f'removed={len(removed)}/{len(patch)}  '
            f'excl_prior={n_users_excluded_prior:,}  '
            f'pre/post={n_users_pre_trim:,}/{n_users_post_trim:,}  '
            f'newly_excl={len(newly_excluded):,}{flag_tag}'
        )

    stats = dict(
        population              = population,
        patch                   = f'{s}->{e}',
        cohort_start            = str(cohort_start),
        cohort_end              = str(cohort_end),
        n_cohort_dates_total    = int(len(patch)),
        n_cohort_dates_kept     = int(len(remaining)),
        n_users_excluded_prior  = n_users_excluded_prior,
        n_users_pre_trim        = n_users_pre_trim,
        n_users_post_trim       = n_users_post_trim,
        n_users_dropped_by_trim = n_users_pre_trim - n_users_post_trim,
        total_rev_before_trim   = total_rev_before_trim,
        total_rev_after_trim    = total_rev_after_trim,
        cv_before               = float(cv_before) if not np.isnan(cv_before) else None,
        cv_after                = float(cv_after)  if not np.isnan(cv_after)  else None,
        mean_after              = float(mean_a)    if not np.isnan(mean_a)    else None,
        flagged                 = bool(flagged),
        removed_dates           = removed,
        trim_method             = cfg.get('method', 'none'),
        trim_pct                = cfg.get('pct', 0),
    )
    # ADDED: robust CV comparison diagnostics (CV methodology unchanged)
    stats.update(robust_cv_compare_fields(cv_after, robust_cv_before, robust_cv_after))
    # keep explicit float/None for cv_* already set above
    return patch, stats, removed, flagged, newly_excluded


print('Adaptive CV function defined (persistent trim + robust CV diagnostics).')
# Out:
# Adaptive CV function defined (persistent trim + robust CV diagnostics).

# %%
# ══════════════════════════════════════════════════════════════
# PERSISTENT TRIM CURVE BUILDER (two-pass)
# ══════════════════════════════════════════════════════════════

def build_curve(
    u_base, daily_user_cums, *,
    population, as_of_date, debug=True,
):
    """Build ARPU curve with persistent trim — excluded users carry forward.
    Two-pass: first pass accumulates all exclusions unconditionally,
    second pass builds step ratios using frozen snapshots."""
    as_of_date = pd.to_datetime(as_of_date).normalize()

    cv_rows      = []
    effective    = []
    excluded_uids = set()

    # ── First pass: determine valid patches & accumulate exclusions ──
    for (s, e) in PATCHES:
        patch, stats, removed, flagged, newly_excluded = patch_cv_adaptive(
            u_base, daily_user_cums,
            population=population, s=s, e=e,
            as_of_date=as_of_date,
            excluded_uids=excluded_uids,
            debug=debug,
        )
        excluded_uids |= newly_excluded

        if not stats:
            continue

        min_cohort_dates = globals().get('MIN_COHORT_DATES', 1)
        if stats.get('n_cohort_dates_total', 0) < min_cohort_dates:
            if debug:
                print(f'  [{population}] {s}->{e}  insufficient data '
                      f'({stats["n_cohort_dates_total"]} < {min_cohort_dates}) — skipping')
            continue

        cv_rows.append(stats)
        effective.append({
            's': s, 'e': e,
            'removed_dates': removed,
            'excluded_snapshot': frozenset(excluded_uids),
        })

    if not effective:
        return pd.DataFrame(cv_rows), pd.DataFrame()

    if debug:
        print(f'  Total unique users excluded across all patches: {len(excluded_uids):,}')

    # ── Second pass: build step ratios using frozen snapshots ──
    step_rows = []
    for ep in effective:
        s, e      = ep['s'], ep['e']
        bad_dates = set(ep['removed_dates'])
        excl      = ep['excluded_snapshot']
        start_k   = 2 if s == 1 else (s + 1)

        cohort_end   = (as_of_date - pd.Timedelta(days=e)).date()
        cohort_start = (as_of_date - pd.Timedelta(days=e + (LOOKBACK_COHORTS - 1))).date()

        cohort_users = u_base.loc[
            (u_base['population'] == population) &
            (u_base['cost_date'] >= cohort_start) &
            (u_base['cost_date'] <= cohort_end)
        ][['population', 'cost_date', '__uid__']].copy()

        if bad_dates:
            cohort_users = cohort_users.loc[~cohort_users['cost_date'].isin(bad_dates)].copy()
        if excl:
            cohort_users = cohort_users.loc[~cohort_users['__uid__'].isin(excl)].copy()
        if cohort_users.empty:
            continue

        _, caps = get_trimmed_cohort_and_caps(population, cohort_users, daily_user_cums, e)
        denom_w = (
            cohort_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                        .nunique().reset_index(name='N_users')
        )

        for k in range(start_k, e + 1):
            sum_prev = sum_cum_at_idx(
                daily_user_cums, cohort_users=cohort_users, idx=k - 2, caps=caps
            ).rename(columns={'sum_cum': 'sum_prev'})
            sum_curr = sum_cum_at_idx(
                daily_user_cums, cohort_users=cohort_users, idx=k - 1, caps=caps
            ).rename(columns={'sum_cum': 'sum_curr'})
            tmp = (
                denom_w
                .merge(sum_prev, on=['population', 'cost_date'])
                .merge(sum_curr, on=['population', 'cost_date'])
            )
            tmp['ARPU_prev']  = tmp['sum_prev'] / tmp['N_users']
            tmp['ARPU_curr']  = tmp['sum_curr'] / tmp['N_users']
            tmp['step_ratio'] = np.where(
                tmp['ARPU_prev'] > 0, tmp['ARPU_curr'] / tmp['ARPU_prev'], np.nan
            )
            mean_step, _, _ = weighted_mean_std_cv(
                tmp['step_ratio'].values, tmp['sum_prev'].values
            )
            step_rows.append({
                'population':      population,
                'day':             int(k),
                'growth_step':     float(mean_step),
                'effective_patch': f'{s}->{e}',
            })

    if not step_rows:
        return pd.DataFrame(cv_rows), pd.DataFrame()

    step_df = pd.DataFrame(step_rows).sort_values('day').reset_index(drop=True)

    # ── Base ARPU from first effective patch ──
    first      = effective[0]
    fs, fe     = first['s'], first['e']
    excl_first = first['excluded_snapshot']
    base_end   = (as_of_date - pd.Timedelta(days=fe)).date()
    base_start = (as_of_date - pd.Timedelta(days=fe + (LOOKBACK_COHORTS - 1))).date()

    base_users = u_base.loc[
        (u_base['population'] == population) &
        (u_base['cost_date'] >= base_start) &
        (u_base['cost_date'] <= base_end)
    ][['population', 'cost_date', '__uid__']].copy()
    bad_first = set(first['removed_dates'])
    if bad_first:
        base_users = base_users.loc[~base_users['cost_date'].isin(bad_first)].copy()
    if excl_first:
        base_users = base_users.loc[~base_users['__uid__'].isin(excl_first)].copy()

    _, base_caps = get_trimmed_cohort_and_caps(population, base_users, daily_user_cums, fe)
    denom_base = (
        base_users.groupby(['population', 'cost_date'], observed=True)['__uid__']
                  .nunique().reset_index(name='N_users')
    )
    start_idx = 0 if fs == 1 else (fs - 1)
    sum_day1 = sum_cum_at_idx(
        daily_user_cums, cohort_users=base_users, idx=start_idx, caps=base_caps
    ).rename(columns={'sum_cum': 'sum_day1'})
    base = denom_base.merge(sum_day1, on=['population', 'cost_date'], how='inner')
    pooled_arpu_1 = (
        base['sum_day1'].sum() / base['N_users'].sum()
        if base['N_users'].sum() > 0 else 0.0
    )

    start_day = 1 if fs == 1 else fs
    out_rows  = [{'population': population, 'day': start_day,
                  'ARPU_nominal': float(pooled_arpu_1),
                  'growth_step':  np.nan,
                  'effective_patch': f'{fs}->{fe}'}]
    arpu = float(pooled_arpu_1)
    for _, row in step_df.iterrows():
        g = row['growth_step']
        if not np.isfinite(g):
            continue
        arpu *= float(g)
        out_rows.append({'population': population, 'day': int(row['day']),
                         'ARPU_nominal': float(arpu),
                         'growth_step':  float(g),
                         'effective_patch': row['effective_patch']})

    curve = pd.DataFrame(out_rows).sort_values('day').reset_index(drop=True)
    all_days = pd.DataFrame({'day': range(start_day, 366)})
    curve    = all_days.merge(curve, on='day', how='left')
    curve['population']      = population
    curve['effective_patch'] = curve['effective_patch'].ffill()
    curve['ARPU_nominal']    = curve['ARPU_nominal'].interpolate(
        method='linear', limit_area='inside'
    )
    curve = curve.dropna(subset=['ARPU_nominal']).reset_index(drop=True)
    curve['is_extrapolated'] = False

    return pd.DataFrame(cv_rows), curve


def extrapolate_curve_tail(curve, *, up_to_day=365, tail_days=30, debug=True):
    """Extend curve to up_to_day using geometric mean of last tail_days daily growth steps."""
    if curve.empty:
        return curve

    population    = curve['population'].iloc[0]
    last_real_day = int(curve['day'].max())
    if last_real_day >= up_to_day:
        return curve

    real = curve.loc[~curve['is_extrapolated']].sort_values('day')
    tail = real.tail(tail_days)
    if len(tail) < 2:
        if debug:
            print(f'  [{population}] Not enough tail data ({len(tail)}) to extrapolate.')
        return curve

    arpu_vals = tail['ARPU_nominal'].values
    ratios    = arpu_vals[1:] / arpu_vals[:-1]
    ratios    = ratios[np.isfinite(ratios) & (ratios > 0)]
    if len(ratios) == 0:
        return curve

    avg_daily_growth = float(np.exp(np.mean(np.log(ratios))))

    if debug:
        print(
            f'  [{population}] Extrapolating D{last_real_day + 1}→D{up_to_day}  '
            f'rate={avg_daily_growth:.6f}/day  (geom. mean of last {len(ratios)} daily ratios)'
        )

    last_arpu  = float(curve.loc[curve['day'] == last_real_day, 'ARPU_nominal'].iloc[0])
    last_patch = curve.loc[curve['day'] == last_real_day, 'effective_patch'].iloc[0]
    tag_patch  = f'{last_patch} (extrapolated)'

    new_rows = []
    arpu = last_arpu
    for d in range(last_real_day + 1, up_to_day + 1):
        arpu *= avg_daily_growth
        new_rows.append({
            'population':      population,
            'day':             d,
            'ARPU_nominal':    float(arpu),
            'growth_step':     avg_daily_growth,
            'effective_patch': tag_patch,
            'is_extrapolated': True,
        })

    return pd.concat([curve, pd.DataFrame(new_rows)], ignore_index=True)


def build_all_populations(
    u_base, daily_user_cums, *,
    as_of_date, debug=True,
    extrapolate_tail=False, tail_days=30, extrapolate_up_to=365,
):
    all_cv_rows = []
    all_curves  = []
    for pop in POPULATIONS:
        if debug:
            print(f'\n{"=" * 55}')
            print(f'POPULATION: {pop}')
            print(f'{"=" * 55}')
        cv_df, curve = build_curve(
            u_base, daily_user_cums,
            population=pop, as_of_date=as_of_date, debug=debug,
        )
        if not cv_df.empty:
            all_cv_rows.append(cv_df)
        if not curve.empty and extrapolate_tail:
            curve = extrapolate_curve_tail(
                curve, up_to_day=extrapolate_up_to, tail_days=tail_days, debug=debug,
            )
        if not curve.empty:
            all_curves.append(curve)
    cv_out    = pd.concat(all_cv_rows, ignore_index=True) if all_cv_rows else pd.DataFrame()
    curve_out = pd.concat(all_curves, ignore_index=True) if all_curves else pd.DataFrame()
    return cv_out, curve_out

print('Persistent trim curve builder defined.')
# Out:
# Persistent trim curve builder defined.

# %%
# ══════════════════════════════════════════════════════════════
# ORGANIC SHARE — multi-config cohort progression with scope
# Supports winsor, cohort_trim (with persistent trim), or none.
# Percentiles always computed from depositors only.
#
# If users_df has 'scope' and 'bucket' columns, uses them directly
# (RP: app vs non_app). Otherwise defaults to scope='all' and
# derives bucket from population == ORGANIC_LABEL (LS).
# ══════════════════════════════════════════════════════════════

def organic_share_cohort_progression(
    users_df, revenue_df, *,
    as_of_date,
    goal_horizons=GOAL_HORIZONS,
    checkpoints=CHECKPOINTS,
    lookback_cohorts=None,
    positive_amount_only=True,
    trim_configs,
    persistent_trim=True,
):
    if lookback_cohorts is None:
        lookback_cohorts = LOOKBACK_COHORTS
    as_of_date = pd.to_datetime(as_of_date).normalize()

    has_scope = 'scope' in users_df.columns and 'bucket' in users_df.columns
    cols = ['id', 'cost_date']
    if has_scope:
        cols += ['scope', 'bucket']
    if 'population' in users_df.columns:
        cols.append('population')

    u = users_df[cols].copy()
    u['cost_date'] = pd.to_datetime(u['cost_date'], errors='coerce').dt.date
    u = u.loc[pd.notna(u['cost_date'])].copy()

    if not has_scope:
        u['scope'] = 'all'
        u['bucket'] = np.where(u['population'] == ORGANIC_LABEL, 'organic', 'acquired')

    u = u.drop_duplicates(subset=['id'])

    r = revenue_df[['playerid', 'date', 'amount']].copy()
    r['date'] = pd.to_datetime(r['date'], errors='coerce').dt.date
    r = r.loc[pd.notna(r['date'])].copy()
    if positive_amount_only:
        r = r[r['amount'] > 0]

    rr = r.merge(
        u.rename(columns={'id': '__uid__'}),
        left_on='playerid', right_on='__uid__', how='inner'
    )
    rr['dsi'] = (pd.to_datetime(rr['date']) - pd.to_datetime(rr['cost_date'])).dt.days
    rr = rr.loc[(rr['dsi'] >= 0) & (rr['dsi'] <= (max(checkpoints) - 1))].copy()

    daily_user = (
        rr.groupby(['scope', 'bucket', 'cost_date', '__uid__', 'dsi'], observed=True)['amount']
          .sum().reset_index()
          .sort_values(['scope', 'bucket', 'cost_date', '__uid__', 'dsi'])
    )
    daily_user['cum_amount'] = (
        daily_user.groupby(['scope', 'bucket', 'cost_date', '__uid__'], observed=True)['amount']
                  .cumsum()
    )

    rows = []
    scopes = sorted(u['scope'].unique())

    for horizon in goal_horizons:
        cohort_end   = (as_of_date - pd.Timedelta(days=horizon)).date()
        cohort_start = (as_of_date - pd.Timedelta(days=horizon + (lookback_cohorts - 1))).date()

        elig = u.loc[
            (u['cost_date'] >= cohort_start) &
            (u['cost_date'] <= cohort_end)
        ].copy()

        if elig.empty:
            print(f'[horizon={horizon}] No eligible users — skipping.')
            continue

        eligible_cps = sorted(c for c in checkpoints if c <= horizon)

        for scope in scopes:
            scope_elig = elig.loc[elig['scope'] == scope]
            if scope_elig.empty:
                continue

            scope_du_h = daily_user.merge(
                scope_elig[['scope', 'bucket', 'id', 'cost_date']].rename(columns={'id': '__uid__'}),
                on=['scope', 'bucket', '__uid__', 'cost_date'], how='inner'
            )

            excluded = {
                cfg['label']: set()
                for cfg in trim_configs
                if cfg['method'] == 'cohort_trim' and persistent_trim
            }

            for cp in eligible_cps:
                du_cp = scope_du_h.loc[scope_du_h['dsi'] <= (cp - 1)]

                row = dict(
                    scope          = scope,
                    goal_horizon   = horizon,
                    cohort_start   = cohort_start,
                    cohort_end     = cohort_end,
                    checkpoint_day = cp,
                )

                if du_cp.empty:
                    for cfg in trim_configs:
                        lbl = cfg['label']
                        row.update({
                            f'organic_sum_{lbl}'       : 0.0,
                            f'acquired_sum_{lbl}'      : 0.0,
                            f'total_sum_{lbl}'         : 0.0,
                            f'organic_share_pct_{lbl}' : np.nan,
                            f'users_org_{lbl}'         : 0,
                            f'users_acq_{lbl}'         : 0,
                        })
                    rows.append(row)
                    continue

                cum_cp = (
                    du_cp.groupby(['bucket', 'cost_date', '__uid__'], observed=True)['cum_amount']
                         .max().reset_index(name='cum_cp')
                )
                cum_cp = (
                    scope_elig.rename(columns={'id': '__uid__'})
                              .merge(cum_cp, on=['bucket', 'cost_date', '__uid__'], how='left')
                )
                cum_cp['cum_cp'] = cum_cp['cum_cp'].fillna(0.0)

                print_line = f'  [{scope}] D{cp:>3}:'

                for cfg in trim_configs:
                    method, pct, lbl = cfg['method'], cfg['pct'], cfg['label']

                    if method == 'none' or pct == 0.0:
                        kept = cum_cp.copy()

                    elif method == 'cohort_trim':
                        working = cum_cp.copy()
                        if persistent_trim and excluded.get(lbl):
                            working = working.loc[~working['__uid__'].isin(excluded[lbl])]

                        depositors = working.loc[working['cum_cp'] > 0]
                        if not depositors.empty:
                            thresh_map = (
                                depositors.groupby('bucket', observed=True)['cum_cp']
                                          .quantile(1.0 - pct)
                                          .to_dict()
                            )
                            thresh_series = working['bucket'].map(thresh_map).fillna(np.inf)
                            above_mask = (working['cum_cp'] > 0) & (working['cum_cp'] > thresh_series)
                            if persistent_trim:
                                excluded[lbl] |= set(working.loc[above_mask, '__uid__'].unique())
                            kept = working.loc[~above_mask]
                        else:
                            kept = working

                    elif method == 'winsor':
                        depositors = cum_cp.loc[cum_cp['cum_cp'] > 0]
                        if not depositors.empty:
                            cap_map = (
                                depositors.groupby('bucket', observed=True)['cum_cp']
                                          .quantile(1.0 - pct)
                                          .to_dict()
                            )
                            kept = cum_cp.copy()
                            caps = kept['bucket'].map(cap_map).fillna(np.inf)
                            kept['cum_cp'] = np.minimum(kept['cum_cp'], caps)
                        else:
                            kept = cum_cp.copy()

                    else:
                        raise ValueError(f"Unknown trim method: {method}")

                    sums = kept.groupby('bucket', observed=True)['cum_cp'].sum().to_dict()
                    cnts = kept.groupby('bucket', observed=True)['__uid__'].nunique().to_dict()

                    org_sum = float(sums.get('organic',  0.0))
                    acq_sum = float(sums.get('acquired', 0.0))
                    total   = org_sum + acq_sum
                    share   = (org_sum / total) if total > 0 else np.nan

                    row.update({
                        f'organic_sum_{lbl}'       : org_sum,
                        f'acquired_sum_{lbl}'      : acq_sum,
                        f'total_sum_{lbl}'         : total,
                        f'organic_share_pct_{lbl}' : share,
                        f'users_org_{lbl}'         : int(cnts.get('organic',  0)),
                        f'users_acq_{lbl}'         : int(cnts.get('acquired', 0)),
                    })

                    print_line += (f'  [{lbl}] org={org_sum:>10,.0f} '
                                   f'acq={acq_sum:>10,.0f} share={share:.1%}')

                print(print_line)
                rows.append(row)

    if not rows:
        return pd.DataFrame()
    df = pd.DataFrame(rows).sort_values(['scope', 'goal_horizon', 'checkpoint_day']).reset_index(drop=True)
    id_cols = ['scope', 'goal_horizon', 'cohort_start', 'cohort_end', 'checkpoint_day']
    metric_cols = []
    for cfg in trim_configs:
        lbl = cfg['label']
        metric_cols += [
            f'organic_sum_{lbl}', f'acquired_sum_{lbl}', f'total_sum_{lbl}',
            f'organic_share_pct_{lbl}', f'users_org_{lbl}', f'users_acq_{lbl}',
        ]
    return df[id_cols + metric_cols]


print('Organic share function defined.')
# Out:
# Organic share function defined.

# %%
# ══════════════════════════════════════════════════════════════
# PART 4 helpers — Goal construction + brand pipeline
# Per-population: adjusted = (ARPU_day / ARPU_horizon) × (1 − organic_share_at_horizon)
# Blended:        adjusted = raw_goal_ratio (no organic adjustment)
# ──
# Organic share rule: for every day inside a horizon, use the share measured AT
# the horizon endpoint (not the share at the day's nearest checkpoint).
# RP: pin lookup to min(horizon, ORGANIC_SHARE_CAP_HORIZON) when cap is set.
# LS: no cap (cap is None).
# ══════════════════════════════════════════════════════════════

def build_goals(curve_df, organic_df, populations, goal_horizons=None,
                organic_share_cap_horizon=None):
    if goal_horizons is None:
        goal_horizons = GOAL_HORIZONS

    has_scope = 'scope' in organic_df.columns
    available_scopes = set(organic_df['scope'].unique()) if has_scope else {'all'}

    org_lookup = {}
    scope_col = 'scope' if has_scope else None
    endpoint = organic_df.loc[organic_df['checkpoint_day'] == organic_df['goal_horizon']]
    if scope_col:
        for scope, grp in endpoint.groupby(scope_col):
            org_lookup[scope] = grp.set_index('goal_horizon')['organic_share_pct'].to_dict()
    else:
        org_lookup['all'] = endpoint.set_index('goal_horizon')['organic_share_pct'].to_dict()

    def pop_to_scope(pop):
        if pop == 'App' and 'app' in available_scopes:
            return 'app'
        if 'non_app' in available_scopes:
            return 'non_app'
        return next(iter(available_scopes))

    rows = []
    all_pops = list(populations) + ['Blended']

    for pop in all_pops:
        is_blended = (pop == 'Blended')

        pop_curve = curve_df.loc[curve_df['population'] == pop].copy()
        if pop_curve.empty:
            continue
        pop_curve = pop_curve.drop_duplicates(subset='day').set_index('day')

        for horizon in goal_horizons:
            if horizon not in pop_curve.index:
                print(f'[{pop}] Day {horizon} missing from curve — skipping horizon.')
                continue
            arpu_horizon = pop_curve.loc[horizon, 'ARPU_nominal']
            if not np.isfinite(arpu_horizon) or arpu_horizon == 0:
                continue

            if is_blended:
                org_share = 0.0
            else:
                scope = pop_to_scope(pop)
                if organic_share_cap_horizon is not None:
                    lookup_horizon = min(horizon, organic_share_cap_horizon)
                else:
                    lookup_horizon = horizon
                org_share = org_lookup.get(scope, {}).get(lookup_horizon, np.nan)

            for day in range(1, horizon + 1):
                if day not in pop_curve.index:
                    continue
                arpu_day  = pop_curve.loc[day, 'ARPU_nominal']
                eff_patch = pop_curve.loc[day, 'effective_patch'] if 'effective_patch' in pop_curve.columns else ''
                is_extrap = bool(pop_curve.loc[day, 'is_extrapolated']) if 'is_extrapolated' in pop_curve.columns else False
                raw_goal  = arpu_day / arpu_horizon

                if np.isfinite(org_share):
                    adj_goal = raw_goal * (1 - org_share)
                else:
                    adj_goal = np.nan

                rows.append(dict(
                    population           = pop,
                    goal_horizon         = horizon,
                    day                  = day,
                    ARPU_nominal         = float(arpu_day),
                    ARPU_at_horizon      = float(arpu_horizon),
                    raw_goal_ratio       = float(raw_goal),
                    organic_share        = float(org_share) if np.isfinite(org_share) else None,
                    adjusted_goal_ratio  = float(adj_goal)  if np.isfinite(adj_goal)  else None,
                    effective_patch      = eff_patch,
                    is_extrapolated      = is_extrap,
                ))

    return pd.DataFrame(rows)


def _banner(title: str):
    print('\n' + '─' * 60)
    print(title)
    print('─' * 60)


def monitor_show_users(brand, users_df):
    """After SQL load: population counts + date span."""
    _banner(f'[{brand}] MONITOR · DATA LOAD')
    print(f'users_df rows:   {len(users_df):,}')
    print('population counts:')
    print(users_df['population'].value_counts().to_string())
    cd = pd.to_datetime(users_df['cost_date'], errors='coerce')
    print(f"cost_date span: {cd.min().date()} → {cd.max().date()}")
    if 'scope' in users_df.columns:
        print('\nscope × bucket:')
        print(users_df.groupby(['scope', 'bucket'], observed=True).size().to_string())


def monitor_show_cv_curve(brand, stage, cv_df, curve_df, populations):
    """After ARPU curve build: CV table + milestone ARPU."""
    _banner(f'[{brand}] MONITOR · {stage}')
    if cv_df is not None and not cv_df.empty:
        display_cols = [
            'population', 'patch', 'n_dates_before', 'n_dates_after',
            'n_cohort_dates_total', 'n_cohort_dates_kept',
            'cv_before', 'robust_cv_before', 'cv_after', 'robust_cv_after',
            'cv_minus_robust_cv_after', 'robust_to_standard_cv_ratio',
            'variability_diagnosis', 'removed_dates',
            'total_rev_before_trim', 'total_rev_after_trim',
            'flagged', 'trim_method',
        ]
        display_cols = [c for c in display_cols if c in cv_df.columns]
        print('CV summary:')
        print(cv_df[display_cols].to_string(index=False))
        if 'flagged' in cv_df.columns:
            flagged = cv_df.loc[cv_df['flagged'] == True]
            if not flagged.empty:
                print('\n>>> FLAGGED PATCHES:')
                for _, r in flagged.iterrows():
                    patch = r['patch'] if 'patch' in r.index else '?'
                    print(f"    {r.get('population', '?')} / {patch}  CV={r.get('cv_after', float('nan')):.4f}")
            else:
                print('\nNo flagged patches in this stage.')
    else:
        print('CV summary: (empty)')

    if curve_df is not None and not curve_df.empty:
        milestones = list(MONITOR_PREVIEW_DAYS)
        for pop in populations:
            sub = curve_df.loc[curve_df['population'] == pop]
            if sub.empty:
                continue
            cols = [c for c in ['day', 'ARPU_nominal', 'effective_patch', 'is_extrapolated'] if c in sub.columns]
            ms = sub.loc[sub['day'].isin(milestones)][cols]
            print(f'\nARPU curve milestones — {pop}  (n_days={sub["day"].nunique()})')
            print(ms.to_string(index=False))
            if 'is_extrapolated' in sub.columns and sub['is_extrapolated'].any():
                n_ex = int(sub['is_extrapolated'].sum())
                last_real = int(sub.loc[~sub['is_extrapolated'], 'day'].max()) if (~sub['is_extrapolated']).any() else None
                print(f'  extrapolated days: {n_ex:,}  last real day: {last_real}')
    else:
        print('ARPU curve: (empty)')


def monitor_show_organic(brand, organic_df):
    """After organic share computation."""
    _banner(f'[{brand}] MONITOR · ORGANIC SHARE')
    if organic_df is None or organic_df.empty:
        print('organic_df: (empty)')
        return
    print(f'rows: {len(organic_df):,}')
    # endpoint only (checkpoint_day == goal_horizon) — what goals actually use
    if 'checkpoint_day' in organic_df.columns and 'goal_horizon' in organic_df.columns:
        ep = organic_df.loc[organic_df['checkpoint_day'] == organic_df['goal_horizon']].copy()
        cols = [c for c in ['scope', 'goal_horizon', 'organic_share_pct', 'users_org', 'users_acq'] if c in ep.columns]
        for scope in ep['scope'].unique() if 'scope' in ep.columns else [None]:
            sub = ep if scope is None else ep.loc[ep['scope'] == scope]
            title = f'endpoint shares — scope={scope}' if scope is not None else 'endpoint shares'
            print(f'\n{title}:')
            print(sub[cols].to_string(index=False))
    else:
        print(organic_df.head(20).to_string(index=False))


def monitor_show_goals(brand, goals_df, populations):
    """After goal construction: sample horizons × days."""
    _banner(f'[{brand}] MONITOR · GOALS')
    if goals_df is None or goals_df.empty:
        print('goals_df: (empty)')
        return
    print(f'total goal rows: {len(goals_df):,}')
    print('counts by population:')
    print(goals_df.groupby('population', observed=True).size().to_string())

    preview_days = list(MONITOR_PREVIEW_DAYS)
    preview_horizons = list(MONITOR_PREVIEW_HORIZONS)
    preview_cols = [
        c for c in [
            'population', 'goal_horizon', 'day',
            'raw_goal_ratio', 'organic_share', 'adjusted_goal_ratio',
            'ARPU_nominal', 'is_extrapolated',
        ] if c in goals_df.columns
    ]
    for pop in list(populations) + ['Blended']:
        for horizon in preview_horizons:
            sub = goals_df.loc[
                (goals_df['population'] == pop) &
                (goals_df['goal_horizon'] == horizon) &
                (goals_df['day'].isin(preview_days))
            ]
            if sub.empty:
                continue
            print(f'\n── {pop} │ horizon D{horizon} ──')
            print(sub[preview_cols].to_string(index=False))


def run_brand_pipeline(cfg, users_df, revenue_df, as_of_date=AS_OF_DATE, monitor=None):
    """Parts 1-4 for one brand. Returns dict of frames with brand column.

    monitor=True  -> print intermediate tables after every part (for Colab monitoring)
    monitor=False -> banners only
    monitor=None  -> use global MONITOR_STEPS
    """
    global POPULATIONS  # reassigned briefly for Blended pass; must be declared before first use

    if monitor is None:
        monitor = bool(globals().get('MONITOR_STEPS', True))

    apply_brand_globals(cfg)
    brand = cfg['brand']

    if monitor:
        monitor_show_users(brand, users_df)

    # ── PART 1 — per-population ARPU curves ──
    _banner(f'[{brand}] PART 1/4 — per-population ARPU curves')
    print(f'[{brand}] Building base cums + adaptive CV patches (debug lines below)...')
    u_pop, daily_pop = build_user_revenue_cums(
        users_df.loc[users_df['population'].isin(POPULATIONS)].copy(),
        revenue_df,
        max_day=365,
    )
    print(f'[{brand}] base users in ARPU pops: {len(u_pop):,}  daily_user rows: {len(daily_pop):,}')

    cv_pop_df, curve_pop_df = build_all_populations(
        u_pop, daily_pop,
        as_of_date=as_of_date,
        extrapolate_tail=EXTRAPOLATE_TAIL,
        tail_days=EXTRAPOLATION_TAIL_DAYS,
        extrapolate_up_to=365,
        debug=True,
    )
    if monitor:
        monitor_show_cv_curve(brand, 'PART 1 done — per-pop CV + curve', cv_pop_df, curve_pop_df, POPULATIONS)

    # ── PART 2 — Blended ──
    _banner(f'[{brand}] PART 2/4 — Blended ARPU curve')
    print(f'[{brand}] Building BLENDED...')
    users_blend = users_df.copy()
    users_blend['population'] = 'Blended'
    u_blend, daily_blend = build_user_revenue_cums(
        users_blend, revenue_df, max_day=365
    )
    print(f'[{brand}] blended users: {len(u_blend):,}')
    # Temporarily set POPULATIONS so build_all_populations iterates Blended only
    _BLENDED_POPS_BACKUP = list(POPULATIONS)
    POPULATIONS = ['Blended']
    try:
        cv_blend_df, curve_blend_df = build_all_populations(
            u_blend, daily_blend,
            as_of_date=as_of_date,
            extrapolate_tail=EXTRAPOLATE_TAIL,
            tail_days=EXTRAPOLATION_TAIL_DAYS,
            extrapolate_up_to=365,
            debug=True,
        )
    finally:
        POPULATIONS = _BLENDED_POPS_BACKUP

    if monitor:
        monitor_show_cv_curve(brand, 'PART 2 done — Blended CV + curve', cv_blend_df, curve_blend_df, ['Blended'])

    cv_df    = pd.concat([cv_pop_df,    cv_blend_df],    ignore_index=True)
    curve_df = pd.concat([curve_pop_df, curve_blend_df], ignore_index=True)

    # ── PART 3 — organic share ──
    _banner(f'[{brand}] PART 3/4 — organic share')
    org_label = f'{ORGANIC_TRIM_METHOD}_{round(ORGANIC_TRIM_PCT * 100):g}pct'
    org_config = [{'method': ORGANIC_TRIM_METHOD, 'pct': ORGANIC_TRIM_PCT, 'label': org_label}]
    print(f'[{brand}] Computing organic share [{org_label}] for horizons {GOAL_HORIZONS}...')
    organic_full = organic_share_cohort_progression(
        users_df, revenue_df,
        as_of_date=as_of_date,
        goal_horizons=GOAL_HORIZONS,
        checkpoints=CHECKPOINTS,
        lookback_cohorts=LOOKBACK_COHORTS,
        positive_amount_only=True,
        trim_configs=org_config,
        persistent_trim=True,
    )
    organic_df = organic_full[['scope', 'goal_horizon', 'cohort_start', 'cohort_end',
                               'checkpoint_day',
                               f'organic_share_pct_{org_label}',
                               f'users_org_{org_label}',
                               f'users_acq_{org_label}']].copy()
    organic_df = organic_df.rename(columns={
        f'organic_share_pct_{org_label}': 'organic_share_pct',
        f'users_org_{org_label}': 'users_org',
        f'users_acq_{org_label}': 'users_acq',
    })
    if monitor:
        monitor_show_organic(brand, organic_df)
    else:
        print(f'[{brand}] organic rows: {len(organic_df):,}')

    # ── PART 4 — goals ──
    _banner(f'[{brand}] PART 4/4 — goal construction')
    goals_df = build_goals(
        curve_df, organic_df, POPULATIONS,
        goal_horizons=GOAL_HORIZONS,
        organic_share_cap_horizon=ORGANIC_SHARE_CAP_HORIZON,
    )
    if monitor:
        monitor_show_goals(brand, goals_df, POPULATIONS)
    else:
        print(f'[{brand}] goals rows: {len(goals_df):,}')

    # stamp brand
    for df in (cv_df, curve_df, organic_df, goals_df):
        if not df.empty:
            df.insert(0, 'brand', brand)

    print(f'\n[{brand}] COMPLETE — goals {len(goals_df):,} | curve {len(curve_df):,} | organic {len(organic_df):,} | cv {len(cv_df):,}')
    return {
        'cv': cv_df,
        'curve': curve_df,
        'organic': organic_df,
        'goals': goals_df,
        'populations': list(cfg['populations']),
    }

print('run_brand_pipeline + monitors ready.')
print('Set MONITOR_STEPS=True in config cell to print intermediate tables after each part.')
# Out:
# run_brand_pipeline + monitors ready.
# Set MONITOR_STEPS=True in config cell to print intermediate tables after each part.

# %%
# ══════════════════════════════════════════════════════════════
# RUN — both brands → one output pack
# ══════════════════════════════════════════════════════════════

brand_results = {}
cv_all, curve_all, organic_all, goals_all = [], [], [], []

for brand_key in RUN_BRANDS:
    cfg = BRAND_CONFIGS[brand_key]
    users_df, revenue_df = load_brand_tables(cfg, as_of_date=AS_OF_DATE)
    result = run_brand_pipeline(cfg, users_df, revenue_df, as_of_date=AS_OF_DATE)
    brand_results[brand_key] = result
    if not result['cv'].empty:
        cv_all.append(result['cv'])
    if not result['curve'].empty:
        curve_all.append(result['curve'])
    if not result['organic'].empty:
        organic_all.append(result['organic'])
    if not result['goals'].empty:
        goals_all.append(result['goals'])

cv_df      = pd.concat(cv_all, ignore_index=True) if cv_all else pd.DataFrame()
curve_df   = pd.concat(curve_all, ignore_index=True) if curve_all else pd.DataFrame()
organic_df = pd.concat(organic_all, ignore_index=True) if organic_all else pd.DataFrame()
goals_detail_df = pd.concat(goals_all, ignore_index=True) if goals_all else pd.DataFrame()

# ── Main locked deliverable (column order fixed) ──
MAIN_GOAL_COLS = [
    'brand', 'population', 'goal_horizon', 'day',
    'raw_goal_ratio', 'organic_share', 'adjusted_goal_ratio',
]
goals_df = goals_detail_df[MAIN_GOAL_COLS].copy() if not goals_detail_df.empty else pd.DataFrame(columns=MAIN_GOAL_COLS)

print('\n' + '=' * 60)
print('UNIFIED RUN COMPLETE')
print(f'  as_of_date     = {AS_OF_DATE.date()}')
print(f'  brands         = {RUN_BRANDS}')
print(f'  cv rows        = {len(cv_df):,}')
print(f'  curve rows     = {len(curve_df):,}')
print(f'  organic rows   = {len(organic_df):,}')
print(f'  goals (main)   = {len(goals_df):,}')
print(f'  goals (detail) = {len(goals_detail_df):,}')
print('=' * 60)

if not goals_df.empty:
    print('\nRow counts by brand × population:')
    print(
        goals_df.groupby(['brand', 'population'], observed=True)
                .size().rename('n_rows').reset_index()
                .to_string(index=False)
    )
# Out:
# [realprize] SQL floor date: 2025-06-24  (AS_OF_DATE = 2026-08-03)
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# [realprize] users_df:   961,316 rows
# [realprize] revenue_df: 1,780,991 rows
# population
# App          299860
# Affiliate    260329
# Organic      190380
# Web          127540
# PPC           83207
#
# ============================================================
# BRAND: realprize
#   populations = ['Web', 'App', 'Affiliate']
#   CV threshold = 0.15  good_enough = 0.1
#   min_cohort_dates = 1
#   extrapolate_tail = False
#   organic_share_cap_horizon = 120
# ============================================================
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · DATA LOAD
# ────────────────────────────────────────────────────────────
# users_df rows:   961,316
# population counts:
# population
# App          299860
# Affiliate    260329
# Organic      190380
# Web          127540
# PPC           83207
# cost_date span: 2025-06-24 → 2026-08-12
#
# scope × bucket:
# scope    bucket
# app      acquired    244559
#          organic      55301
# non_app  acquired    471076
#          organic     190380
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 1/4 — per-population ARPU curves
# ────────────────────────────────────────────────────────────
# [realprize] Building base cums + adaptive CV patches (debug lines below)...
# [realprize] base users in ARPU pops: 687,729  daily_user rows: 409,718
#
# =======================================================
# POPULATION: Web
# =======================================================
#   [Web] 1->7  cv 0.3590->0.2446  robust_cv 0.3152->0.2964  removed=5/35  excl_prior=0  pre/post=6,241/6,241  newly_excl=0  >>> FLAGGED (cv=0.2446 > 0.15)
#   [Web] 7->14  cv 0.2205->0.1507  robust_cv 0.1632->0.1443  removed=5/35  excl_prior=0  pre/post=6,565/6,565  newly_excl=0  >>> FLAGGED (cv=0.1507 > 0.15)
#   [Web] 14->30  cv 0.5362->0.2209  robust_cv 0.2707->0.2116  removed=5/35  excl_prior=0  pre/post=5,061/5,061  newly_excl=0  >>> FLAGGED (cv=0.2209 > 0.15)
#   [Web] 30->60  cv 0.2729->0.2018  robust_cv 0.2701->0.2086  removed=5/35  excl_prior=0  pre/post=1,277/1,277  newly_excl=0  >>> FLAGGED (cv=0.2018 > 0.15)
#   [Web] 60->90  cv 0.3931->0.1254  robust_cv 0.0000->0.0000  removed=5/35  excl_prior=0  pre/post=497/497  newly_excl=0
#   [Web] 90->120  cv 0.1588->0.1251  robust_cv 0.1930->0.1676  removed=5/35  excl_prior=0  pre/post=2,295/2,295  newly_excl=0
#   [Web] 120->150  cv 0.1957->0.0878  robust_cv 0.0944->0.0643  removed=3/35  excl_prior=0  pre/post=1,780/1,780  newly_excl=0
#   [Web] 150->180  cv 0.0878->0.0878  robust_cv 0.0458->0.0458  removed=0/35  excl_prior=0  pre/post=3,337/3,337  newly_excl=0
#   [Web] 180->270  cv 0.2329->0.1111  robust_cv 0.1858->0.1536  removed=5/35  excl_prior=0  pre/post=15,743/15,743  newly_excl=0
#   [Web] 270->365  cv 0.3441->0.1075  robust_cv 0.1513->0.1427  removed=5/35  excl_prior=0  pre/post=21,064/21,064  newly_excl=0
#   Total unique users excluded across all patches: 0
#
# =======================================================
# POPULATION: App
# =======================================================
#   [App] 1->7  cv 0.3414->0.2231  robust_cv 0.1743->0.1856  removed=5/35  excl_prior=0  pre/post=31,034/31,034  newly_excl=0  >>> FLAGGED (cv=0.2231 > 0.15)
#   [App] 7->14  cv 0.1700->0.1116  robust_cv 0.1644->0.1308  removed=5/35  excl_prior=0  pre/post=32,127/32,127  newly_excl=0
#   [App] 14->30  cv 0.2551->0.0937  robust_cv 0.0965->0.0895  removed=4/35  excl_prior=0  pre/post=33,341/33,341  newly_excl=0
#   [App] 30->60  cv 0.1638->0.1176  robust_cv 0.1694->0.1374  removed=5/35  excl_prior=0  pre/post=29,598/29,598  newly_excl=0
#   [App] 60->90  cv 0.2425->0.1324  robust_cv 0.1381->0.1067  removed=5/35  excl_prior=0  pre/post=21,618/21,618  newly_excl=0
#   [App] 90->120  cv 0.1404->0.0795  robust_cv 0.1011->0.0917  removed=3/35  excl_prior=0  pre/post=19,076/19,076  newly_excl=0
#   [App] 120->150  cv 0.0523->0.0523  robust_cv 0.0533->0.0533  removed=0/35  excl_prior=0  pre/post=13,650/13,650  newly_excl=0
#   [App] 150->180  cv 0.0727->0.0727  robust_cv 0.0825->0.0825  removed=0/35  excl_prior=0  pre/post=19,839/19,839  newly_excl=0
#   [App] 180->270  cv 0.3084->0.1093  robust_cv 0.1767->0.1237  removed=5/35  excl_prior=0  pre/post=13,298/13,298  newly_excl=0
#   [App] 270->365  cv 0.2065->0.0859  robust_cv 0.1150->0.1157  removed=2/35  excl_prior=0  pre/post=24,384/24,384  newly_excl=0
#   Total unique users excluded across all patches: 0
#
# =======================================================
# POPULATION: Affiliate
# =======================================================
#   [Affiliate] 1->7  cv 0.4255->0.1414  robust_cv 0.2152->0.1598  removed=5/35  excl_prior=0  pre/post=15,181/15,181  newly_excl=0
#   [Affiliate] 7->14  cv 0.1114->0.0902  robust_cv 0.0982->0.0923  removed=2/35  excl_prior=0  pre/post=15,321/15,321  newly_excl=0
#   [Affiliate] 14->30  cv 0.1664->0.0945  robust_cv 0.0806->0.0637  removed=5/35  excl_prior=0  pre/post=15,296/15,296  newly_excl=0
#   [Affiliate] 30->60  cv 0.1236->0.0997  robust_cv 0.1439->0.1253  removed=3/35  excl_prior=0  pre/post=9,852/9,852  newly_excl=0
#   [Affiliate] 60->90  cv 0.0760->0.0760  robust_cv 0.0876->0.0876  removed=0/35  excl_prior=0  pre/post=11,760/11,760  newly_excl=0
#   [Affiliate] 90->120  cv 0.0758->0.0758  robust_cv 0.0320->0.0320  removed=0/35  excl_prior=0  pre/post=18,373/18,373  newly_excl=0
#   [Affiliate] 120->150  cv 0.0961->0.0961  robust_cv 0.0334->0.0334  removed=0/35  excl_prior=0  pre/post=19,113/19,113  newly_excl=0
#   [Affiliate] 150->180  cv 0.0529->0.0529  robust_cv 0.0463->0.0463  removed=0/35  excl_prior=0  pre/post=24,263/24,263  newly_excl=0
#   [Affiliate] 180->270  cv 0.0678->0.0678  robust_cv 0.0721->0.0721  removed=0/35  excl_prior=0  pre/post=23,399/23,399  newly_excl=0
#   [Affiliate] 270->365  cv 0.0861->0.0861  robust_cv 0.0572->0.0572  removed=0/35  excl_prior=0  pre/post=39,719/39,719  newly_excl=0
#   Total unique users excluded across all patches: 0
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · PART 1 done — per-pop CV + curve
# ────────────────────────────────────────────────────────────
# CV summary:
# population    patch  n_cohort_dates_total  n_cohort_dates_kept  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  variability_diagnosis                                                removed_dates  total_rev_before_trim  total_rev_after_trim  flagged trim_method
#        Web     1->7                    35                   30   0.359043          0.315228  0.244573         0.296364                 -0.051791                     1.211762                 REVIEW [2026-07-26, 2026-07-07, 2026-07-23, 2026-07-15, 2026-06-26]               66824.43            59764.6107     True      winsor
#        Web    7->14                    35                   30   0.220494          0.163219  0.150728         0.144286                  0.006442                     0.957259 CONSISTENT_VARIABILITY [2026-06-30, 2026-07-03, 2026-07-11, 2026-06-19, 2026-07-14]               60337.28            56937.2223     True      winsor
#        Web   14->30                    35                   30   0.536224          0.270678  0.220869         0.211614                  0.009255                     0.958097 CONSISTENT_VARIABILITY [2026-06-30, 2026-06-15, 2026-06-04, 2026-07-03, 2026-07-02]               54085.50            51055.1242     True      winsor
#        Web   30->60                    35                   30   0.272884          0.270069  0.201778         0.208584                 -0.006806                     1.033731 CONSISTENT_VARIABILITY [2026-05-12, 2026-05-31, 2026-05-26, 2026-05-02, 2026-05-22]               18320.95            17863.8713     True      winsor
#        Web   60->90                    35                   30   0.393106          0.000000  0.125433         0.000000                  0.125433                     0.000000         OUTLIER_DRIVEN [2026-04-21, 2026-04-02, 2026-04-19, 2026-04-04, 2026-04-03]                3463.58             3432.0427    False      winsor
#        Web  90->120                    35                   30   0.158812          0.193003  0.125078         0.167604                 -0.042526                     1.340000                 REVIEW [2026-03-31, 2026-03-13, 2026-03-04, 2026-03-08, 2026-03-20]               14135.91            13577.7913    False      winsor
#        Web 120->150                    35                   32   0.195702          0.094424  0.087775         0.064326                  0.023449                     0.732854 CONSISTENT_VARIABILITY                         [2026-02-26, 2026-02-01, 2026-02-12]               23593.86            22949.3843    False      winsor
#        Web 150->180                    35                   35   0.087759          0.045802  0.087759         0.045802                  0.041957                     0.521908         OUTLIER_DRIVEN                                                           []               66798.23            62519.7557    False      winsor
#        Web 180->270                    35                   30   0.232851          0.185790  0.111117         0.153552                 -0.042435                     1.381892                 REVIEW [2025-10-05, 2025-10-11, 2025-10-14, 2025-10-26, 2025-10-12]              222543.68           191067.7736    False      winsor
#        Web 270->365                    35                   30   0.344060          0.151333  0.107542         0.142656                 -0.035113                     1.326506                 REVIEW [2025-07-23, 2025-07-28, 2025-07-30, 2025-07-18, 2025-07-08]              327596.72           277722.4137    False      winsor
#        App     1->7                    35                   30   0.341382          0.174349  0.223079         0.185590                  0.037489                     0.831947 CONSISTENT_VARIABILITY [2026-07-13, 2026-06-27, 2026-07-08, 2026-07-17, 2026-06-30]              411808.73           411808.7300     True      winsor
#        App    7->14                    35                   30   0.170034          0.164442  0.111586         0.130788                 -0.019202                     1.172082                 REVIEW [2026-07-14, 2026-06-30, 2026-07-19, 2026-06-27, 2026-06-19]              551877.89           551877.8900    False      winsor
#        App   14->30                    35                   31   0.255102          0.096486  0.093723         0.089463                  0.004260                     0.954550 CONSISTENT_VARIABILITY             [2026-06-24, 2026-06-04, 2026-06-13, 2026-06-27]              787255.22           787255.2200    False      winsor
#        App   30->60                    35                   30   0.163753          0.169376  0.117578         0.137377                 -0.019799                     1.168386                 REVIEW [2026-05-21, 2026-05-05, 2026-05-07, 2026-05-22, 2026-05-14]             1106648.92          1106648.9200    False      winsor
#        App   60->90                    35                   30   0.242505          0.138103  0.132429         0.106677                  0.025753                     0.805537 CONSISTENT_VARIABILITY [2026-05-03, 2026-04-28, 2026-05-02, 2026-05-04, 2026-04-26]             1304184.93          1304184.9300    False      winsor
#        App  90->120                    35                   32   0.140358          0.101127  0.079481         0.091728                 -0.012247                     1.154093                 REVIEW                         [2026-03-13, 2026-03-11, 2026-03-21]             1192681.77          1192681.7700    False      winsor
#        App 120->150                    35                   35   0.052292          0.053292  0.052292         0.053292                 -0.001000                     1.019126 CONSISTENT_VARIABILITY                                                           []              719706.82           719706.8200    False      winsor
#        App 150->180                    35                   35   0.072651          0.082477  0.072651         0.082477                 -0.009826                     1.135253 CONSISTENT_VARIABILITY                                                           []              646209.10           646209.1000    False      winsor
#        App 180->270                    35                   30   0.308391          0.176697  0.109293         0.123702                 -0.014409                     1.131840 CONSISTENT_VARIABILITY [2025-10-29, 2025-10-27, 2025-10-30, 2025-11-02, 2025-10-16]              458512.97           458512.9700    False      winsor
#        App 270->365                    35                   33   0.206491          0.115014  0.085927         0.115740                 -0.029813                     1.346956                 REVIEW                                     [2025-07-07, 2025-07-16]              695695.85           695695.8500    False      winsor
#  Affiliate     1->7                    35                   30   0.425545          0.215198  0.141403         0.159792                 -0.018388                     1.130043 CONSISTENT_VARIABILITY [2026-07-10, 2026-07-21, 2026-07-12, 2026-07-22, 2026-07-13]              252735.23           188892.9113    False      winsor
#  Affiliate    7->14                    35                   33   0.111384          0.098217  0.090185         0.092316                 -0.002131                     1.023628 CONSISTENT_VARIABILITY                                     [2026-06-22, 2026-07-13]              347911.87           225133.9662    False      winsor
#  Affiliate   14->30                    35                   30   0.166376          0.080611  0.094532         0.063673                  0.030858                     0.673564         OUTLIER_DRIVEN [2026-06-02, 2026-06-30, 2026-06-25, 2026-06-08, 2026-06-12]              445858.88           303040.7080    False      winsor
#  Affiliate   30->60                    35                   32   0.123578          0.143911  0.099726         0.125282                 -0.025557                     1.256270                 REVIEW                         [2026-05-08, 2026-05-20, 2026-05-21]              639681.73           325514.4524    False      winsor
#  Affiliate   60->90                    35                   35   0.075978          0.087591  0.075978         0.087591                 -0.011613                     1.152841                 REVIEW                                                           []              781544.95           424822.8102    False      winsor
#  Affiliate  90->120                    35                   35   0.075816          0.032014  0.075816         0.032014                  0.043802                     0.422254         OUTLIER_DRIVEN                                                           []             1020010.28           578367.2319    False      winsor
#  Affiliate 120->150                    35                   35   0.096103          0.033380  0.096103         0.033380                  0.062723                     0.347335         OUTLIER_DRIVEN                                                           []             1662133.41          1135794.4108    False      winsor
#  Affiliate 150->180                    35                   35   0.052901          0.046251  0.052901         0.046251                  0.006650                     0.874294 CONSISTENT_VARIABILITY                                                           []             2446404.59          1466308.1111    False      winsor
#  Affiliate 180->270                    35                   35   0.067774          0.072122  0.067774         0.072122                 -0.004347                     1.064145 CONSISTENT_VARIABILITY                                                           []             2053339.88          1154881.4264    False      winsor
#  Affiliate 270->365                    35                   35   0.086077          0.057174  0.086077         0.057174                  0.028903                     0.664224         OUTLIER_DRIVEN                                                           []             5850877.84          3686758.6543    False      winsor
#
# >>> FLAGGED PATCHES:
#     Web / 1->7  CV=0.2446
#     Web / 7->14  CV=0.1507
#     Web / 14->30  CV=0.2209
#     Web / 30->60  CV=0.2018
#     App / 1->7  CV=0.2231
#
# ARPU curve milestones — Web  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      4.594260            1->7            False
#    7      8.391303            1->7            False
#   14     11.440428           7->14            False
#   30     15.339526          14->30            False
#   60     19.578929          30->60            False
#   90     21.084367          60->90            False
#  120     25.105805         90->120            False
#  180     29.329547        150->180            False
#  270     34.133723        180->270            False
#  365     41.029709        270->365            False
#
# ARPU curve milestones — App  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      5.243508            1->7            False
#    7     11.512095            1->7            False
#   14     15.035535           7->14            False
#   30     21.337796          14->30            False
#   60     30.850226          30->60            False
#   90     38.578233          60->90            False
#  120     43.160356         90->120            False
#  180     51.706637        150->180            False
#  270     63.371410        180->270            False
#  365     71.341127        270->365            False
#
# ARPU curve milestones — Affiliate  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      6.940305            1->7            False
#    7     11.595896            1->7            False
#   14     14.201855           7->14            False
#   30     17.675206          14->30            False
#   60     22.180944          30->60            False
#   90     25.503998          60->90            False
#  120     28.623331         90->120            False
#  180     33.674997        150->180            False
#  270     38.334607        180->270            False
#  365     42.757520        270->365            False
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 2/4 — Blended ARPU curve
# ────────────────────────────────────────────────────────────
# [realprize] Building BLENDED...
# [realprize] blended users: 961,316
#
# =======================================================
# POPULATION: Blended
# =======================================================
#   [Blended] 1->7  cv 0.2778->0.1920  robust_cv 0.2647->0.2104  removed=5/35  excl_prior=0  pre/post=72,490/72,490  newly_excl=0  >>> FLAGGED (cv=0.1920 > 0.15)
#   [Blended] 7->14  cv 0.1331->0.1007  robust_cv 0.1027->0.0897  removed=5/35  excl_prior=0  pre/post=73,453/73,453  newly_excl=0
#   [Blended] 14->30  cv 0.1676->0.0986  robust_cv 0.1259->0.1108  removed=4/35  excl_prior=0  pre/post=72,313/72,313  newly_excl=0
#   [Blended] 30->60  cv 0.1929->0.0852  robust_cv 0.0969->0.0695  removed=4/35  excl_prior=0  pre/post=60,401/60,401  newly_excl=0
#   [Blended] 60->90  cv 0.1430->0.0944  robust_cv 0.1275->0.1244  removed=3/35  excl_prior=0  pre/post=55,218/55,218  newly_excl=0
#   [Blended] 90->120  cv 0.1133->0.0908  robust_cv 0.1039->0.0915  removed=1/35  excl_prior=0  pre/post=57,777/57,777  newly_excl=0
#   [Blended] 120->150  cv 0.0414->0.0414  robust_cv 0.0415->0.0415  removed=0/35  excl_prior=0  pre/post=55,176/55,176  newly_excl=0
#   [Blended] 150->180  cv 0.0533->0.0533  robust_cv 0.0429->0.0429  removed=0/35  excl_prior=0  pre/post=65,093/65,093  newly_excl=0
#   [Blended] 180->270  cv 0.1353->0.0975  robust_cv 0.0911->0.0778  removed=4/35  excl_prior=0  pre/post=78,730/78,730  newly_excl=0
#   [Blended] 270->365  cv 0.0744->0.0744  robust_cv 0.0707->0.0707  removed=0/35  excl_prior=0  pre/post=117,022/117,022  newly_excl=0
#   Total unique users excluded across all patches: 0
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · PART 2 done — Blended CV + curve
# ────────────────────────────────────────────────────────────
# CV summary:
# population    patch  n_cohort_dates_total  n_cohort_dates_kept  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  variability_diagnosis                                                removed_dates  total_rev_before_trim  total_rev_after_trim  flagged trim_method
#    Blended     1->7                    35                   30   0.277850          0.264715  0.192020         0.210441                 -0.018421                     1.095931 CONSISTENT_VARIABILITY [2026-06-24, 2026-06-27, 2026-07-02, 2026-07-04, 2026-07-12]             1151598.83            1151598.83     True      winsor
#    Blended    7->14                    35                   30   0.133137          0.102701  0.100732         0.089696                  0.011036                     0.890446 CONSISTENT_VARIABILITY [2026-07-05, 2026-06-18, 2026-06-29, 2026-06-24, 2026-07-18]             1497261.81            1497261.81    False      winsor
#    Blended   14->30                    35                   31   0.167582          0.125877  0.098605         0.110773                 -0.012167                     1.123394 CONSISTENT_VARIABILITY             [2026-06-16, 2026-06-04, 2026-06-27, 2026-06-01]             1949601.23            1949601.23    False      winsor
#    Blended   30->60                    35                   31   0.192888          0.096913  0.085180         0.069468                  0.015712                     0.815543 CONSISTENT_VARIABILITY             [2026-05-20, 2026-05-12, 2026-05-06, 2026-05-21]             2630786.56            2630786.56    False      winsor
#    Blended   60->90                    35                   32   0.142963          0.127545  0.094387         0.124416                 -0.030030                     1.318159                 REVIEW                         [2026-04-30, 2026-04-28, 2026-05-02]             3597502.92            3597502.92    False      winsor
#    Blended  90->120                    35                   34   0.113289          0.103857  0.090758         0.091510                 -0.000752                     1.008290 CONSISTENT_VARIABILITY                                                 [2026-03-21]             3994131.25            3994131.25    False      winsor
#    Blended 120->150                    35                   35   0.041437          0.041494  0.041437         0.041494                 -0.000057                     1.001373 CONSISTENT_VARIABILITY                                                           []             4123491.42            4123491.42    False      winsor
#    Blended 150->180                    35                   35   0.053310          0.042872  0.053310         0.042872                  0.010438                     0.804203 CONSISTENT_VARIABILITY                                                           []             5110836.71            5110836.71    False      winsor
#    Blended 180->270                    35                   31   0.135293          0.091148  0.097453         0.077799                  0.019654                     0.798324 CONSISTENT_VARIABILITY             [2025-10-25, 2025-10-04, 2025-10-26, 2025-10-29]             6302363.64            6302363.64    False      winsor
#    Blended 270->365                    35                   35   0.074368          0.070696  0.074368         0.070696                  0.003672                     0.950621 CONSISTENT_VARIABILITY                                                           []            11588206.64           11588206.64    False      winsor
#
# >>> FLAGGED PATCHES:
#     Blended / 1->7  CV=0.1920
#
# ARPU curve milestones — Blended  (n_days=365)
#  day  ARPU_nominal effective_patch  is_extrapolated
#    1      6.952154            1->7            False
#    7     16.177401            1->7            False
#   14     22.319166           7->14            False
#   30     32.976584          14->30            False
#   60     46.157477          30->60            False
#   90     58.955804          60->90            False
#  120     70.090857         90->120            False
#  180     86.581144        150->180            False
#  270    110.212355        180->270            False
#  365    132.880243        270->365            False
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 3/4 — organic share
# ────────────────────────────────────────────────────────────
# [realprize] Computing organic share [winsor_0pct] for horizons [7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]...
#   [app] D  7:  [winsor_0pct] org=    53,744 acq=   358,065 share=13.1%
#   [non_app] D  7:  [winsor_0pct] org=   419,954 acq=   319,837 share=56.8%
#   [app] D  7:  [winsor_0pct] org=    51,054 acq=   293,442 share=14.8%
#   [app] D 30:  [winsor_0pct] org=   117,692 acq=   669,563 share=14.9%
#   [non_app] D  7:  [winsor_0pct] org=   326,582 acq=   247,028 share=56.9%
#   [non_app] D 30:  [winsor_0pct] org=   660,578 acq=   501,768 share=56.8%
#   [app] D  7:  [winsor_0pct] org=    93,056 acq=   271,651 share=25.5%
#   [app] D 30:  [winsor_0pct] org=   177,901 acq=   555,280 share=24.3%
#   [app] D 60:  [winsor_0pct] org=   241,237 acq=   865,412 share=21.8%
#   [non_app] D  7:  [winsor_0pct] org=   318,486 acq=   191,899 share=62.4%
#   [non_app] D 30:  [winsor_0pct] org=   620,624 acq=   407,746 share=60.4%
#   [non_app] D 60:  [winsor_0pct] org=   861,036 acq=   663,101 share=56.5%
#   [app] D  7:  [winsor_0pct] org=    63,013 acq=   239,693 share=20.8%
#   [app] D 30:  [winsor_0pct] org=   142,840 acq=   476,174 share=23.1%
#   [app] D 60:  [winsor_0pct] org=   257,919 acq=   710,130 share=26.6%
#   [app] D 90:  [winsor_0pct] org=   359,035 acq=   945,150 share=27.5%
#   [non_app] D  7:  [winsor_0pct] org=   417,204 acq=   193,535 share=68.3%
#   [non_app] D 30:  [winsor_0pct] org=   769,673 acq=   429,714 share=64.2%
#   [non_app] D 60:  [winsor_0pct] org= 1,124,157 acq=   627,923 share=64.2%
#   [non_app] D 90:  [winsor_0pct] org= 1,501,323 acq=   791,995 share=65.5%
#   [app] D  7:  [winsor_0pct] org=    20,610 acq=   161,964 share=11.3%
#   [app] D 30:  [winsor_0pct] org=    84,684 acq=   366,596 share=18.8%
#   [app] D 60:  [winsor_0pct] org=   115,869 acq=   685,037 share=14.5%
#   [app] D 90:  [winsor_0pct] org=   129,314 acq=   902,651 share=12.5%
#   [app] D120:  [winsor_0pct] org=   145,611 acq= 1,047,071 share=12.2%
#   [non_app] D  7:  [winsor_0pct] org=   389,775 acq=   248,895 share=61.0%
#   [non_app] D 30:  [winsor_0pct] org=   784,810 acq=   491,345 share=61.5%
#   [non_app] D 60:  [winsor_0pct] org= 1,181,474 acq=   666,076 share=63.9%
#   [non_app] D 90:  [winsor_0pct] org= 1,456,997 acq=   833,801 share=63.6%
#   [non_app] D120:  [winsor_0pct] org= 1,760,299 acq= 1,041,150 share=62.8%
#   [app] D  7:  [winsor_0pct] org=    23,582 acq=   123,521 share=16.0%
#   [app] D 30:  [winsor_0pct] org=    52,411 acq=   274,876 share=16.0%
#   [app] D 60:  [winsor_0pct] org=    68,027 acq=   378,732 share=15.2%
#   [app] D 90:  [winsor_0pct] org=    82,587 acq=   501,578 share=14.1%
#   [app] D120:  [winsor_0pct] org=    86,653 acq=   573,005 share=13.1%
#   [app] D150:  [winsor_0pct] org=    93,452 acq=   626,254 share=13.0%
#   [non_app] D  7:  [winsor_0pct] org=   276,596 acq=   417,422 share=39.9%
#   [non_app] D 30:  [winsor_0pct] org=   618,149 acq=   803,632 share=43.5%
#   [non_app] D 60:  [winsor_0pct] org= 1,031,599 acq= 1,105,702 share=48.3%
#   [non_app] D 90:  [winsor_0pct] org= 1,318,671 acq= 1,351,635 share=49.4%
#   [non_app] D120:  [winsor_0pct] org= 1,514,779 acq= 1,542,266 share=49.6%
#   [non_app] D150:  [winsor_0pct] org= 1,669,960 acq= 1,733,825 share=49.1%
#   [app] D  7:  [winsor_0pct] org=    16,197 acq=   126,525 share=11.3%
#   [app] D 30:  [winsor_0pct] org=    25,565 acq=   240,067 share=9.6%
#   [app] D 60:  [winsor_0pct] org=    35,106 acq=   344,214 share=9.3%
#   [app] D 90:  [winsor_0pct] org=    43,784 acq=   415,298 share=9.5%
#   [app] D120:  [winsor_0pct] org=    57,750 acq=   478,500 share=10.8%
#   [app] D150:  [winsor_0pct] org=    71,753 acq=   516,749 share=12.2%
#   [app] D180:  [winsor_0pct] org=    79,981 acq=   566,229 share=12.4%
#   [non_app] D  7:  [winsor_0pct] org=   251,335 acq=   395,991 share=38.8%
#   [non_app] D 30:  [winsor_0pct] org=   551,598 acq=   961,886 share=36.4%
#   [non_app] D 60:  [winsor_0pct] org=   865,804 acq= 1,393,631 share=38.3%
#   [non_app] D 90:  [winsor_0pct] org= 1,117,271 acq= 1,746,387 share=39.0%
#   [non_app] D120:  [winsor_0pct] org= 1,410,398 acq= 2,076,191 share=40.5%
#   [non_app] D150:  [winsor_0pct] org= 1,641,108 acq= 2,360,650 share=41.0%
#   [non_app] D180:  [winsor_0pct] org= 1,830,736 acq= 2,633,891 share=41.0%
#   [app] D  7:  [winsor_0pct] org=    20,491 acq=   129,966 share=13.6%
#   [app] D 30:  [winsor_0pct] org=    37,235 acq=   331,978 share=10.1%
#   [app] D 60:  [winsor_0pct] org=    67,506 acq=   485,119 share=12.2%
#   [app] D 90:  [winsor_0pct] org=    91,161 acq=   596,527 share=13.3%
#   [app] D120:  [winsor_0pct] org=   122,686 acq=   676,120 share=15.4%
#   [app] D150:  [winsor_0pct] org=   194,058 acq=   749,156 share=20.6%
#   [app] D180:  [winsor_0pct] org=   232,456 acq=   842,303 share=21.6%
#   [app] D210:  [winsor_0pct] org=   264,469 acq=   921,653 share=22.3%
#   [non_app] D  7:  [winsor_0pct] org=   243,651 acq=   373,685 share=39.5%
#   [non_app] D 30:  [winsor_0pct] org=   581,720 acq=   797,197 share=42.2%
#   [non_app] D 60:  [winsor_0pct] org=   811,246 acq= 1,178,498 share=40.8%
#   [non_app] D 90:  [winsor_0pct] org= 1,051,013 acq= 1,549,216 share=40.4%
#   [non_app] D120:  [winsor_0pct] org= 1,492,015 acq= 1,906,742 share=43.9%
#   [non_app] D150:  [winsor_0pct] org= 1,794,192 acq= 2,208,050 share=44.8%
#   [non_app] D180:  [winsor_0pct] org= 1,969,295 acq= 2,409,010 share=45.0%
#   [non_app] D210:  [winsor_0pct] org= 2,141,789 acq= 2,616,675 share=45.0%
#   [app] D  7:  [winsor_0pct] org=    29,084 acq=    37,118 share=43.9%
#   [app] D 30:  [winsor_0pct] org=    45,744 acq=   134,225 share=25.4%
#   [app] D 60:  [winsor_0pct] org=    71,482 acq=   231,001 share=23.6%
#   [app] D 90:  [winsor_0pct] org=   101,161 acq=   315,170 share=24.3%
#   [app] D120:  [winsor_0pct] org=   122,752 acq=   373,461 share=24.7%
#   [app] D150:  [winsor_0pct] org=   159,564 acq=   444,112 share=26.4%
#   [app] D180:  [winsor_0pct] org=   184,845 acq=   523,693 share=26.1%
#   [app] D210:  [winsor_0pct] org=   198,170 acq=   579,175 share=25.5%
#   [app] D240:  [winsor_0pct] org=   208,280 acq=   616,395 share=25.3%
#   [non_app] D  7:  [winsor_0pct] org=   283,340 acq=   323,304 share=46.7%
#   [non_app] D 30:  [winsor_0pct] org=   669,994 acq=   684,505 share=49.5%
#   [non_app] D 60:  [winsor_0pct] org=   854,679 acq= 1,001,009 share=46.1%
#   [non_app] D 90:  [winsor_0pct] org= 1,065,778 acq= 1,218,149 share=46.7%
#   [non_app] D120:  [winsor_0pct] org= 1,482,562 acq= 1,453,654 share=50.5%
#   [non_app] D150:  [winsor_0pct] org= 1,757,256 acq= 1,612,593 share=52.1%
#   [non_app] D180:  [winsor_0pct] org= 1,969,356 acq= 1,830,052 share=51.8%
#   [non_app] D210:  [winsor_0pct] org= 2,088,103 acq= 2,024,160 share=50.8%
#   [non_app] D240:  [winsor_0pct] org= 2,396,668 acq= 2,225,989 share=51.8%
#   [app] D  7:  [winsor_0pct] org=    20,749 acq=    11,603 share=64.1%
#   [app] D 30:  [winsor_0pct] org=    36,945 acq=    36,536 share=50.3%
#   [app] D 60:  [winsor_0pct] org=    94,047 acq=    49,303 share=65.6%
#   [app] D 90:  [winsor_0pct] org=   123,923 acq=    63,921 share=66.0%
#   [app] D120:  [winsor_0pct] org=   183,424 acq=    75,603 share=70.8%
#   [app] D150:  [winsor_0pct] org=   219,578 acq=    85,282 share=72.0%
#   [app] D180:  [winsor_0pct] org=   254,092 acq=   100,703 share=71.6%
#   [app] D210:  [winsor_0pct] org=   283,064 acq=   112,065 share=71.6%
#   [app] D240:  [winsor_0pct] org=   288,456 acq=   142,000 share=67.0%
#   [app] D270:  [winsor_0pct] org=   298,022 acq=   160,491 share=65.0%
#   [non_app] D  7:  [winsor_0pct] org=   192,981 acq=   476,709 share=28.8%
#   [non_app] D 30:  [winsor_0pct] org=   393,886 acq= 1,056,204 share=27.2%
#   [non_app] D 60:  [winsor_0pct] org=   598,172 acq= 1,592,558 share=27.3%
#   [non_app] D 90:  [winsor_0pct] org=   791,505 acq= 2,006,105 share=28.3%
#   [non_app] D120:  [winsor_0pct] org=   937,751 acq= 2,467,281 share=27.5%
#   [non_app] D150:  [winsor_0pct] org= 1,097,480 acq= 2,877,985 share=27.6%
#   [non_app] D180:  [winsor_0pct] org= 1,247,731 acq= 3,229,498 share=27.9%
#   [non_app] D210:  [winsor_0pct] org= 1,379,839 acq= 3,599,571 share=27.7%
#   [non_app] D240:  [winsor_0pct] org= 1,477,335 acq= 3,922,833 share=27.4%
#   [non_app] D270:  [winsor_0pct] org= 1,598,411 acq= 4,245,440 share=27.4%
#   [app] D  7:  [winsor_0pct] org=    59,297 acq=     6,892 share=89.6%
#   [app] D 30:  [winsor_0pct] org=   129,627 acq=    20,704 share=86.2%
#   [app] D 60:  [winsor_0pct] org=   191,662 acq=    30,068 share=86.4%
#   [app] D 90:  [winsor_0pct] org=   239,825 acq=    39,789 share=85.8%
#   [app] D120:  [winsor_0pct] org=   276,922 acq=    49,962 share=84.7%
#   [app] D150:  [winsor_0pct] org=   315,340 acq=    60,721 share=83.9%
#   [app] D180:  [winsor_0pct] org=   354,343 acq=    71,826 share=83.1%
#   [app] D210:  [winsor_0pct] org=   398,344 acq=    88,366 share=81.8%
#   [app] D240:  [winsor_0pct] org=   428,685 acq=   104,235 share=80.4%
#   [app] D270:  [winsor_0pct] org=   458,502 acq=   123,358 share=78.8%
#   [app] D365:  [winsor_0pct] org=   541,180 acq=   154,516 share=77.8%
#   [non_app] D  7:  [winsor_0pct] org=   198,845 acq=   973,793 share=17.0%
#   [non_app] D 30:  [winsor_0pct] org=   414,801 acq= 2,101,880 share=16.5%
#   [non_app] D 60:  [winsor_0pct] org=   570,040 acq= 3,224,544 share=15.0%
#   [non_app] D 90:  [winsor_0pct] org=   749,138 acq= 4,045,942 share=15.6%
#   [non_app] D120:  [winsor_0pct] org=   862,669 acq= 4,823,455 share=15.2%
#   [non_app] D150:  [winsor_0pct] org=   952,416 acq= 5,452,064 share=14.9%
#   [non_app] D180:  [winsor_0pct] org= 1,055,936 acq= 6,093,928 share=14.8%
#   [non_app] D210:  [winsor_0pct] org= 1,138,535 acq= 6,712,909 share=14.5%
#   [non_app] D240:  [winsor_0pct] org= 1,211,133 acq= 7,249,721 share=14.3%
#   [non_app] D270:  [winsor_0pct] org= 1,306,057 acq= 7,723,470 share=14.5%
#   [non_app] D365:  [winsor_0pct] org= 1,581,730 acq= 9,310,781 share=14.5%
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · ORGANIC SHARE
# ────────────────────────────────────────────────────────────
# rows: 132
#
# endpoint shares — scope=app:
# scope  goal_horizon  organic_share_pct  users_org  users_acq
#   app             7           0.130506       1594      29440
#   app            30           0.149497       2631      30710
#   app            60           0.217989       3014      26584
#   app            90           0.275295       1875      19743
#   app           120           0.122087       1204      17872
#   app           150           0.129848        861      12789
#   app           180           0.123769       1574      18265
#   app           210           0.222970       3444      58419
#   app           240           0.252560       3509      29888
#   app           270           0.649975       3006      10292
#   app           365           0.777898      21260       3124
#
# endpoint shares — scope=non_app:
#   scope  goal_horizon  organic_share_pct  users_org  users_acq
# non_app             7           0.567666      19825      21631
# non_app            30           0.568315      18373      20599
# non_app            60           0.564933      19307      11496
# non_app            90           0.654651      20838      12762
# non_app           120           0.628353      17593      21108
# non_app           150           0.490619      19205      22321
# non_app           180           0.410054      16407      28847
# non_app           210           0.450101      15080      51794
# non_app           240           0.518461      13205      55929
# non_app           270           0.273520      11603      53829
# non_app           365           0.145213      12494      80144
#
# ────────────────────────────────────────────────────────────
# [realprize] PART 4/4 — goal construction
# ────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# [realprize] MONITOR · GOALS
# ────────────────────────────────────────────────────────────
# total goal rows: 6,888
# counts by population:
# population
# Affiliate    1722
# App          1722
# Blended      1722
# Web          1722
#
# ── Web │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web             7    1        0.547503       0.567666             0.236704      4.594260            False
#        Web             7    7        1.000000       0.567666             0.432334      8.391303            False
#
# ── Web │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web            30    1        0.299505       0.568315             0.129292      4.594260            False
#        Web            30    7        0.547038       0.568315             0.236148      8.391303            False
#        Web            30   14        0.745814       0.568315             0.321957     11.440428            False
#        Web            30   30        1.000000       0.568315             0.431685     15.339526            False
#
# ── Web │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           120    1        0.182996       0.628353             0.068010      4.594260            False
#        Web           120    7        0.334238       0.628353             0.124218      8.391303            False
#        Web           120   14        0.455689       0.628353             0.169355     11.440428            False
#        Web           120   30        0.610995       0.628353             0.227075     15.339526            False
#        Web           120   60        0.779857       0.628353             0.289831     19.578929            False
#        Web           120   90        0.839820       0.628353             0.312117     21.084367            False
#        Web           120  120        1.000000       0.628353             0.371647     25.105805            False
#
# ── Web │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           365    1        0.111974       0.628353             0.041615      4.594260            False
#        Web           365    7        0.204518       0.628353             0.076008      8.391303            False
#        Web           365   14        0.278833       0.628353             0.103627     11.440428            False
#        Web           365   30        0.373864       0.628353             0.138945     15.339526            False
#        Web           365   60        0.477189       0.628353             0.177346     19.578929            False
#        Web           365   90        0.513880       0.628353             0.190982     21.084367            False
#        Web           365  120        0.611893       0.628353             0.227408     25.105805            False
#        Web           365  180        0.714837       0.628353             0.265667     29.329547            False
#        Web           365  270        0.831927       0.628353             0.309183     34.133723            False
#        Web           365  365        1.000000       0.628353             0.371647     41.029709            False
#
# ── App │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App             7    1        0.455478       0.130506             0.396035      5.243508            False
#        App             7    7        1.000000       0.130506             0.869494     11.512095            False
#
# ── App │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App            30    1        0.245738       0.149497             0.209001      5.243508            False
#        App            30    7        0.539517       0.149497             0.458860     11.512095            False
#        App            30   14        0.704643       0.149497             0.599301     15.035535            False
#        App            30   30        1.000000       0.149497             0.850503     21.337796            False
#
# ── App │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           120    1        0.121489       0.122087             0.106657      5.243508            False
#        App           120    7        0.266728       0.122087             0.234164     11.512095            False
#        App           120   14        0.348364       0.122087             0.305834     15.035535            False
#        App           120   30        0.494384       0.122087             0.434026     21.337796            False
#        App           120   60        0.714782       0.122087             0.627516     30.850226            False
#        App           120   90        0.893835       0.122087             0.784709     38.578233            False
#        App           120  120        1.000000       0.122087             0.877913     43.160356            False
#
# ── App │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        App           365    1        0.073499       0.122087             0.064526      5.243508            False
#        App           365    7        0.161367       0.122087             0.141666     11.512095            False
#        App           365   14        0.210756       0.122087             0.185025     15.035535            False
#        App           365   30        0.299095       0.122087             0.262580     21.337796            False
#        App           365   60        0.432433       0.122087             0.379638     30.850226            False
#        App           365   90        0.540757       0.122087             0.474738     38.578233            False
#        App           365  120        0.604986       0.122087             0.531125     43.160356            False
#        App           365  180        0.724780       0.122087             0.636294     51.706637            False
#        App           365  270        0.888287       0.122087             0.779839     63.371410            False
#        App           365  365        1.000000       0.122087             0.877913     71.341127            False
#
# ── Affiliate │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate             7    1        0.598514       0.567666             0.258758      6.940305            False
#  Affiliate             7    7        1.000000       0.567666             0.432334     11.595896            False
#
# ── Affiliate │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate            30    1        0.392658       0.568315             0.169505      6.940305            False
#  Affiliate            30    7        0.656054       0.568315             0.283209     11.595896            False
#  Affiliate            30   14        0.803490       0.568315             0.346855     14.201855            False
#  Affiliate            30   30        1.000000       0.568315             0.431685     17.675206            False
#
# ── Affiliate │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           120    1        0.242470       0.628353             0.090113      6.940305            False
#  Affiliate           120    7        0.405120       0.628353             0.150562     11.595896            False
#  Affiliate           120   14        0.496164       0.628353             0.184398     14.201855            False
#  Affiliate           120   30        0.617510       0.628353             0.229496     17.675206            False
#  Affiliate           120   60        0.774925       0.628353             0.287999     22.180944            False
#  Affiliate           120   90        0.891021       0.628353             0.331145     25.503998            False
#  Affiliate           120  120        1.000000       0.628353             0.371647     28.623331            False
#
# ── Affiliate │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           365    1        0.162318       0.628353             0.060325      6.940305            False
#  Affiliate           365    7        0.271201       0.628353             0.100791     11.595896            False
#  Affiliate           365   14        0.332149       0.628353             0.123442     14.201855            False
#  Affiliate           365   30        0.413382       0.628353             0.153632     17.675206            False
#  Affiliate           365   60        0.518761       0.628353             0.192796     22.180944            False
#  Affiliate           365   90        0.596480       0.628353             0.221680     25.503998            False
#  Affiliate           365  120        0.669434       0.628353             0.248793     28.623331            False
#  Affiliate           365  180        0.787581       0.628353             0.292702     33.674997            False
#  Affiliate           365  270        0.896558       0.628353             0.333203     38.334607            False
#  Affiliate           365  365        1.000000       0.628353             0.371647     42.757520            False
#
# ── Blended │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended             7    1        0.429745            0.0             0.429745      6.952154            False
#    Blended             7    7        1.000000            0.0             1.000000     16.177401            False
#
# ── Blended │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended            30    1        0.210821            0.0             0.210821      6.952154            False
#    Blended            30    7        0.490572            0.0             0.490572     16.177401            False
#    Blended            30   14        0.676819            0.0             0.676819     22.319166            False
#    Blended            30   30        1.000000            0.0             1.000000     32.976584            False
#
# ── Blended │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           120    1        0.099188            0.0             0.099188      6.952154            False
#    Blended           120    7        0.230806            0.0             0.230806     16.177401            False
#    Blended           120   14        0.318432            0.0             0.318432     22.319166            False
#    Blended           120   30        0.470483            0.0             0.470483     32.976584            False
#    Blended           120   60        0.658538            0.0             0.658538     46.157477            False
#    Blended           120   90        0.841134            0.0             0.841134     58.955804            False
#    Blended           120  120        1.000000            0.0             1.000000     70.090857            False
#
# ── Blended │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
# ...
#   [all] D  7:  [winsor_0pct] org=   532,015 acq=   743,420 share=41.7%
#   [all] D 30:  [winsor_0pct] org= 1,158,989 acq= 1,546,204 share=42.8%
#   [all] D 60:  [winsor_0pct] org= 1,927,634 acq= 2,399,520 share=44.5%
#   [all] D  7:  [winsor_0pct] org=   537,992 acq=   789,177 share=40.5%
#   [all] D 30:  [winsor_0pct] org= 1,033,861 acq= 1,789,082 share=36.6%
#   [all] D 60:  [winsor_0pct] org= 1,503,548 acq= 2,857,409 share=34.5%
#   [all] D 90:  [winsor_0pct] org= 1,938,831 acq= 3,943,858 share=33.0%
#   [all] D  7:  [winsor_0pct] org=   714,162 acq= 1,075,520 share=39.9%
#   [all] D 30:  [winsor_0pct] org= 1,470,690 acq= 2,406,266 share=37.9%
#   [all] D 60:  [winsor_0pct] org= 2,148,717 acq= 3,466,849 share=38.3%
#   [all] D 90:  [winsor_0pct] org= 2,660,104 acq= 4,444,365 share=37.4%
#   [all] D120:  [winsor_0pct] org= 3,165,095 acq= 5,289,681 share=37.4%
#   [all] D  7:  [winsor_0pct] org=   681,831 acq= 1,103,097 share=38.2%
#   [all] D 30:  [winsor_0pct] org= 1,527,163 acq= 2,640,927 share=36.6%
#   [all] D 60:  [winsor_0pct] org= 2,114,486 acq= 3,935,068 share=35.0%
#   [all] D 90:  [winsor_0pct] org= 2,489,773 acq= 5,205,960 share=32.4%
#   [all] D120:  [winsor_0pct] org= 2,872,921 acq= 6,265,108 share=31.4%
#   [all] D150:  [winsor_0pct] org= 3,332,521 acq= 7,392,336 share=31.1%
#   [all] D  7:  [winsor_0pct] org=   457,999 acq=   937,539 share=32.8%
#   [all] D 30:  [winsor_0pct] org= 1,045,350 acq= 2,118,398 share=33.0%
#   [all] D 60:  [winsor_0pct] org= 1,620,983 acq= 3,383,742 share=32.4%
#   [all] D 90:  [winsor_0pct] org= 2,246,444 acq= 4,472,272 share=33.4%
#   [all] D120:  [winsor_0pct] org= 2,716,303 acq= 5,358,356 share=33.6%
#   [all] D150:  [winsor_0pct] org= 3,114,510 acq= 6,406,955 share=32.7%
#   [all] D180:  [winsor_0pct] org= 3,492,285 acq= 7,334,999 share=32.3%
#   [all] D  7:  [winsor_0pct] org=   392,352 acq= 1,052,668 share=27.2%
#   [all] D 30:  [winsor_0pct] org=   933,645 acq= 2,364,654 share=28.3%
#   [all] D 60:  [winsor_0pct] org= 1,549,220 acq= 3,693,138 share=29.6%
#   [all] D 90:  [winsor_0pct] org= 2,238,514 acq= 4,985,734 share=31.0%
#   [all] D120:  [winsor_0pct] org= 2,726,988 acq= 6,140,241 share=30.8%
#   [all] D150:  [winsor_0pct] org= 3,055,669 acq= 7,300,197 share=29.5%
#   [all] D180:  [winsor_0pct] org= 3,348,234 acq= 8,328,395 share=28.7%
#   [all] D210:  [winsor_0pct] org= 3,773,058 acq= 9,214,388 share=29.1%
#   [all] D  7:  [winsor_0pct] org=   414,876 acq= 1,112,163 share=27.2%
#   [all] D 30:  [winsor_0pct] org=   768,357 acq= 2,531,410 share=23.3%
#   [all] D 60:  [winsor_0pct] org= 1,152,739 acq= 3,822,560 share=23.2%
#   [all] D 90:  [winsor_0pct] org= 1,419,652 acq= 4,874,312 share=22.6%
#   [all] D120:  [winsor_0pct] org= 1,732,235 acq= 5,735,529 share=23.2%
#   [all] D150:  [winsor_0pct] org= 2,051,109 acq= 6,560,613 share=23.8%
#   [all] D180:  [winsor_0pct] org= 2,309,850 acq= 7,275,104 share=24.1%
#   [all] D210:  [winsor_0pct] org= 2,564,802 acq= 8,107,049 share=24.0%
#   [all] D240:  [winsor_0pct] org= 2,795,272 acq= 8,932,623 share=23.8%
#   [all] D  7:  [winsor_0pct] org=   321,155 acq= 1,500,425 share=17.6%
#   [all] D 30:  [winsor_0pct] org=   804,466 acq= 3,341,795 share=19.4%
#   [all] D 60:  [winsor_0pct] org= 1,107,494 acq= 4,828,301 share=18.7%
#   [all] D 90:  [winsor_0pct] org= 1,379,857 acq= 6,068,652 share=18.5%
#   [all] D120:  [winsor_0pct] org= 1,619,542 acq= 7,199,693 share=18.4%
#   [all] D150:  [winsor_0pct] org= 1,909,024 acq= 8,332,873 share=18.6%
#   [all] D180:  [winsor_0pct] org= 2,163,685 acq= 9,632,813 share=18.3%
#   [all] D210:  [winsor_0pct] org= 2,399,308 acq=10,893,106 share=18.1%
#   [all] D240:  [winsor_0pct] org= 2,609,062 acq=11,913,376 share=18.0%
#   [all] D270:  [winsor_0pct] org= 2,794,647 acq=13,053,468 share=17.6%
#   [all] D  7:  [winsor_0pct] org=   203,371 acq= 1,337,297 share=13.2%
#   [all] D 30:  [winsor_0pct] org=   520,846 acq= 2,765,629 share=15.8%
#   [all] D 60:  [winsor_0pct] org=   770,354 acq= 4,034,552 share=16.0%
#   [all] D 90:  [winsor_0pct] org= 1,006,043 acq= 5,079,343 share=16.5%
#   [all] D120:  [winsor_0pct] org= 1,191,069 acq= 6,078,329 share=16.4%
#   [all] D150:  [winsor_0pct] org= 1,544,929 acq= 7,031,426 share=18.0%
#   [all] D180:  [winsor_0pct] org= 1,754,867 acq= 7,918,404 share=18.1%
#   [all] D210:  [winsor_0pct] org= 1,998,462 acq= 8,897,291 share=18.3%
#   [all] D240:  [winsor_0pct] org= 2,251,929 acq= 9,958,703 share=18.4%
#   [all] D270:  [winsor_0pct] org= 2,535,946 acq=10,883,575 share=18.9%
#   [all] D365:  [winsor_0pct] org= 3,751,560 acq=13,806,237 share=21.4%
#
# ────────────────────────────────────────────────────────────
# [lonestar] MONITOR · ORGANIC SHARE
# ────────────────────────────────────────────────────────────
# rows: 66
#
# endpoint shares — scope=all:
# scope  goal_horizon  organic_share_pct  users_org  users_acq
#   all             7           0.383016      21269      62762
#   all            30           0.360781      20807      59309
#   all            60           0.445474      25467      43200
#   all            90           0.329582      23916      52493
#   all           120           0.374356      24938      50490
#   all           150           0.310729      27428      60253
#   all           180           0.322545      28158      54561
#   all           210           0.290516      23971      94370
#   all           240           0.238344      20794      99146
#   all           270           0.176339      19308     109217
#   all           365           0.213669      14481     105561
#
# ────────────────────────────────────────────────────────────
# [lonestar] PART 4/4 — goal construction
# ────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# [lonestar] MONITOR · GOALS
# ────────────────────────────────────────────────────────────
# total goal rows: 5,166
# counts by population:
# population
# Affiliate    1722
# Blended      1722
# Web          1722
#
# ── Web │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web             7    1        0.380516       0.383016             0.234772      6.433123            False
#        Web             7    7        1.000000       0.383016             0.616984     16.906335            False
#
# ── Web │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web            30    1        0.189430       0.360781             0.121087      6.433123            False
#        Web            30    7        0.497824       0.360781             0.318218     16.906335            False
#        Web            30   14        0.672014       0.360781             0.429565     22.821946            False
#        Web            30   30        1.000000       0.360781             0.639219     33.960499            False
#
# ── Web │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           120    1        0.085523       0.374356             0.053507      6.433123            False
#        Web           120    7        0.224755       0.374356             0.140617     16.906335            False
#        Web           120   14        0.303398       0.374356             0.189819     22.821946            False
#        Web           120   30        0.451476       0.374356             0.282463     33.960499            False
#        Web           120   60        0.666054       0.374356             0.416713     50.101299            False
#        Web           120   90        0.866619       0.374356             0.542195     65.188068            False
#        Web           120  120        1.000000       0.374356             0.625644     75.221123            False
#
# ── Web │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#        Web           365    1        0.040350       0.213669             0.031729      6.433123            False
#        Web           365    7        0.106041       0.213669             0.083383     16.906335            False
#        Web           365   14        0.143145       0.213669             0.112559     22.821946            False
#        Web           365   30        0.213008       0.213669             0.167495     33.960499            False
#        Web           365   60        0.314247       0.213669             0.247102     50.101299            False
#        Web           365   90        0.408875       0.213669             0.321511     65.188068            False
#        Web           365  120        0.471805       0.213669             0.370995     75.221123            False
#        Web           365  180        0.571559       0.213669             0.449434     91.125220            False
#        Web           365  270        0.794553       0.213669             0.624782    126.677791            False
#        Web           365  365        1.000000       0.213669             0.786331    159.432763            False
#
# ── Affiliate │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate             7    1        0.551209       0.383016             0.340087      5.010583            False
#  Affiliate             7    7        1.000000       0.383016             0.616984      9.090165            False
#
# ── Affiliate │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate            30    1        0.360343       0.360781             0.230338      5.010583            False
#  Affiliate            30    7        0.653733       0.360781             0.417878      9.090165            False
#  Affiliate            30   14        0.790982       0.360781             0.505611     10.998628            False
#  Affiliate            30   30        1.000000       0.360781             0.639219     13.905021            False
#
# ── Affiliate │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           120    1        0.226916       0.374356             0.141969      5.010583            False
#  Affiliate           120    7        0.411670       0.374356             0.257559      9.090165            False
#  Affiliate           120   14        0.498099       0.374356             0.311633     10.998628            False
#  Affiliate           120   30        0.629722       0.374356             0.393982     13.905021            False
#  Affiliate           120   60        0.751257       0.374356             0.470020     16.588663            False
#  Affiliate           120   90        0.885634       0.374356             0.554092     19.555874            False
#  Affiliate           120  120        1.000000       0.374356             0.625644     22.081207            False
#
# ── Affiliate │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#  Affiliate           365    1        0.140275       0.213669             0.110303      5.010583            False
#  Affiliate           365    7        0.254487       0.213669             0.200111      9.090165            False
#  Affiliate           365   14        0.307916       0.213669             0.242123     10.998628            False
#  Affiliate           365   30        0.389282       0.213669             0.306105     13.905021            False
#  Affiliate           365   60        0.464413       0.213669             0.365182     16.588663            False
#  Affiliate           365   90        0.547483       0.213669             0.430502     19.555874            False
#  Affiliate           365  120        0.618181       0.213669             0.486095     22.081207            False
#  Affiliate           365  180        0.731994       0.213669             0.575589     26.146553            False
#  Affiliate           365  270        0.874741       0.213669             0.687836     31.245420            False
#  Affiliate           365  365        1.000000       0.213669             0.786331     35.719628            False
#
# ── Blended │ horizon D7 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended             7    1        0.394095            0.0             0.394095      7.010079            False
#    Blended             7    7        1.000000            0.0             1.000000     17.787786            False
#
# ── Blended │ horizon D30 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended            30    1        0.190021            0.0             0.190021      7.010079            False
#    Blended            30    7        0.482171            0.0             0.482171     17.787786            False
#    Blended            30   14        0.656415            0.0             0.656415     24.215833            False
#    Blended            30   30        1.000000            0.0             1.000000     36.891042            False
#
# ── Blended │ horizon D120 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           120    1        0.080106            0.0             0.080106      7.010079            False
#    Blended           120    7        0.203265            0.0             0.203265     17.787786            False
#    Blended           120   14        0.276720            0.0             0.276720     24.215833            False
#    Blended           120   30        0.421563            0.0             0.421563     36.891042            False
#    Blended           120   60        0.652037            0.0             0.652037     57.059914            False
#    Blended           120   90        0.840291            0.0             0.840291     73.534043            False
#    Blended           120  120        1.000000            0.0             1.000000     87.510255            False
#
# ── Blended │ horizon D365 ──
# population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio  ARPU_nominal  is_extrapolated
#    Blended           365    1        0.035690            0.0             0.035690      7.010079            False
#    Blended           365    7        0.090563            0.0             0.090563     17.787786            False
#    Blended           365   14        0.123290            0.0             0.123290     24.215833            False
#    Blended           365   30        0.187824            0.0             0.187824     36.891042            False
#    Blended           365   60        0.290509            0.0             0.290509     57.059914            False
#    Blended           365   90        0.374384            0.0             0.374384     73.534043            False
#    Blended           365  120        0.445541            0.0             0.445541     87.510255            False
#    Blended           365  180        0.594624            0.0             0.594624    116.792157            False
#    Blended           365  270        0.790577            0.0             0.790577    155.279882            False
#    Blended           365  365        1.000000            0.0             1.000000    196.413341            False
#
# [lonestar] COMPLETE — goals 5,166 | curve 1,095 | organic 66 | cv 30
#
# ============================================================
# UNIFIED RUN COMPLETE
#   as_of_date     = 2026-08-03
#   brands         = ['realprize', 'lonestar']
#   cv rows        = 70
#   curve rows     = 2,555
#   organic rows   = 198
#   goals (main)   = 12,054
#   goals (detail) = 12,054
# ============================================================
#
# Row counts by brand × population:
#     brand population  n_rows
#  lonestar  Affiliate    1722
#  lonestar    Blended    1722
#  lonestar        Web    1722
# realprize  Affiliate    1722
# realprize        App    1722
# realprize    Blended    1722
# realprize        Web    1722

# %%
# ══════════════════════════════════════════════════════════════
# PREVIEW — main goals table + Combined-style spot checks
# ══════════════════════════════════════════════════════════════

print('MAIN GOALS (head):')
print(goals_df.head(20).to_string(index=False))

preview_days = [1, 7, 14, 30, 60, 90, 120, 150, 180, 210, 240, 270, 365]
preview_horizons = [7, 30, 120, 365]

for brand in RUN_BRANDS:
    pops = list(BRAND_CONFIGS[brand]['populations']) + ['Blended']
    for pop in pops:
        for horizon in preview_horizons:
            sub = goals_df.loc[
                (goals_df['brand'] == brand) &
                (goals_df['population'] == pop) &
                (goals_df['goal_horizon'] == horizon) &
                (goals_df['day'].isin(preview_days))
            ]
            if sub.empty:
                continue
            print(f'\n── {brand} │ {pop} │ horizon D{horizon} ──')
            print(sub[MAIN_GOAL_COLS].to_string(index=False))

# CV flags
if not cv_df.empty and 'flagged' in cv_df.columns:
    flagged = cv_df.loc[cv_df['flagged'] == True]
    if not flagged.empty:
        print('\n>>> FLAGGED PATCHES:')
        cols = [c for c in ['brand', 'population', 'patch', 'cv_after', 'robust_cv_after', 'robust_to_standard_cv_ratio', 'variability_diagnosis'] if c in flagged.columns]
        print(flagged[cols].to_string(index=False))
    else:
        print('\nNo flagged patches.')
# Out:
# MAIN GOALS (head):
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web             7    1        0.547503       0.567666             0.236704
# realprize        Web             7    2        0.676041       0.567666             0.292276
# realprize        Web             7    3        0.740984       0.567666             0.320353
# realprize        Web             7    4        0.822616       0.567666             0.355645
# realprize        Web             7    5        0.877077       0.567666             0.379190
# realprize        Web             7    6        0.937281       0.567666             0.405219
# realprize        Web             7    7        1.000000       0.567666             0.432334
# realprize        Web            30    1        0.299505       0.568315             0.129292
# realprize        Web            30    2        0.369820       0.568315             0.159646
# realprize        Web            30    3        0.405346       0.568315             0.174982
# realprize        Web            30    4        0.450002       0.568315             0.194259
# realprize        Web            30    5        0.479795       0.568315             0.207120
# realprize        Web            30    6        0.512728       0.568315             0.221337
# realprize        Web            30    7        0.547038       0.568315             0.236148
# realprize        Web            30    8        0.592256       0.568315             0.255668
# realprize        Web            30    9        0.616286       0.568315             0.266042
# realprize        Web            30   10        0.669917       0.568315             0.289193
# realprize        Web            30   11        0.691184       0.568315             0.298374
# realprize        Web            30   12        0.703865       0.568315             0.303848
# realprize        Web            30   13        0.726597       0.568315             0.313661
#
# ── realprize │ Web │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web             7    1        0.547503       0.567666             0.236704
# realprize        Web             7    7        1.000000       0.567666             0.432334
#
# ── realprize │ Web │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web            30    1        0.299505       0.568315             0.129292
# realprize        Web            30    7        0.547038       0.568315             0.236148
# realprize        Web            30   14        0.745814       0.568315             0.321957
# realprize        Web            30   30        1.000000       0.568315             0.431685
#
# ── realprize │ Web │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web           120    1        0.182996       0.628353             0.068010
# realprize        Web           120    7        0.334238       0.628353             0.124218
# realprize        Web           120   14        0.455689       0.628353             0.169355
# realprize        Web           120   30        0.610995       0.628353             0.227075
# realprize        Web           120   60        0.779857       0.628353             0.289831
# realprize        Web           120   90        0.839820       0.628353             0.312117
# realprize        Web           120  120        1.000000       0.628353             0.371647
#
# ── realprize │ Web │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        Web           365    1        0.111974       0.628353             0.041615
# realprize        Web           365    7        0.204518       0.628353             0.076008
# realprize        Web           365   14        0.278833       0.628353             0.103627
# realprize        Web           365   30        0.373864       0.628353             0.138945
# realprize        Web           365   60        0.477189       0.628353             0.177346
# realprize        Web           365   90        0.513880       0.628353             0.190982
# realprize        Web           365  120        0.611893       0.628353             0.227408
# realprize        Web           365  150        0.665410       0.628353             0.247297
# realprize        Web           365  180        0.714837       0.628353             0.265667
# realprize        Web           365  210        0.761205       0.628353             0.282900
# realprize        Web           365  240        0.795845       0.628353             0.295773
# realprize        Web           365  270        0.831927       0.628353             0.309183
# realprize        Web           365  365        1.000000       0.628353             0.371647
#
# ── realprize │ App │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App             7    1        0.455478       0.130506             0.396035
# realprize        App             7    7        1.000000       0.130506             0.869494
#
# ── realprize │ App │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App            30    1        0.245738       0.149497             0.209001
# realprize        App            30    7        0.539517       0.149497             0.458860
# realprize        App            30   14        0.704643       0.149497             0.599301
# realprize        App            30   30        1.000000       0.149497             0.850503
#
# ── realprize │ App │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App           120    1        0.121489       0.122087             0.106657
# realprize        App           120    7        0.266728       0.122087             0.234164
# realprize        App           120   14        0.348364       0.122087             0.305834
# realprize        App           120   30        0.494384       0.122087             0.434026
# realprize        App           120   60        0.714782       0.122087             0.627516
# realprize        App           120   90        0.893835       0.122087             0.784709
# realprize        App           120  120        1.000000       0.122087             0.877913
#
# ── realprize │ App │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize        App           365    1        0.073499       0.122087             0.064526
# realprize        App           365    7        0.161367       0.122087             0.141666
# realprize        App           365   14        0.210756       0.122087             0.185025
# realprize        App           365   30        0.299095       0.122087             0.262580
# realprize        App           365   60        0.432433       0.122087             0.379638
# realprize        App           365   90        0.540757       0.122087             0.474738
# realprize        App           365  120        0.604986       0.122087             0.531125
# realprize        App           365  150        0.660057       0.122087             0.579473
# realprize        App           365  180        0.724780       0.122087             0.636294
# realprize        App           365  210        0.809207       0.122087             0.710413
# realprize        App           365  240        0.844652       0.122087             0.741531
# realprize        App           365  270        0.888287       0.122087             0.779839
# realprize        App           365  365        1.000000       0.122087             0.877913
#
# ── realprize │ Affiliate │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate             7    1        0.598514       0.567666             0.258758
# realprize  Affiliate             7    7        1.000000       0.567666             0.432334
#
# ── realprize │ Affiliate │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate            30    1        0.392658       0.568315             0.169505
# realprize  Affiliate            30    7        0.656054       0.568315             0.283209
# realprize  Affiliate            30   14        0.803490       0.568315             0.346855
# realprize  Affiliate            30   30        1.000000       0.568315             0.431685
#
# ── realprize │ Affiliate │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate           120    1        0.242470       0.628353             0.090113
# realprize  Affiliate           120    7        0.405120       0.628353             0.150562
# realprize  Affiliate           120   14        0.496164       0.628353             0.184398
# realprize  Affiliate           120   30        0.617510       0.628353             0.229496
# realprize  Affiliate           120   60        0.774925       0.628353             0.287999
# realprize  Affiliate           120   90        0.891021       0.628353             0.331145
# realprize  Affiliate           120  120        1.000000       0.628353             0.371647
#
# ── realprize │ Affiliate │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize  Affiliate           365    1        0.162318       0.628353             0.060325
# realprize  Affiliate           365    7        0.271201       0.628353             0.100791
# realprize  Affiliate           365   14        0.332149       0.628353             0.123442
# realprize  Affiliate           365   30        0.413382       0.628353             0.153632
# realprize  Affiliate           365   60        0.518761       0.628353             0.192796
# realprize  Affiliate           365   90        0.596480       0.628353             0.221680
# realprize  Affiliate           365  120        0.669434       0.628353             0.248793
# realprize  Affiliate           365  150        0.728681       0.628353             0.270812
# realprize  Affiliate           365  180        0.787581       0.628353             0.292702
# realprize  Affiliate           365  210        0.830991       0.628353             0.308835
# realprize  Affiliate           365  240        0.866446       0.628353             0.322012
# realprize  Affiliate           365  270        0.896558       0.628353             0.333203
# realprize  Affiliate           365  365        1.000000       0.628353             0.371647
#
# ── realprize │ Blended │ horizon D7 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended             7    1        0.429745            0.0             0.429745
# realprize    Blended             7    7        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D30 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended            30    1        0.210821            0.0             0.210821
# realprize    Blended            30    7        0.490572            0.0             0.490572
# realprize    Blended            30   14        0.676819            0.0             0.676819
# realprize    Blended            30   30        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D120 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended           120    1        0.099188            0.0             0.099188
# realprize    Blended           120    7        0.230806            0.0             0.230806
# realprize    Blended           120   14        0.318432            0.0             0.318432
# realprize    Blended           120   30        0.470483            0.0             0.470483
# realprize    Blended           120   60        0.658538            0.0             0.658538
# realprize    Blended           120   90        0.841134            0.0             0.841134
# realprize    Blended           120  120        1.000000            0.0             1.000000
#
# ── realprize │ Blended │ horizon D365 ──
#     brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# realprize    Blended           365    1        0.052319            0.0             0.052319
# realprize    Blended           365    7        0.121744            0.0             0.121744
# realprize    Blended           365   14        0.167965            0.0             0.167965
# realprize    Blended           365   30        0.248168            0.0             0.248168
# realprize    Blended           365   60        0.347361            0.0             0.347361
# realprize    Blended           365   90        0.443676            0.0             0.443676
# realprize    Blended           365  120        0.527474            0.0             0.527474
# realprize    Blended           365  150        0.585205            0.0             0.585205
# realprize    Blended           365  180        0.651573            0.0             0.651573
# realprize    Blended           365  210        0.716309            0.0             0.716309
# realprize    Blended           365  240        0.768545            0.0             0.768545
# realprize    Blended           365  270        0.829411            0.0             0.829411
# realprize    Blended           365  365        1.000000            0.0             1.000000
#
# ── lonestar │ Web │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web             7    1        0.380516       0.383016             0.234772
# lonestar        Web             7    7        1.000000       0.383016             0.616984
#
# ── lonestar │ Web │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web            30    1        0.189430       0.360781             0.121087
# lonestar        Web            30    7        0.497824       0.360781             0.318218
# lonestar        Web            30   14        0.672014       0.360781             0.429565
# lonestar        Web            30   30        1.000000       0.360781             0.639219
#
# ── lonestar │ Web │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web           120    1        0.085523       0.374356             0.053507
# lonestar        Web           120    7        0.224755       0.374356             0.140617
# lonestar        Web           120   14        0.303398       0.374356             0.189819
# lonestar        Web           120   30        0.451476       0.374356             0.282463
# lonestar        Web           120   60        0.666054       0.374356             0.416713
# lonestar        Web           120   90        0.866619       0.374356             0.542195
# lonestar        Web           120  120        1.000000       0.374356             0.625644
#
# ── lonestar │ Web │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar        Web           365    1        0.040350       0.213669             0.031729
# lonestar        Web           365    7        0.106041       0.213669             0.083383
# lonestar        Web           365   14        0.143145       0.213669             0.112559
# lonestar        Web           365   30        0.213008       0.213669             0.167495
# lonestar        Web           365   60        0.314247       0.213669             0.247102
# lonestar        Web           365   90        0.408875       0.213669             0.321511
# lonestar        Web           365  120        0.471805       0.213669             0.370995
# lonestar        Web           365  150        0.515658       0.213669             0.405478
# lonestar        Web           365  180        0.571559       0.213669             0.449434
# lonestar        Web           365  210        0.673351       0.213669             0.529476
# lonestar        Web           365  240        0.733514       0.213669             0.576785
# lonestar        Web           365  270        0.794553       0.213669             0.624782
# lonestar        Web           365  365        1.000000       0.213669             0.786331
#
# ── lonestar │ Affiliate │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate             7    1        0.551209       0.383016             0.340087
# lonestar  Affiliate             7    7        1.000000       0.383016             0.616984
#
# ── lonestar │ Affiliate │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate            30    1        0.360343       0.360781             0.230338
# lonestar  Affiliate            30    7        0.653733       0.360781             0.417878
# lonestar  Affiliate            30   14        0.790982       0.360781             0.505611
# lonestar  Affiliate            30   30        1.000000       0.360781             0.639219
#
# ── lonestar │ Affiliate │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate           120    1        0.226916       0.374356             0.141969
# lonestar  Affiliate           120    7        0.411670       0.374356             0.257559
# lonestar  Affiliate           120   14        0.498099       0.374356             0.311633
# lonestar  Affiliate           120   30        0.629722       0.374356             0.393982
# lonestar  Affiliate           120   60        0.751257       0.374356             0.470020
# lonestar  Affiliate           120   90        0.885634       0.374356             0.554092
# lonestar  Affiliate           120  120        1.000000       0.374356             0.625644
#
# ── lonestar │ Affiliate │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar  Affiliate           365    1        0.140275       0.213669             0.110303
# lonestar  Affiliate           365    7        0.254487       0.213669             0.200111
# lonestar  Affiliate           365   14        0.307916       0.213669             0.242123
# lonestar  Affiliate           365   30        0.389282       0.213669             0.306105
# lonestar  Affiliate           365   60        0.464413       0.213669             0.365182
# lonestar  Affiliate           365   90        0.547483       0.213669             0.430502
# lonestar  Affiliate           365  120        0.618181       0.213669             0.486095
# lonestar  Affiliate           365  150        0.684516       0.213669             0.538256
# lonestar  Affiliate           365  180        0.731994       0.213669             0.575589
# lonestar  Affiliate           365  210        0.785745       0.213669             0.617856
# lonestar  Affiliate           365  240        0.835025       0.213669             0.656606
# lonestar  Affiliate           365  270        0.874741       0.213669             0.687836
# lonestar  Affiliate           365  365        1.000000       0.213669             0.786331
#
# ── lonestar │ Blended │ horizon D7 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended             7    1        0.394095            0.0             0.394095
# lonestar    Blended             7    7        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D30 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended            30    1        0.190021            0.0             0.190021
# lonestar    Blended            30    7        0.482171            0.0             0.482171
# lonestar    Blended            30   14        0.656415            0.0             0.656415
# lonestar    Blended            30   30        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D120 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended           120    1        0.080106            0.0             0.080106
# lonestar    Blended           120    7        0.203265            0.0             0.203265
# lonestar    Blended           120   14        0.276720            0.0             0.276720
# lonestar    Blended           120   30        0.421563            0.0             0.421563
# lonestar    Blended           120   60        0.652037            0.0             0.652037
# lonestar    Blended           120   90        0.840291            0.0             0.840291
# lonestar    Blended           120  120        1.000000            0.0             1.000000
#
# ── lonestar │ Blended │ horizon D365 ──
#    brand population  goal_horizon  day  raw_goal_ratio  organic_share  adjusted_goal_ratio
# lonestar    Blended           365    1        0.035690            0.0             0.035690
# lonestar    Blended           365    7        0.090563            0.0             0.090563
# lonestar    Blended           365   14        0.123290            0.0             0.123290
# lonestar    Blended           365   30        0.187824            0.0             0.187824
# lonestar    Blended           365   60        0.290509            0.0             0.290509
# lonestar    Blended           365   90        0.374384            0.0             0.374384
# lonestar    Blended           365  120        0.445541            0.0             0.445541
# lonestar    Blended           365  150        0.522910            0.0             0.522910
# lonestar    Blended           365  180        0.594624            0.0             0.594624
# lonestar    Blended           365  210        0.667535            0.0             0.667535
# lonestar    Blended           365  240        0.729795            0.0             0.729795
# lonestar    Blended           365  270        0.790577            0.0             0.790577
# lonestar    Blended           365  365        1.000000            0.0             1.000000
#
# >>> FLAGGED PATCHES:
#     brand population    patch  cv_after  robust_cv_after  robust_to_standard_cv_ratio  variability_diagnosis
# realprize        Web     1->7  0.244573         0.296364                     1.211762                 REVIEW
# realprize        Web    7->14  0.150728         0.144286                     0.957259 CONSISTENT_VARIABILITY
# realprize        Web   14->30  0.220869         0.211614                     0.958097 CONSISTENT_VARIABILITY
# realprize        Web   30->60  0.201778         0.208584                     1.033731 CONSISTENT_VARIABILITY
# realprize        App     1->7  0.223079         0.185590                     0.831947 CONSISTENT_VARIABILITY
# realprize    Blended     1->7  0.192020         0.210441                     1.095931 CONSISTENT_VARIABILITY
#  lonestar        Web     1->7  0.316002         0.233063                     0.737537 CONSISTENT_VARIABILITY
#  lonestar        Web   14->30  0.158852         0.145767                     0.917626 CONSISTENT_VARIABILITY
#  lonestar        Web   30->60  0.162292         0.160278                     0.987592 CONSISTENT_VARIABILITY
#  lonestar        Web 180->270  0.194077         0.160412                     0.826537 CONSISTENT_VARIABILITY
#  lonestar    Blended     1->7  0.238197         0.291236                     1.222671                 REVIEW

# %%
# ══════════════════════════════════════════════════════════════
# EXPORT — unique run folder when re-run same day
# ══════════════════════════════════════════════════════════════
# Naming when you run more than once per day:
#   runs/<as_of>_<brands>_<run_ts>/
#   e.g. 2026-08-05_rp_142233/   or  2026-08-05_rp_ls_143015/
# run_ts = local clock when this export cell runs (HHMMSS) — never overwrites.
# as_of_date is the cohort anchor (today-2), not wall-clock time.
# ══════════════════════════════════════════════════════════════

from datetime import datetime
from pathlib import Path
import os
import re

# Brand slug: realprize → rp, lonestar → ls (stable short codes)
_BRAND_SLUG = {'realprize': 'rp', 'lonestar': 'ls'}
brand_slug = '_'.join(
    _BRAND_SLUG.get(b, re.sub(r'[^a-z0-9]+', '', b.lower())[:6])
    for b in RUN_BRANDS
)

# Unique per execution
exported_at = datetime.now()
run_ts = exported_at.strftime('%H%M%S')
run_tag = f"{AS_OF_DATE.date()}_{brand_slug}_{EXPERIMENT_TAG}_{run_ts}"  # ADDED

main_goals_path    = f'combined_goals_{run_tag}.csv'
detail_goals_path  = f'combined_goals_detail_{run_tag}.csv'
curve_path         = f'combined_arpu_curve_{run_tag}.csv'
organic_path       = f'combined_organic_share_{run_tag}.csv'
cv_path            = f'combined_cv_summary_{run_tag}_robust_cv_test.csv'  # ADDED: distinct filename

goals_df.to_csv(main_goals_path, index=False)
goals_detail_df.to_csv(detail_goals_path, index=False)
curve_df.to_csv(curve_path, index=False)
organic_df.to_csv(organic_path, index=False)
cv_df.to_csv(cv_path, index=False)

print(f'Run tag: {run_tag}')
print(f'  as_of_date (data) = {AS_OF_DATE.date()}')
print(f'  brands            = {RUN_BRANDS}')
print(f'  run_ts (export)   = {run_ts}  (unique each time this cell runs)')
print('Saved in working directory:')
for pth in [main_goals_path, detail_goals_path, curve_path, organic_path, cv_path]:
    print(f'  {pth}')

run_candidates = [
    Path('/content/drive/MyDrive/lee_project/marketing_goals/runs'),
    Path('/content/drive/My Drive/lee_project/marketing_goals/runs'),
]
drive_runs = next((c for c in run_candidates if c.is_dir()), None)

if drive_runs is not None:
    out_dir = drive_runs / run_tag
    out_dir.mkdir(parents=True, exist_ok=True)
    goals_df.to_csv(out_dir / 'combined_goals.csv', index=False)
    goals_detail_df.to_csv(out_dir / 'combined_goals_detail.csv', index=False)
    curve_df.to_csv(out_dir / 'combined_arpu_curve.csv', index=False)
    organic_df.to_csv(out_dir / 'combined_organic_share.csv', index=False)
    cv_df.to_csv(out_dir / 'combined_cv_summary_robust_cv_test.csv', index=False)  # ADDED
    meta = pd.DataFrame([{
        'run_tag': run_tag,
        'as_of_date': str(AS_OF_DATE.date()),
        'brands': ','.join(RUN_BRANDS),
        'brand_slug': brand_slug,
        'run_ts': run_ts,
        'exported_at': exported_at.isoformat(timespec='seconds'),
        'main_columns': ','.join(MAIN_GOAL_COLS),
        'env': 'colab',
        'experiment_tag': EXPERIMENT_TAG,  # ADDED
    }])
    meta.to_csv(out_dir / 'run_meta.csv', index=False)
    print(f'\nAlso wrote to: {out_dir}')
    print('(Each re-run creates a NEW folder under runs/ — previous runs stay.)')
else:
    print('\nDrive runs/ not found (mount skip or wrong path).')
    print('Browser downloads below still give you the full pack.')

from google.colab import files
for pth in [main_goals_path, detail_goals_path, curve_path, organic_path, cv_path]:
    files.download(pth)
print('Downloads started in browser.')
# Out:
# Run tag: 2026-08-03_rp_ls_robust_cv_111132
#   as_of_date (data) = 2026-08-03
#   brands            = ['realprize', 'lonestar']
#   run_ts (export)   = 111132  (unique each time this cell runs)
# Saved in working directory:
#   combined_goals_2026-08-03_rp_ls_robust_cv_111132.csv
#   combined_goals_detail_2026-08-03_rp_ls_robust_cv_111132.csv
#   combined_arpu_curve_2026-08-03_rp_ls_robust_cv_111132.csv
#   combined_organic_share_2026-08-03_rp_ls_robust_cv_111132.csv
#   combined_cv_summary_2026-08-03_rp_ls_robust_cv_111132_robust_cv_test.csv
#
# Also wrote to: /content/drive/MyDrive/lee_project/marketing_goals/runs/2026-08-03_rp_ls_robust_cv_111132
# (Each re-run creates a NEW folder under runs/ — previous runs stay.)
# Downloads started in browser.

# %%
# ══════════════════════════════════════════════════════════════
# ADDED: robust CV experiment — comparison analysis + plots
# Question: when standard CV is high, is it outlier-driven (Robust CV
# much lower) or structural (both high)?
# Does NOT change goals / trim / flagged methodology.
# ══════════════════════════════════════════════════════════════

import matplotlib.pyplot as plt

COMPARE_COLS = [
    'brand', 'population', 'patch', 'cohort_start', 'cohort_end',
    'n_cohort_dates_total', 'n_cohort_dates_kept',
    'n_users_pre_trim', 'n_users_post_trim',
    'cv_before', 'robust_cv_before', 'cv_after', 'robust_cv_after',
    'cv_minus_robust_cv_after', 'robust_to_standard_cv_ratio',
    'flagged', 'variability_diagnosis',
    'removed_dates', 'trim_method', 'trim_pct',
]

cmp = cv_df.copy()
have = [c for c in COMPARE_COLS if c in cmp.columns]
cmp = cmp[have].copy()

print('=== Robust CV comparison table (all patches) ===')
print(f'Classification rule (edit constants in helpers cell):')
print(f'  OUTLIER_DRIVEN         if robust/cv <= {ROBUST_OUTLIER_RATIO_MAX}')
print(f'  CONSISTENT_VARIABILITY if {ROBUST_OUTLIER_RATIO_MAX} < robust/cv <= {ROBUST_CONSISTENT_RATIO_MAX}')
print(f'  REVIEW                 otherwise / missing')
print()
print(cmp.to_string(index=False))

# also save a focused comparison CSV next to other exports
cmp_name = f'combined_cv_robust_compare_{run_tag}.csv'
cmp.to_csv(cmp_name, index=False)
print(f'\nSaved working-dir comparison CSV: {cmp_name}')
if 'drive_runs' in dir() and drive_runs is not None and 'out_dir' in dir() and out_dir is not None:
    cmp.to_csv(out_dir / 'combined_cv_robust_compare.csv', index=False)
    print(f'Saved Drive comparison CSV: {out_dir / "combined_cv_robust_compare.csv"}')

# 1) Average / median CV vs Robust CV by patch
print('\n=== 1) Mean / median CV vs Robust CV by patch ===')
g1 = (
    cmp.groupby('patch', sort=False)
       .agg(
           n=('cv_after', 'count'),
           cv_after_mean=('cv_after', 'mean'),
           cv_after_median=('cv_after', 'median'),
           robust_cv_after_mean=('robust_cv_after', 'mean'),
           robust_cv_after_median=('robust_cv_after', 'median'),
       )
       .reset_index()
)
print(g1.to_string(index=False))

# 2) by brand × population × patch
print('\n=== 2) CV vs Robust CV by brand × population × patch ===')
g2_cols = [c for c in [
    'brand', 'population', 'patch', 'cv_before', 'robust_cv_before',
    'cv_after', 'robust_cv_after', 'cv_minus_robust_cv_after',
    'robust_to_standard_cv_ratio', 'flagged', 'variability_diagnosis',
] if c in cmp.columns]
print(cmp[g2_cols].sort_values(['brand', 'population', 'patch']).to_string(index=False))

# 3) flagged patches
print('\n=== 3) Flagged patches (cv_after desc) with Robust CV ===')
if 'flagged' in cmp.columns:
    fl = cmp.loc[cmp['flagged'] == True].sort_values('cv_after', ascending=False)
    if fl.empty:
        print('(none flagged)')
    else:
        print(fl[g2_cols].to_string(index=False))
else:
    fl = cmp.iloc[0:0]
    print('flagged column missing')

# 4) high CV, substantially lower Robust CV
print('\n=== 4) High CV but substantially lower Robust CV (OUTLIER_DRIVEN) ===')
od = cmp.loc[cmp.get('variability_diagnosis') == 'OUTLIER_DRIVEN'].sort_values('cv_after', ascending=False)
if od.empty:
    print('(none)')
else:
    print(od[g2_cols].to_string(index=False))

# 5) both remain high (consistent + still above flag threshold when available)
print('\n=== 5) Both metrics remain high (CONSISTENT_VARIABILITY & flagged) ===')
both = cmp.loc[
    (cmp.get('variability_diagnosis') == 'CONSISTENT_VARIABILITY')
    & (cmp.get('flagged') == True)
].sort_values('cv_after', ascending=False)
if both.empty:
    # fallback: consistent and cv_after in top quartile
    print('(no flagged+consistent rows; showing CONSISTENT_VARIABILITY with cv_after >= median of flagged or 0.15)')
    thr = 0.15
    both = cmp.loc[
        (cmp.get('variability_diagnosis') == 'CONSISTENT_VARIABILITY')
        & (cmp['cv_after'] >= thr)
    ].sort_values('cv_after', ascending=False)
if both.empty:
    print('(none)')
else:
    print(both[g2_cols].to_string(index=False))

# --- plots ---
plot_df = cmp.dropna(subset=['cv_after', 'robust_cv_after']).copy()
if plot_df.empty:
    print('\n(no finite cv_after/robust_cv_after for plots)')
else:
    # Scatter overall
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.scatter(plot_df['cv_after'], plot_df['robust_cv_after'], alpha=0.75)
    lim = max(plot_df['cv_after'].max(), plot_df['robust_cv_after'].max()) * 1.05
    ax.plot([0, lim], [0, lim], '--', color='grey', linewidth=1, label='y = x')
    ax.set_xlabel('CV after (existing)')
    ax.set_ylabel('Robust CV after')
    ax.set_title('CV After vs Robust CV After (all patches)')
    ax.legend()
    ax.set_xlim(0, lim)
    ax.set_ylim(0, lim)
    plt.tight_layout()
    plt.show()

    # By population
    pops = sorted(plot_df['population'].dropna().unique())
    n = len(pops)
    cols = min(3, max(n, 1))
    rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.5 * cols, 4 * rows), squeeze=False)
    for i, pop in enumerate(pops):
        r, c = divmod(i, cols)
        ax = axes[r][c]
        sub = plot_df.loc[plot_df['population'] == pop]
        ax.scatter(sub['cv_after'], sub['robust_cv_after'], alpha=0.8)
        m = max(sub['cv_after'].max(), sub['robust_cv_after'].max(), 0.01) * 1.05
        ax.plot([0, m], [0, m], '--', color='grey', linewidth=1)
        # highlight early patches
        early = sub['patch'].astype(str).isin(['1->7', '7->14', '14->30'])
        if early.any():
            ax.scatter(
                sub.loc[early, 'cv_after'], sub.loc[early, 'robust_cv_after'],
                facecolors='none', edgecolors='red', s=80, label='early patches',
            )
        ax.set_title(pop)
        ax.set_xlabel('CV after')
        ax.set_ylabel('Robust CV after')
        ax.set_xlim(0, m)
        ax.set_ylim(0, m)
        if early.any():
            ax.legend(fontsize=8)
    for j in range(i + 1, rows * cols):
        r, c = divmod(j, cols)
        axes[r][c].axis('off')
    fig.suptitle('CV After vs Robust CV After by population', y=1.02)
    plt.tight_layout()
    plt.show()

# brief read — not a recommendation to replace CV
print('\n=== Brief read (not a recommendation to replace CV) ===')
n_flag = int((cmp['flagged'] == True).sum()) if 'flagged' in cmp.columns else 0
n_od = int((cmp.get('variability_diagnosis') == 'OUTLIER_DRIVEN').sum()) if 'variability_diagnosis' in cmp.columns else 0
n_od_flag = int(((cmp.get('variability_diagnosis') == 'OUTLIER_DRIVEN') & (cmp.get('flagged') == True)).sum()) if 'variability_diagnosis' in cmp.columns else 0
n_both_flag = int(((cmp.get('variability_diagnosis') == 'CONSISTENT_VARIABILITY') & (cmp.get('flagged') == True)).sum()) if 'variability_diagnosis' in cmp.columns else 0
print(f'Patches: {len(cmp)}; flagged (existing CV rule): {n_flag}.')
print(f'OUTLIER_DRIVEN overall: {n_od}; of which flagged: {n_od_flag}.')
print(f'CONSISTENT_VARIABILITY & flagged: {n_both_flag}.')
print(
    'If many flagged patches are OUTLIER_DRIVEN, high CV may be driven by a few extreme '
    'cohort dates. If many are CONSISTENT_VARIABILITY, cohorts look unstable even under a '
    'robust spread measure. This experiment only diagnoses; it does not change production CV.'
)
# Out:
# === Robust CV comparison table (all patches) ===
# Classification rule (edit constants in helpers cell):
#   OUTLIER_DRIVEN         if robust/cv <= 0.7
#   CONSISTENT_VARIABILITY if 0.7 < robust/cv <= 1.15
#   REVIEW                 otherwise / missing
#
#     brand population    patch cohort_start cohort_end  n_cohort_dates_total  n_cohort_dates_kept  n_users_pre_trim  n_users_post_trim  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  flagged  variability_diagnosis                                                removed_dates trim_method  trim_pct
# realprize        Web     1->7   2026-06-23 2026-07-27                    35                   30              6241               6241   0.359043          0.315228  0.244573         0.296364                 -0.051791                     1.211762     True                 REVIEW [2026-07-26, 2026-07-07, 2026-07-23, 2026-07-15, 2026-06-26]      winsor      0.01
# realprize        Web    7->14   2026-06-16 2026-07-20                    35                   30              6565               6565   0.220494          0.163219  0.150728         0.144286                  0.006442                     0.957259     True CONSISTENT_VARIABILITY [2026-06-30, 2026-07-03, 2026-07-11, 2026-06-19, 2026-07-14]      winsor      0.01
# realprize        Web   14->30   2026-05-31 2026-07-04                    35                   30              5061               5061   0.536224          0.270678  0.220869         0.211614                  0.009255                     0.958097     True CONSISTENT_VARIABILITY [2026-06-30, 2026-06-15, 2026-06-04, 2026-07-03, 2026-07-02]      winsor      0.01
# realprize        Web   30->60   2026-05-01 2026-06-04                    35                   30              1277               1277   0.272884          0.270069  0.201778         0.208584                 -0.006806                     1.033731     True CONSISTENT_VARIABILITY [2026-05-12, 2026-05-31, 2026-05-26, 2026-05-02, 2026-05-22]      winsor      0.01
# realprize        Web   60->90   2026-04-01 2026-05-05                    35                   30               497                497   0.393106          0.000000  0.125433         0.000000                  0.125433                     0.000000    False         OUTLIER_DRIVEN [2026-04-21, 2026-04-02, 2026-04-19, 2026-04-04, 2026-04-03]      winsor      0.01
# realprize        Web  90->120   2026-03-02 2026-04-05                    35                   30              2295               2295   0.158812          0.193003  0.125078         0.167604                 -0.042526                     1.340000    False                 REVIEW [2026-03-31, 2026-03-13, 2026-03-04, 2026-03-08, 2026-03-20]      winsor      0.01
# realprize        Web 120->150   2026-01-31 2026-03-06                    35                   32              1780               1780   0.195702          0.094424  0.087775         0.064326                  0.023449                     0.732854    False CONSISTENT_VARIABILITY                         [2026-02-26, 2026-02-01, 2026-02-12]      winsor      0.01
# realprize        Web 150->180   2026-01-01 2026-02-04                    35                   35              3337               3337   0.087759          0.045802  0.087759         0.045802                  0.041957                     0.521908    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
# realprize        Web 180->270   2025-10-03 2025-11-06                    35                   30             15743              15743   0.232851          0.185790  0.111117         0.153552                 -0.042435                     1.381892    False                 REVIEW [2025-10-05, 2025-10-11, 2025-10-14, 2025-10-26, 2025-10-12]      winsor      0.01
# realprize        Web 270->365   2025-06-30 2025-08-03                    35                   30             21064              21064   0.344060          0.151333  0.107542         0.142656                 -0.035113                     1.326506    False                 REVIEW [2025-07-23, 2025-07-28, 2025-07-30, 2025-07-18, 2025-07-08]      winsor      0.01
# realprize        App     1->7   2026-06-23 2026-07-27                    35                   30             31034              31034   0.341382          0.174349  0.223079         0.185590                  0.037489                     0.831947     True CONSISTENT_VARIABILITY [2026-07-13, 2026-06-27, 2026-07-08, 2026-07-17, 2026-06-30]      winsor      0.00
# realprize        App    7->14   2026-06-16 2026-07-20                    35                   30             32127              32127   0.170034          0.164442  0.111586         0.130788                 -0.019202                     1.172082    False                 REVIEW [2026-07-14, 2026-06-30, 2026-07-19, 2026-06-27, 2026-06-19]      winsor      0.00
# realprize        App   14->30   2026-05-31 2026-07-04                    35                   31             33341              33341   0.255102          0.096486  0.093723         0.089463                  0.004260                     0.954550    False CONSISTENT_VARIABILITY             [2026-06-24, 2026-06-04, 2026-06-13, 2026-06-27]      winsor      0.00
# realprize        App   30->60   2026-05-01 2026-06-04                    35                   30             29598              29598   0.163753          0.169376  0.117578         0.137377                 -0.019799                     1.168386    False                 REVIEW [2026-05-21, 2026-05-05, 2026-05-07, 2026-05-22, 2026-05-14]      winsor      0.00
# realprize        App   60->90   2026-04-01 2026-05-05                    35                   30             21618              21618   0.242505          0.138103  0.132429         0.106677                  0.025753                     0.805537    False CONSISTENT_VARIABILITY [2026-05-03, 2026-04-28, 2026-05-02, 2026-05-04, 2026-04-26]      winsor      0.00
# realprize        App  90->120   2026-03-02 2026-04-05                    35                   32             19076              19076   0.140358          0.101127  0.079481         0.091728                 -0.012247                     1.154093    False                 REVIEW                         [2026-03-13, 2026-03-11, 2026-03-21]      winsor      0.00
# realprize        App 120->150   2026-01-31 2026-03-06                    35                   35             13650              13650   0.052292          0.053292  0.052292         0.053292                 -0.001000                     1.019126    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
# realprize        App 150->180   2026-01-01 2026-02-04                    35                   35             19839              19839   0.072651          0.082477  0.072651         0.082477                 -0.009826                     1.135253    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
# realprize        App 180->270   2025-10-03 2025-11-06                    35                   30             13298              13298   0.308391          0.176697  0.109293         0.123702                 -0.014409                     1.131840    False CONSISTENT_VARIABILITY [2025-10-29, 2025-10-27, 2025-10-30, 2025-11-02, 2025-10-16]      winsor      0.00
# realprize        App 270->365   2025-06-30 2025-08-03                    35                   33             24384              24384   0.206491          0.115014  0.085927         0.115740                 -0.029813                     1.346956    False                 REVIEW                                     [2025-07-07, 2025-07-16]      winsor      0.00
# realprize  Affiliate     1->7   2026-06-23 2026-07-27                    35                   30             15181              15181   0.425545          0.215198  0.141403         0.159792                 -0.018388                     1.130043    False CONSISTENT_VARIABILITY [2026-07-10, 2026-07-21, 2026-07-12, 2026-07-22, 2026-07-13]      winsor      0.01
# realprize  Affiliate    7->14   2026-06-16 2026-07-20                    35                   33             15321              15321   0.111384          0.098217  0.090185         0.092316                 -0.002131                     1.023628    False CONSISTENT_VARIABILITY                                     [2026-06-22, 2026-07-13]      winsor      0.01
# realprize  Affiliate   14->30   2026-05-31 2026-07-04                    35                   30             15296              15296   0.166376          0.080611  0.094532         0.063673                  0.030858                     0.673564    False         OUTLIER_DRIVEN [2026-06-02, 2026-06-30, 2026-06-25, 2026-06-08, 2026-06-12]      winsor      0.01
# realprize  Affiliate   30->60   2026-05-01 2026-06-04                    35                   32              9852               9852   0.123578          0.143911  0.099726         0.125282                 -0.025557                     1.256270    False                 REVIEW                         [2026-05-08, 2026-05-20, 2026-05-21]      winsor      0.01
# realprize  Affiliate   60->90   2026-04-01 2026-05-05                    35                   35             11760              11760   0.075978          0.087591  0.075978         0.087591                 -0.011613                     1.152841    False                 REVIEW                                                           []      winsor      0.01
# realprize  Affiliate  90->120   2026-03-02 2026-04-05                    35                   35             18373              18373   0.075816          0.032014  0.075816         0.032014                  0.043802                     0.422254    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
# realprize  Affiliate 120->150   2026-01-31 2026-03-06                    35                   35             19113              19113   0.096103          0.033380  0.096103         0.033380                  0.062723                     0.347335    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
# realprize  Affiliate 150->180   2026-01-01 2026-02-04                    35                   35             24263              24263   0.052901          0.046251  0.052901         0.046251                  0.006650                     0.874294    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
# realprize  Affiliate 180->270   2025-10-03 2025-11-06                    35                   35             23399              23399   0.067774          0.072122  0.067774         0.072122                 -0.004347                     1.064145    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
# realprize  Affiliate 270->365   2025-06-30 2025-08-03                    35                   35             39719              39719   0.086077          0.057174  0.086077         0.057174                  0.028903                     0.664224    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
# realprize    Blended     1->7   2026-06-23 2026-07-27                    35                   30             72490              72490   0.277850          0.264715  0.192020         0.210441                 -0.018421                     1.095931     True CONSISTENT_VARIABILITY [2026-06-24, 2026-06-27, 2026-07-02, 2026-07-04, 2026-07-12]      winsor      0.00
# realprize    Blended    7->14   2026-06-16 2026-07-20                    35                   30             73453              73453   0.133137          0.102701  0.100732         0.089696                  0.011036                     0.890446    False CONSISTENT_VARIABILITY [2026-07-05, 2026-06-18, 2026-06-29, 2026-06-24, 2026-07-18]      winsor      0.00
# realprize    Blended   14->30   2026-05-31 2026-07-04                    35                   31             72313              72313   0.167582          0.125877  0.098605         0.110773                 -0.012167                     1.123394    False CONSISTENT_VARIABILITY             [2026-06-16, 2026-06-04, 2026-06-27, 2026-06-01]      winsor      0.00
# realprize    Blended   30->60   2026-05-01 2026-06-04                    35                   31             60401              60401   0.192888          0.096913  0.085180         0.069468                  0.015712                     0.815543    False CONSISTENT_VARIABILITY             [2026-05-20, 2026-05-12, 2026-05-06, 2026-05-21]      winsor      0.00
# realprize    Blended   60->90   2026-04-01 2026-05-05                    35                   32             55218              55218   0.142963          0.127545  0.094387         0.124416                 -0.030030                     1.318159    False                 REVIEW                         [2026-04-30, 2026-04-28, 2026-05-02]      winsor      0.00
# realprize    Blended  90->120   2026-03-02 2026-04-05                    35                   34             57777              57777   0.113289          0.103857  0.090758         0.091510                 -0.000752                     1.008290    False CONSISTENT_VARIABILITY                                                 [2026-03-21]      winsor      0.00
# realprize    Blended 120->150   2026-01-31 2026-03-06                    35                   35             55176              55176   0.041437          0.041494  0.041437         0.041494                 -0.000057                     1.001373    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
# realprize    Blended 150->180   2026-01-01 2026-02-04                    35                   35             65093              65093   0.053310          0.042872  0.053310         0.042872                  0.010438                     0.804203    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
# realprize    Blended 180->270   2025-10-03 2025-11-06                    35                   31             78730              78730   0.135293          0.091148  0.097453         0.077799                  0.019654                     0.798324    False CONSISTENT_VARIABILITY             [2025-10-25, 2025-10-04, 2025-10-26, 2025-10-29]      winsor      0.00
# realprize    Blended 270->365   2025-06-30 2025-08-03                    35                   35            117022             117022   0.074368          0.070696  0.074368         0.070696                  0.003672                     0.950621    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
#  lonestar        Web     1->7   2026-06-23 2026-07-27                    35                   30             19978              19978   0.439340          0.314302  0.316002         0.233063                  0.082939                     0.737537     True CONSISTENT_VARIABILITY [2026-07-10, 2026-06-30, 2026-06-26, 2026-07-06, 2026-06-28]      winsor      0.00
#  lonestar        Web    7->14   2026-06-16 2026-07-20                    35                   30             21937              21937   0.216866          0.220817  0.142392         0.188276                 -0.045884                     1.322236    False                 REVIEW [2026-07-14, 2026-07-10, 2026-06-30, 2026-07-11, 2026-07-15]      winsor      0.00
#  lonestar        Web   14->30   2026-05-31 2026-07-04                    35                   30             23374              23374   0.258925          0.185398  0.158852         0.145767                  0.013085                     0.917626     True CONSISTENT_VARIABILITY [2026-06-17, 2026-06-16, 2026-06-07, 2026-06-19, 2026-06-18]      winsor      0.00
#  lonestar        Web   30->60   2026-05-01 2026-06-04                    35                   30             15967              15967   0.289354          0.196280  0.162292         0.160278                  0.002014                     0.987592     True CONSISTENT_VARIABILITY [2026-05-09, 2026-05-15, 2026-05-26, 2026-05-12, 2026-05-27]      winsor      0.00
#  lonestar        Web   60->90   2026-04-01 2026-05-05                    35                   30             16275              16275   0.226624          0.132046  0.124878         0.119300                  0.005578                     0.955331    False CONSISTENT_VARIABILITY [2026-04-19, 2026-04-25, 2026-04-18, 2026-04-05, 2026-04-15]      winsor      0.00
#  lonestar        Web  90->120   2026-03-02 2026-04-05                    35                   30              9219               9219   0.153863          0.099694  0.107416         0.078220                  0.029195                     0.728202    False CONSISTENT_VARIABILITY [2026-03-08, 2026-03-28, 2026-03-19, 2026-03-11, 2026-03-21]      winsor      0.00
#  lonestar        Web 120->150   2026-01-31 2026-03-06                    35                   34              6056               6056   0.175946          0.074247  0.079299         0.071923                  0.007376                     0.906983    False CONSISTENT_VARIABILITY                                                 [2026-02-18]      winsor      0.00
#  lonestar        Web 150->180   2026-01-01 2026-02-04                    35                   31              4223               4223   0.177902          0.129154  0.077723         0.105876                 -0.028153                     1.362223    False                 REVIEW             [2026-01-15, 2026-01-02, 2026-01-12, 2026-01-28]      winsor      0.00
#  lonestar        Web 180->270   2025-10-03 2025-11-06                    35                   30             26859              26859   2.070565          0.170548  0.194077         0.160412                  0.033665                     0.826537     True CONSISTENT_VARIABILITY [2025-10-05, 2025-10-04, 2025-11-01, 2025-10-21, 2025-10-07]      winsor      0.00
#  lonestar        Web 270->365   2025-06-30 2025-08-03                    35                   30             31294              31294   0.306148          0.082681  0.098877         0.061616                  0.037261                     0.623157    False         OUTLIER_DRIVEN [2025-06-30, 2025-07-17, 2025-07-24, 2025-07-30, 2025-07-19]      winsor      0.00
#  lonestar  Affiliate     1->7   2026-06-23 2026-07-27                    35                   30             42640              42640   0.173956          0.208930  0.135468         0.184802                 -0.049334                     1.364173    False                 REVIEW [2026-07-20, 2026-07-18, 2026-07-11, 2026-07-10, 2026-07-26]      winsor      0.01
#  lonestar  Affiliate    7->14   2026-06-16 2026-07-20                    35                   33             38057              38057   0.129743          0.077980  0.089556         0.082836                  0.006720                     0.924963    False CONSISTENT_VARIABILITY                                     [2026-07-15, 2026-07-17]      winsor      0.01
#  lonestar  Affiliate   14->30   2026-05-31 2026-07-04                    35                   32             35740              35740   0.133011          0.089842  0.099749         0.076732                  0.023017                     0.769255    False CONSISTENT_VARIABILITY                         [2026-06-07, 2026-06-30, 2026-06-22]      winsor      0.01
#  lonestar  Affiliate   30->60   2026-05-01 2026-06-04                    35                   33             26970              26970   0.159098          0.089145  0.094078         0.081915                  0.012163                     0.870712    False CONSISTENT_VARIABILITY                                     [2026-05-23, 2026-05-28]      winsor      0.01
#  lonestar  Affiliate   60->90   2026-04-01 2026-05-05                    35                   35             35804              35804   0.086208          0.063444  0.086208         0.063444                  0.022764                     0.735943    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
#  lonestar  Affiliate  90->120   2026-03-02 2026-04-05                    35                   35             40830              40830   0.068192          0.046478  0.068192         0.046478                  0.021714                     0.681571    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
#  lonestar  Affiliate 120->150   2026-01-31 2026-03-06                    35                   35             51855              51855   0.063555          0.045701  0.063555         0.045701                  0.017854                     0.719074    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
#  lonestar  Affiliate 150->180   2026-01-01 2026-02-04                    35                   35             48112              48112   0.031994          0.024900  0.031994         0.024900                  0.007094                     0.778272    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
#  lonestar  Affiliate 180->270   2025-10-03 2025-11-06                    35                   35             40021              40021   0.087892          0.072770  0.087892         0.072770                  0.015122                     0.827945    False CONSISTENT_VARIABILITY                                                           []      winsor      0.01
#  lonestar  Affiliate 270->365   2025-06-30 2025-08-03                    35                   35             32563              32563   0.094608          0.053743  0.094608         0.053743                  0.040865                     0.568060    False         OUTLIER_DRIVEN                                                           []      winsor      0.01
#  lonestar    Blended     1->7   2026-06-23 2026-07-27                    35                   30             84031              84031   0.308099          0.331151  0.238197         0.291236                 -0.053040                     1.222671     True                 REVIEW [2026-07-12, 2026-07-19, 2026-07-10, 2026-07-11, 2026-07-14]      winsor      0.00
#  lonestar    Blended    7->14   2026-06-16 2026-07-20                    35                   33             81283              81283   0.112610          0.106792  0.099335         0.095430                  0.003905                     0.960687    False CONSISTENT_VARIABILITY                                     [2026-07-11, 2026-06-30]      winsor      0.00
#  lonestar    Blended   14->30   2026-05-31 2026-07-04                    35                   30             80116              80116   0.148877          0.142405  0.101032         0.092933                  0.008098                     0.919844    False CONSISTENT_VARIABILITY [2026-06-07, 2026-07-02, 2026-07-03, 2026-07-01, 2026-06-19]      winsor      0.00
#  lonestar    Blended   30->60   2026-05-01 2026-06-04                    35                   30             68667              68667   0.225677          0.155465  0.130171         0.148326                 -0.018155                     1.139470    False CONSISTENT_VARIABILITY [2026-05-03, 2026-06-01, 2026-05-15, 2026-05-29, 2026-05-04]      winsor      0.00
#  lonestar    Blended   60->90   2026-04-01 2026-05-05                    35                   33             76409              76409   0.171523          0.100660  0.086230         0.093262                 -0.007032                     1.081544    False CONSISTENT_VARIABILITY                                     [2026-04-19, 2026-05-03]      winsor      0.00
#  lonestar    Blended  90->120   2026-03-02 2026-04-05                    35                   35             75428              75428   0.083313          0.093358  0.083313         0.093358                 -0.010045                     1.120571    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
#  lonestar    Blended 120->150   2026-01-31 2026-03-06                    35                   35             87681              87681   0.095312          0.058023  0.095312         0.058023                  0.037290                     0.608762    False         OUTLIER_DRIVEN                                                           []      winsor      0.00
#  lonestar    Blended 150->180   2026-01-01 2026-02-04                    35                   35             82719              82719   0.052298          0.044989  0.052298         0.044989                  0.007309                     0.860250    False CONSISTENT_VARIABILITY                                                           []      winsor      0.00
#  lonestar    Blended 180->270   2025-10-03 2025-11-06                    35                   34            128525             128525   0.102565          0.077246  0.084959         0.076390                  0.008569                     0.899142    False CONSISTENT_VARIABILITY                                                 [2025-10-05]      winsor      0.00
#  lonestar    Blended 270->365   2025-06-30 2025-08-03                    35                   33            120042             120042   0.135469          0.078749  0.092311         0.078521                  0.013790                     0.850613    False CONSISTENT_VARIABILITY                                     [2025-08-01, 2025-07-24]      winsor      0.00
#
# Saved working-dir comparison CSV: combined_cv_robust_compare_2026-08-03_rp_ls_robust_cv_111132.csv
# Saved Drive comparison CSV: /content/drive/MyDrive/lee_project/marketing_goals/runs/2026-08-03_rp_ls_robust_cv_111132/combined_cv_robust_compare.csv
#
# === 1) Mean / median CV vs Robust CV by patch ===
#    patch  n  cv_after_mean  cv_after_median  robust_cv_after_mean  robust_cv_after_median
#     1->7  7       0.212963         0.223079              0.223041                0.210441
#    7->14  7       0.112073         0.100732              0.117661                0.095430
#   14->30  7       0.123909         0.099749              0.112994                0.092933
#   30->60  7       0.127258         0.117578              0.133033                0.137377
#   60->90  7       0.103649         0.094387              0.084956                0.093262
#  90->120  7       0.090008         0.083313              0.085845                0.091510
# 120->150  7       0.073682         0.079299              0.052591                0.053292
# 150->180  7       0.061234         0.053310              0.056167                0.045802
# 180->270  7       0.107509         0.097453              0.105249                0.077799
# 270->365  7       0.091387         0.092311              0.082878                0.070696
#
# === 2) CV vs Robust CV by brand × population × patch ===
#     brand population    patch  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  flagged  variability_diagnosis
#  lonestar  Affiliate     1->7   0.173956          0.208930  0.135468         0.184802                 -0.049334                     1.364173    False                 REVIEW
#  lonestar  Affiliate 120->150   0.063555          0.045701  0.063555         0.045701                  0.017854                     0.719074    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate   14->30   0.133011          0.089842  0.099749         0.076732                  0.023017                     0.769255    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate 150->180   0.031994          0.024900  0.031994         0.024900                  0.007094                     0.778272    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate 180->270   0.087892          0.072770  0.087892         0.072770                  0.015122                     0.827945    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate 270->365   0.094608          0.053743  0.094608         0.053743                  0.040865                     0.568060    False         OUTLIER_DRIVEN
#  lonestar  Affiliate   30->60   0.159098          0.089145  0.094078         0.081915                  0.012163                     0.870712    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate   60->90   0.086208          0.063444  0.086208         0.063444                  0.022764                     0.735943    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate    7->14   0.129743          0.077980  0.089556         0.082836                  0.006720                     0.924963    False CONSISTENT_VARIABILITY
#  lonestar  Affiliate  90->120   0.068192          0.046478  0.068192         0.046478                  0.021714                     0.681571    False         OUTLIER_DRIVEN
#  lonestar    Blended     1->7   0.308099          0.331151  0.238197         0.291236                 -0.053040                     1.222671     True                 REVIEW
#  lonestar    Blended 120->150   0.095312          0.058023  0.095312         0.058023                  0.037290                     0.608762    False         OUTLIER_DRIVEN
#  lonestar    Blended   14->30   0.148877          0.142405  0.101032         0.092933                  0.008098                     0.919844    False CONSISTENT_VARIABILITY
#  lonestar    Blended 150->180   0.052298          0.044989  0.052298         0.044989                  0.007309                     0.860250    False CONSISTENT_VARIABILITY
#  lonestar    Blended 180->270   0.102565          0.077246  0.084959         0.076390                  0.008569                     0.899142    False CONSISTENT_VARIABILITY
#  lonestar    Blended 270->365   0.135469          0.078749  0.092311         0.078521                  0.013790                     0.850613    False CONSISTENT_VARIABILITY
#  lonestar    Blended   30->60   0.225677          0.155465  0.130171         0.148326                 -0.018155                     1.139470    False CONSISTENT_VARIABILITY
#  lonestar    Blended   60->90   0.171523          0.100660  0.086230         0.093262                 -0.007032                     1.081544    False CONSISTENT_VARIABILITY
#  lonestar    Blended    7->14   0.112610          0.106792  0.099335         0.095430                  0.003905                     0.960687    False CONSISTENT_VARIABILITY
#  lonestar    Blended  90->120   0.083313          0.093358  0.083313         0.093358                 -0.010045                     1.120571    False CONSISTENT_VARIABILITY
#  lonestar        Web     1->7   0.439340          0.314302  0.316002         0.233063                  0.082939                     0.737537     True CONSISTENT_VARIABILITY
#  lonestar        Web 120->150   0.175946          0.074247  0.079299         0.071923                  0.007376                     0.906983    False CONSISTENT_VARIABILITY
#  lonestar        Web   14->30   0.258925          0.185398  0.158852         0.145767                  0.013085                     0.917626     True CONSISTENT_VARIABILITY
#  lonestar        Web 150->180   0.177902          0.129154  0.077723         0.105876                 -0.028153                     1.362223    False                 REVIEW
#  lonestar        Web 180->270   2.070565          0.170548  0.194077         0.160412                  0.033665                     0.826537     True CONSISTENT_VARIABILITY
#  lonestar        Web 270->365   0.306148          0.082681  0.098877         0.061616                  0.037261                     0.623157    False         OUTLIER_DRIVEN
#  lonestar        Web   30->60   0.289354          0.196280  0.162292         0.160278                  0.002014                     0.987592     True CONSISTENT_VARIABILITY
#  lonestar        Web   60->90   0.226624          0.132046  0.124878         0.119300                  0.005578                     0.955331    False CONSISTENT_VARIABILITY
#  lonestar        Web    7->14   0.216866          0.220817  0.142392         0.188276                 -0.045884                     1.322236    False                 REVIEW
#  lonestar        Web  90->120   0.153863          0.099694  0.107416         0.078220                  0.029195                     0.728202    False CONSISTENT_VARIABILITY
# realprize  Affiliate     1->7   0.425545          0.215198  0.141403         0.159792                 -0.018388                     1.130043    False CONSISTENT_VARIABILITY
# realprize  Affiliate 120->150   0.096103          0.033380  0.096103         0.033380                  0.062723                     0.347335    False         OUTLIER_DRIVEN
# realprize  Affiliate   14->30   0.166376          0.080611  0.094532         0.063673                  0.030858                     0.673564    False         OUTLIER_DRIVEN
# realprize  Affiliate 150->180   0.052901          0.046251  0.052901         0.046251                  0.006650                     0.874294    False CONSISTENT_VARIABILITY
# realprize  Affiliate 180->270   0.067774          0.072122  0.067774         0.072122                 -0.004347                     1.064145    False CONSISTENT_VARIABILITY
# realprize  Affiliate 270->365   0.086077          0.057174  0.086077         0.057174                  0.028903                     0.664224    False         OUTLIER_DRIVEN
# realprize  Affiliate   30->60   0.123578          0.143911  0.099726         0.125282                 -0.025557                     1.256270    False                 REVIEW
# realprize  Affiliate   60->90   0.075978          0.087591  0.075978         0.087591                 -0.011613                     1.152841    False                 REVIEW
# realprize  Affiliate    7->14   0.111384          0.098217  0.090185         0.092316                 -0.002131                     1.023628    False CONSISTENT_VARIABILITY
# realprize  Affiliate  90->120   0.075816          0.032014  0.075816         0.032014                  0.043802                     0.422254    False         OUTLIER_DRIVEN
# realprize        App     1->7   0.341382          0.174349  0.223079         0.185590                  0.037489                     0.831947     True CONSISTENT_VARIABILITY
# realprize        App 120->150   0.052292          0.053292  0.052292         0.053292                 -0.001000                     1.019126    False CONSISTENT_VARIABILITY
# realprize        App   14->30   0.255102          0.096486  0.093723         0.089463                  0.004260                     0.954550    False CONSISTENT_VARIABILITY
# realprize        App 150->180   0.072651          0.082477  0.072651         0.082477                 -0.009826                     1.135253    False CONSISTENT_VARIABILITY
# realprize        App 180->270   0.308391          0.176697  0.109293         0.123702                 -0.014409                     1.131840    False CONSISTENT_VARIABILITY
# realprize        App 270->365   0.206491          0.115014  0.085927         0.115740                 -0.029813                     1.346956    False                 REVIEW
# realprize        App   30->60   0.163753          0.169376  0.117578         0.137377                 -0.019799                     1.168386    False                 REVIEW
# realprize        App   60->90   0.242505          0.138103  0.132429         0.106677                  0.025753                     0.805537    False CONSISTENT_VARIABILITY
# realprize        App    7->14   0.170034          0.164442  0.111586         0.130788                 -0.019202                     1.172082    False                 REVIEW
# realprize        App  90->120   0.140358          0.101127  0.079481         0.091728                 -0.012247                     1.154093    False                 REVIEW
# realprize    Blended     1->7   0.277850          0.264715  0.192020         0.210441                 -0.018421                     1.095931     True CONSISTENT_VARIABILITY
# realprize    Blended 120->150   0.041437          0.041494  0.041437         0.041494                 -0.000057                     1.001373    False CONSISTENT_VARIABILITY
# realprize    Blended   14->30   0.167582          0.125877  0.098605         0.110773                 -0.012167                     1.123394    False CONSISTENT_VARIABILITY
# realprize    Blended 150->180   0.053310          0.042872  0.053310         0.042872                  0.010438                     0.804203    False CONSISTENT_VARIABILITY
# realprize    Blended 180->270   0.135293          0.091148  0.097453         0.077799                  0.019654                     0.798324    False CONSISTENT_VARIABILITY
# realprize    Blended 270->365   0.074368          0.070696  0.074368         0.070696                  0.003672                     0.950621    False CONSISTENT_VARIABILITY
# realprize    Blended   30->60   0.192888          0.096913  0.085180         0.069468                  0.015712                     0.815543    False CONSISTENT_VARIABILITY
# realprize    Blended   60->90   0.142963          0.127545  0.094387         0.124416                 -0.030030                     1.318159    False                 REVIEW
# realprize    Blended    7->14   0.133137          0.102701  0.100732         0.089696                  0.011036                     0.890446    False CONSISTENT_VARIABILITY
# realprize    Blended  90->120   0.113289          0.103857  0.090758         0.091510                 -0.000752                     1.008290    False CONSISTENT_VARIABILITY
# realprize        Web     1->7   0.359043          0.315228  0.244573         0.296364                 -0.051791                     1.211762     True                 REVIEW
# realprize        Web 120->150   0.195702          0.094424  0.087775         0.064326                  0.023449                     0.732854    False CONSISTENT_VARIABILITY
# realprize        Web   14->30   0.536224          0.270678  0.220869         0.211614                  0.009255                     0.958097     True CONSISTENT_VARIABILITY
# realprize        Web 150->180   0.087759          0.045802  0.087759         0.045802                  0.041957                     0.521908    False         OUTLIER_DRIVEN
# realprize        Web 180->270   0.232851          0.185790  0.111117         0.153552                 -0.042435                     1.381892    False                 REVIEW
# realprize        Web 270->365   0.344060          0.151333  0.107542         0.142656                 -0.035113                     1.326506    False                 REVIEW
# realprize        Web   30->60   0.272884          0.270069  0.201778         0.208584                 -0.006806                     1.033731     True CONSISTENT_VARIABILITY
# realprize        Web   60->90   0.393106          0.000000  0.125433         0.000000                  0.125433                     0.000000    False         OUTLIER_DRIVEN
# realprize        Web    7->14   0.220494          0.163219  0.150728         0.144286                  0.006442                     0.957259     True CONSISTENT_VARIABILITY
# realprize        Web  90->120   0.158812          0.193003  0.125078         0.167604                 -0.042526                     1.340000    False                 REVIEW
#
# === 3) Flagged patches (cv_after desc) with Robust CV ===
#     brand population    patch  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  flagged  variability_diagnosis
#  lonestar        Web     1->7   0.439340          0.314302  0.316002         0.233063                  0.082939                     0.737537     True CONSISTENT_VARIABILITY
# realprize        Web     1->7   0.359043          0.315228  0.244573         0.296364                 -0.051791                     1.211762     True                 REVIEW
#  lonestar    Blended     1->7   0.308099          0.331151  0.238197         0.291236                 -0.053040                     1.222671     True                 REVIEW
# realprize        App     1->7   0.341382          0.174349  0.223079         0.185590                  0.037489                     0.831947     True CONSISTENT_VARIABILITY
# realprize        Web   14->30   0.536224          0.270678  0.220869         0.211614                  0.009255                     0.958097     True CONSISTENT_VARIABILITY
# realprize        Web   30->60   0.272884          0.270069  0.201778         0.208584                 -0.006806                     1.033731     True CONSISTENT_VARIABILITY
#  lonestar        Web 180->270   2.070565          0.170548  0.194077         0.160412                  0.033665                     0.826537     True CONSISTENT_VARIABILITY
# realprize    Blended     1->7   0.277850          0.264715  0.192020         0.210441                 -0.018421                     1.095931     True CONSISTENT_VARIABILITY
#  lonestar        Web   30->60   0.289354          0.196280  0.162292         0.160278                  0.002014                     0.987592     True CONSISTENT_VARIABILITY
#  lonestar        Web   14->30   0.258925          0.185398  0.158852         0.145767                  0.013085                     0.917626     True CONSISTENT_VARIABILITY
# realprize        Web    7->14   0.220494          0.163219  0.150728         0.144286                  0.006442                     0.957259     True CONSISTENT_VARIABILITY
#
# === 4) High CV but substantially lower Robust CV (OUTLIER_DRIVEN) ===
#     brand population    patch  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  flagged variability_diagnosis
# realprize        Web   60->90   0.393106          0.000000  0.125433         0.000000                  0.125433                     0.000000    False        OUTLIER_DRIVEN
#  lonestar        Web 270->365   0.306148          0.082681  0.098877         0.061616                  0.037261                     0.623157    False        OUTLIER_DRIVEN
# realprize  Affiliate 120->150   0.096103          0.033380  0.096103         0.033380                  0.062723                     0.347335    False        OUTLIER_DRIVEN
#  lonestar    Blended 120->150   0.095312          0.058023  0.095312         0.058023                  0.037290                     0.608762    False        OUTLIER_DRIVEN
#  lonestar  Affiliate 270->365   0.094608          0.053743  0.094608         0.053743                  0.040865                     0.568060    False        OUTLIER_DRIVEN
# realprize  Affiliate   14->30   0.166376          0.080611  0.094532         0.063673                  0.030858                     0.673564    False        OUTLIER_DRIVEN
# realprize        Web 150->180   0.087759          0.045802  0.087759         0.045802                  0.041957                     0.521908    False        OUTLIER_DRIVEN
# realprize  Affiliate 270->365   0.086077          0.057174  0.086077         0.057174                  0.028903                     0.664224    False        OUTLIER_DRIVEN
# realprize  Affiliate  90->120   0.075816          0.032014  0.075816         0.032014                  0.043802                     0.422254    False        OUTLIER_DRIVEN
#  lonestar  Affiliate  90->120   0.068192          0.046478  0.068192         0.046478                  0.021714                     0.681571    False        OUTLIER_DRIVEN
#
# === 5) Both metrics remain high (CONSISTENT_VARIABILITY & flagged) ===
#     brand population    patch  cv_before  robust_cv_before  cv_after  robust_cv_after  cv_minus_robust_cv_after  robust_to_standard_cv_ratio  flagged  variability_diagnosis
#  lonestar        Web     1->7   0.439340          0.314302  0.316002         0.233063                  0.082939                     0.737537     True CONSISTENT_VARIABILITY
# realprize        App     1->7   0.341382          0.174349  0.223079         0.185590                  0.037489                     0.831947     True CONSISTENT_VARIABILITY
# realprize        Web   14->30   0.536224          0.270678  0.220869         0.211614                  0.009255                     0.958097     True CONSISTENT_VARIABILITY
# realprize        Web   30->60   0.272884          0.270069  0.201778         0.208584                 -0.006806                     1.033731     True CONSISTENT_VARIABILITY
#  lonestar        Web 180->270   2.070565          0.170548  0.194077         0.160412                  0.033665                     0.826537     True CONSISTENT_VARIABILITY
# realprize    Blended     1->7   0.277850          0.264715  0.192020         0.210441                 -0.018421                     1.095931     True CONSISTENT_VARIABILITY
#  lonestar        Web   30->60   0.289354          0.196280  0.162292         0.160278                  0.002014                     0.987592     True CONSISTENT_VARIABILITY
#  lonestar        Web   14->30   0.258925          0.185398  0.158852         0.145767                  0.013085                     0.917626     True CONSISTENT_VARIABILITY
# realprize        Web    7->14   0.220494          0.163219  0.150728         0.144286                  0.006442                     0.957259     True CONSISTENT_VARIABILITY
# === Brief read (not a recommendation to replace CV) ===
# Patches: 70; flagged (existing CV rule): 11.
# OUTLIER_DRIVEN overall: 10; of which flagged: 0.
# CONSISTENT_VARIABILITY & flagged: 9.
# If many flagged patches are OUTLIER_DRIVEN, high CV may be driven by a few extreme cohort dates. If many are CONSISTENT_VARIABILITY, cohorts look unstable even under a robust spread measure. This experiment only diagnoses; it does not change production CV.
